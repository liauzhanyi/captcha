# %%
DATA_PATH = '/home/liauzhanyi/cs4243/data'
TEST_DATASET_PATH = DATA_PATH + '/test'
TRAIN_DATASET_PATH = DATA_PATH + '/train'
OUTPUT_PATH = f'{DATA_PATH}/segmented_train'
SEGMENTED_TRAIN_DATASET_PATH = f'{DATA_PATH}/segmented_train'
AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH = f'{DATA_PATH}/augmented_segmented_train'

IMG_HEIGHT, IMG_WIDTH = 80, 400

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-10-26 09:55:18.844444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1729907718.943670    6907 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1729907718.977884    6907 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-26 09:55:19.241953: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def dilate(image, kernel_size=(3, 3)):
    kernel = np.ones(kernel_size, np.uint8)
    dilation = cv2.dilate(image, kernel, iterations=1)
    return dilation

def erode(image, kernel_size=(3, 3)):
    kernel = np.ones(kernel_size, np.uint8)
    erosion = cv2.erode(image, kernel, iterations=1)
    return erosion

def gaussian_thresholding(image, kernel=(5, 5), block_size=11, C=2):
    blur = cv2.GaussianBlur(image, kernel, 0)
    thresholded_image = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY, blockSize=block_size, C=C
    )
    return thresholded_image

def segment_characters(image):
    inverted_image = cv2.bitwise_not(image)
    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    char_images = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if h > 10:  # Filter small noise
            char_img = image[y:y+h, x:x+w]
            char_images.append((x, char_img))
    char_images = sorted(char_images, key=lambda c: c[0])  # Sort by x-coordinate

    return [char[1] for char in char_images]

# %%
def process_and_save_images(input_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Keep track of how many captchas were skipped
    skipped_count = 0

    # Process each image in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Extract the true label from the filename
            base_name = filename.split('-')[0]

            # Load and preprocess the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Apply preprocessing steps
            image = cv2.bitwise_not(image)
            image = erode(image, kernel_size=(2, 2))
            image = cv2.bitwise_not(image)
            image = gaussian_thresholding(image, kernel=(5, 5), block_size=11, C=2)
            image = erode(image, kernel_size=(2, 2))
            image = gaussian_thresholding(image, kernel=(5, 5), block_size=11, C=2)
            image = erode(image, kernel_size=(2, 2))

            # Segment characters
            char_images = segment_characters(image)

            # Validate the number of segmented parts
            if len(char_images) != len(base_name):
                print(f"Skipping {filename}: Expected {len(base_name)} parts, got {len(char_images)}.")
                skipped_count += 1
                continue  # Skip saving this image

            # Save each segmented character follow the naming convention <label_str>-<char>.png
            for idx, char_img in enumerate(char_images):
                char_label = base_name[idx]
                save_name = f"{base_name}-{char_label}.png"
                save_path = os.path.join(output_dir, save_name)

                # Save the segmented character
                cv2.imwrite(save_path, char_img)

    print(f"Processing complete! Segmented characters are saved in {output_dir}")
    print(f"Total skipped: {skipped_count}")

process_and_save_images(TRAIN_DATASET_PATH, SEGMENTED_TRAIN_DATASET_PATH)
# Out:
# Skipping f9305osy-0.png: Expected 8 parts, got 13.
# Skipping shfkvjtx-0.png: Expected 8 parts, got 7.
# Skipping mhpky4-0.png: Expected 6 parts, got 7.
# Skipping 2at5l1k9-0.png: Expected 8 parts, got 2.
# Skipping ifg6ly-0.png: Expected 6 parts, got 7.
# Skipping md79ncz4-0.png: Expected 8 parts, got 9.
# Skipping ot728-0.png: Expected 5 parts, got 6.
# Skipping ji9zjl3b-0.png: Expected 8 parts, got 7.
# Skipping hiczvfiu-0.png: Expected 8 parts, got 7.
# Skipping 6rw7x-0.png: Expected 5 parts, got 4.
# Skipping 5uzppk-0.png: Expected 6 parts, got 7.
# Skipping wjss-0.png: Expected 4 parts, got 3.
# Skipping 916e-0.png: Expected 4 parts, got 3.
# Skipping j5e1ag-0.png: Expected 6 parts, got 5.
# Skipping 4d3wu-0.png: Expected 5 parts, got 6.
# Skipping pw6m9n-0.png: Expected 6 parts, got 8.
# Skipping gdrbjx-0.png: Expected 6 parts, got 5.
# Skipping u5zba0-0.png: Expected 6 parts, got 5.
# Skipping 69n150-0.png: Expected 6 parts, got 5.
# Skipping bsqrf4-0.png: Expected 6 parts, got 4.
# Skipping k0x12-0.png: Expected 5 parts, got 3.
# Skipping v4xj8-0.png: Expected 5 parts, got 0.
# Skipping 6c4p6qhc-0.png: Expected 8 parts, got 12.
# Skipping spnwdje-0.png: Expected 7 parts, got 4.
# Skipping 4fw61vc-0.png: Expected 7 parts, got 5.
# Skipping xrdc-0.png: Expected 4 parts, got 1.
# Skipping fk17p-0.png: Expected 5 parts, got 4.
# Skipping 6zdkq7o-0.png: Expected 7 parts, got 5.
# Skipping crlfgrl-0.png: Expected 7 parts, got 6.
# Skipping nlah-0.png: Expected 4 parts, got 7.
# Skipping n2ujhk0b-0.png: Expected 8 parts, got 2.
# Skipping qpbv6led-0.png: Expected 8 parts, got 9.
# Skipping jhob1-0.png: Expected 5 parts, got 4.
# Skipping 7v2460-0.png: Expected 6 parts, got 7.
# Skipping rmtsp1w1-0.png: Expected 8 parts, got 11.
# Skipping ibtj-0.png: Expected 4 parts, got 1.
# Skipping 3v17ro93-0.png: Expected 8 parts, got 6.
# Skipping wcum5y-0.png: Expected 6 parts, got 7.
# Skipping n1sr52-0.png: Expected 6 parts, got 9.
# Skipping lhilaj-0.png: Expected 6 parts, got 4.
# Skipping kfew-0.png: Expected 4 parts, got 3.
# Skipping ngsc-0.png: Expected 4 parts, got 1.
# Skipping trf8z7r-0.png: Expected 7 parts, got 6.
# Skipping zeid7gsb-0.png: Expected 8 parts, got 4.
# Skipping 63z7g-0.png: Expected 5 parts, got 7.
# Skipping 7dqtxy-0.png: Expected 6 parts, got 2.
# Skipping cx2ysb-0.png: Expected 6 parts, got 16.
# Skipping dymxr-0.png: Expected 5 parts, got 4.
# Skipping owoxze6-0.png: Expected 7 parts, got 6.
# Skipping a3wpy8-0.png: Expected 6 parts, got 8.
# Skipping ul77-0.png: Expected 4 parts, got 3.
# Skipping rg1ce-0.png: Expected 5 parts, got 3.
# Skipping iuzr7-0.png: Expected 5 parts, got 2.
# Skipping w6podu-0.png: Expected 6 parts, got 9.
# Skipping lpv0fg4g-0.png: Expected 8 parts, got 10.
# Skipping lw86q-0.png: Expected 5 parts, got 3.
# Skipping s6vqce6-0.png: Expected 7 parts, got 4.
# Skipping mh2lv-0.png: Expected 5 parts, got 8.
# Skipping 4knef0-0.png: Expected 6 parts, got 7.
# Skipping dxx8nkp-0.png: Expected 7 parts, got 6.
# Skipping shx46lx-0.png: Expected 7 parts, got 6.
# Skipping cc8y-0.png: Expected 4 parts, got 3.
# Skipping io26vp4-0.png: Expected 7 parts, got 5.
# Skipping 8v14kl-0.png: Expected 6 parts, got 4.
# Skipping s5wb1q-0.png: Expected 6 parts, got 0.
# Skipping ei8c8mhy-0.png: Expected 8 parts, got 4.
# Skipping f6rie-0.png: Expected 5 parts, got 4.
# Skipping pd7tcd12-0.png: Expected 8 parts, got 7.
# Skipping tqy4so-0.png: Expected 6 parts, got 9.
# Skipping mcik3b1-0.png: Expected 7 parts, got 5.
# Skipping 3uqd-0.png: Expected 4 parts, got 2.
# Skipping fks4-0.png: Expected 4 parts, got 2.
# Skipping mnzu-0.png: Expected 4 parts, got 5.
# Skipping pk7d-0.png: Expected 4 parts, got 3.
# Skipping d6147s-0.png: Expected 6 parts, got 9.
# Skipping 44y4ih3-0.png: Expected 7 parts, got 4.
# Skipping wk6ll3-0.png: Expected 6 parts, got 15.
# Skipping 7s0txxh-0.png: Expected 7 parts, got 3.
# Skipping q9gvg1ew-0.png: Expected 8 parts, got 9.
# Skipping fe7ous-0.png: Expected 6 parts, got 5.
# Skipping 8jbtjs-0.png: Expected 6 parts, got 8.
# Skipping fvdaomqc-0.png: Expected 8 parts, got 2.
# Skipping 99xgc9m2-0.png: Expected 8 parts, got 5.
# Skipping zl259-0.png: Expected 5 parts, got 7.
# Skipping dkabj-0.png: Expected 5 parts, got 6.
# Skipping nehnwg-0.png: Expected 6 parts, got 5.
# Skipping 6ktbls-0.png: Expected 6 parts, got 5.
# Skipping zwol36kj-0.png: Expected 8 parts, got 14.
# Skipping wm0klj-0.png: Expected 6 parts, got 5.
# Skipping hcul03l-0.png: Expected 7 parts, got 6.
# Skipping 23e4h-0.png: Expected 5 parts, got 3.
# Skipping wf0qh7-0.png: Expected 6 parts, got 8.
# Skipping hwq0huvj-0.png: Expected 8 parts, got 5.
# Skipping 7etzoob-0.png: Expected 7 parts, got 5.
# Skipping g47ff-0.png: Expected 5 parts, got 6.
# Skipping dsgrtai-0.png: Expected 7 parts, got 4.
# Skipping 3zb67dd6-0.png: Expected 8 parts, got 6.
# Skipping rqejj20e-0.png: Expected 8 parts, got 9.
# Skipping btip85-0.png: Expected 6 parts, got 8.
# Skipping 1y2lk-0.png: Expected 5 parts, got 4.
# Skipping dqeds7z-0.png: Expected 7 parts, got 5.
# Skipping g7pft2-0.png: Expected 6 parts, got 4.
# Skipping qswxd6-0.png: Expected 6 parts, got 7.
# Skipping 70do56y-0.png: Expected 7 parts, got 3.
# Skipping 67zs-0.png: Expected 4 parts, got 3.
# Skipping 32pt-0.png: Expected 4 parts, got 5.
# Skipping wtvaivr-0.png: Expected 7 parts, got 4.
# Skipping pdpkbaxg-0.png: Expected 8 parts, got 0.
# Skipping 9agm-0.png: Expected 4 parts, got 5.
# Skipping bzs716r-0.png: Expected 7 parts, got 10.
# Skipping 21zvg6u-0.png: Expected 7 parts, got 6.
# Skipping uje2qi73-0.png: Expected 8 parts, got 11.
# Skipping g4skf9-0.png: Expected 6 parts, got 4.
# Skipping dkbv9bm1-0.png: Expected 8 parts, got 14.
# Skipping ma78yz-0.png: Expected 6 parts, got 7.
# Skipping 0umrcy-0.png: Expected 6 parts, got 11.
# Skipping vbxzwgh-0.png: Expected 7 parts, got 6.
# Skipping ttzw4bw-0.png: Expected 7 parts, got 5.
# Skipping lyjy-0.png: Expected 4 parts, got 2.
# Skipping mjh78bc-0.png: Expected 7 parts, got 8.
# Skipping am45-0.png: Expected 4 parts, got 9.
# Skipping uhtls-0.png: Expected 5 parts, got 6.
# Skipping t9jfbddu-0.png: Expected 8 parts, got 9.
# Skipping lphl360-0.png: Expected 7 parts, got 6.
# Skipping 5yiwz-0.png: Expected 5 parts, got 7.
# Skipping les8-0.png: Expected 4 parts, got 0.
# Skipping 2bd9wa3-0.png: Expected 7 parts, got 2.
# Skipping dfvrep-0.png: Expected 6 parts, got 5.
# Skipping s40m-0.png: Expected 4 parts, got 5.
# Skipping i4pi8h-0.png: Expected 6 parts, got 7.
# Skipping sltmu3i-0.png: Expected 7 parts, got 6.
# Skipping f85pu-0.png: Expected 5 parts, got 8.
# Skipping 6gzxrr-0.png: Expected 6 parts, got 5.
# Skipping y47br5d3-0.png: Expected 8 parts, got 2.
# Skipping 3cnr4p9-0.png: Expected 7 parts, got 10.
# Skipping pm9yyl8-0.png: Expected 7 parts, got 1.
# Skipping vpqb1za-0.png: Expected 7 parts, got 17.
# Skipping hwxmjb-0.png: Expected 6 parts, got 5.
# Skipping wvim9f3-0.png: Expected 7 parts, got 10.
# Skipping rugb4q3m-0.png: Expected 8 parts, got 10.
# Skipping qgaz-0.png: Expected 4 parts, got 3.
# Skipping gvra3-0.png: Expected 5 parts, got 7.
# Skipping jigp-0.png: Expected 4 parts, got 1.
# Skipping ue3pp9h-0.png: Expected 7 parts, got 4.
# Skipping ze4p5c14-0.png: Expected 8 parts, got 7.
# Skipping ugfwgd-0.png: Expected 6 parts, got 7.
# Skipping cxl8dhh6-0.png: Expected 8 parts, got 9.
# Skipping 6ks0nbja-0.png: Expected 8 parts, got 10.
# Skipping hbw1t2fs-0.png: Expected 8 parts, got 6.
# Skipping 06yx8nkv-0.png: Expected 8 parts, got 7.
# Skipping 2e6i-0.png: Expected 4 parts, got 3.
# Skipping r9ec79xv-0.png: Expected 8 parts, got 5.
# Skipping 1fuhmmn-0.png: Expected 7 parts, got 6.
# Skipping mq8qnw-0.png: Expected 6 parts, got 5.
# Skipping 1gqe-0.png: Expected 4 parts, got 2.
# Skipping ztlig-0.png: Expected 5 parts, got 4.
# Skipping nljkrn0-0.png: Expected 7 parts, got 21.
# Skipping 4jjv-0.png: Expected 4 parts, got 1.
# Skipping co9nerl-0.png: Expected 7 parts, got 6.
# Skipping lhul7j-0.png: Expected 6 parts, got 8.
# Skipping v4xia2-0.png: Expected 6 parts, got 11.
# Skipping 8shgmq-0.png: Expected 6 parts, got 5.
# Skipping dixa-0.png: Expected 4 parts, got 3.
# Skipping 4nx86y-0.png: Expected 6 parts, got 7.
# Skipping 38sh-0.png: Expected 4 parts, got 3.
# Skipping ieqhcc-0.png: Expected 6 parts, got 0.
# Skipping gk33rm-0.png: Expected 6 parts, got 3.
# Skipping y3df0f79-0.png: Expected 8 parts, got 7.
# Skipping jz1of2-0.png: Expected 6 parts, got 13.
# Skipping k5e8alz-0.png: Expected 7 parts, got 8.
# Skipping w3aezn-0.png: Expected 6 parts, got 8.
# Skipping grjdtf11-0.png: Expected 8 parts, got 12.
# Skipping rsfdztk5-0.png: Expected 8 parts, got 9.
# Skipping sn6xou-0.png: Expected 6 parts, got 3.
# Skipping xjgk68-0.png: Expected 6 parts, got 4.
# Skipping wmzd1q-0.png: Expected 6 parts, got 11.
# Skipping 8zdzgsf3-0.png: Expected 8 parts, got 7.
# Skipping ky94up-0.png: Expected 6 parts, got 2.
# Skipping 1zh3-0.png: Expected 4 parts, got 5.
# Skipping iy59f27-0.png: Expected 7 parts, got 10.
# Skipping 3wrs2p-0.png: Expected 6 parts, got 5.
# Skipping 9ljr9-0.png: Expected 5 parts, got 11.
# Skipping 369b4-0.png: Expected 5 parts, got 2.
# Skipping gzjtii-0.png: Expected 6 parts, got 3.
# Skipping hd6za8-0.png: Expected 6 parts, got 7.
# Skipping ilo0y-0.png: Expected 5 parts, got 6.
# Skipping ysqhhiqa-0.png: Expected 8 parts, got 0.
# Skipping 5uafo-0.png: Expected 5 parts, got 4.
# Skipping uaqmlp-0.png: Expected 6 parts, got 5.
# Skipping dxlqowh-0.png: Expected 7 parts, got 11.
# Skipping u5rx8w4-0.png: Expected 7 parts, got 6.
# Skipping 9aeol3h-0.png: Expected 7 parts, got 16.
# Skipping ogrnx-0.png: Expected 5 parts, got 1.
# Skipping 5onol-0.png: Expected 5 parts, got 4.
# Skipping ostkosqw-0.png: Expected 8 parts, got 14.
# Skipping m7gxu6u-0.png: Expected 7 parts, got 8.
# Skipping 0fm4a3rx-0.png: Expected 8 parts, got 14.
# Skipping gevq89j1-0.png: Expected 8 parts, got 24.
# Skipping oqtqd59-0.png: Expected 7 parts, got 4.
# Skipping pcmrn8e-0.png: Expected 7 parts, got 12.
# Skipping qvtxb1-0.png: Expected 6 parts, got 8.
# Skipping xnrr-0.png: Expected 4 parts, got 3.
# Skipping wexb1h4r-0.png: Expected 8 parts, got 10.
# Skipping vmszgrh5-0.png: Expected 8 parts, got 7.
# Skipping qru5nm-0.png: Expected 6 parts, got 15.
# Skipping y33e0ck-0.png: Expected 7 parts, got 4.
# Skipping efnkypn5-0.png: Expected 8 parts, got 9.
# Skipping vpv9-0.png: Expected 4 parts, got 3.
# Skipping bc8eexe-0.png: Expected 7 parts, got 9.
# Skipping wmx8-0.png: Expected 4 parts, got 2.
# Skipping v6ktn5x-0.png: Expected 7 parts, got 9.
# Skipping y9om70-0.png: Expected 6 parts, got 3.
# Skipping qunj-0.png: Expected 4 parts, got 7.
# Skipping 2pc9-0.png: Expected 4 parts, got 5.
# Skipping 0ykbzgvb-0.png: Expected 8 parts, got 12.
# Skipping fge7x28-0.png: Expected 7 parts, got 5.
# Skipping 7094tgmo-0.png: Expected 8 parts, got 4.
# Skipping 7fnlfb4t-0.png: Expected 8 parts, got 7.
# Skipping zael6-0.png: Expected 5 parts, got 6.
# Skipping ao69ag5-0.png: Expected 7 parts, got 8.
# Skipping zhpy-0.png: Expected 4 parts, got 7.
# Skipping dbz24514-0.png: Expected 8 parts, got 7.
# Skipping ckp24c3b-0.png: Expected 8 parts, got 1.
# Skipping 7pzrx0ct-0.png: Expected 8 parts, got 7.
# Skipping ezqs43ph-0.png: Expected 8 parts, got 7.
# Skipping auijw0-0.png: Expected 6 parts, got 2.
# Skipping 94w29l95-0.png: Expected 8 parts, got 7.
# Skipping 4rvj-0.png: Expected 4 parts, got 1.
# Skipping abligtsu-0.png: Expected 8 parts, got 3.
# Skipping ww80ktq3-0.png: Expected 8 parts, got 5.
# Skipping lasubcf-0.png: Expected 7 parts, got 6.
# Skipping 1w572r-0.png: Expected 6 parts, got 5.
# Skipping qwsdmlxu-0.png: Expected 8 parts, got 7.
# Skipping o0feac94-0.png: Expected 8 parts, got 9.
# Skipping 37fhsm2-0.png: Expected 7 parts, got 11.
# Skipping 666o5ez0-0.png: Expected 8 parts, got 7.
# Skipping zke6m379-0.png: Expected 8 parts, got 9.
# Skipping x2fmm8j-0.png: Expected 7 parts, got 8.
# Skipping 60j6f-0.png: Expected 5 parts, got 2.
# Skipping sww2-0.png: Expected 4 parts, got 5.
# Skipping jpe8-0.png: Expected 4 parts, got 3.
# Skipping gqy9e-0.png: Expected 5 parts, got 3.
# Skipping hihs-0.png: Expected 4 parts, got 0.
# Skipping i8cc6-0.png: Expected 5 parts, got 4.
# Skipping 6q84ibe-0.png: Expected 7 parts, got 6.
# Skipping ay5a-0.png: Expected 4 parts, got 5.
# Skipping ow1uitv-0.png: Expected 7 parts, got 6.
# Skipping gz8x-0.png: Expected 4 parts, got 3.
# Skipping iawa6qei-0.png: Expected 8 parts, got 9.
# Skipping 1su4ar-0.png: Expected 6 parts, got 5.
# Skipping qphgsi-0.png: Expected 6 parts, got 11.
# Skipping 5poop-0.png: Expected 5 parts, got 4.
# Skipping 2urroi-0.png: Expected 6 parts, got 8.
# Skipping 9abwl0a-0.png: Expected 7 parts, got 5.
# Skipping e69dz4z-0.png: Expected 7 parts, got 8.
# Skipping 7hyn7eq-0.png: Expected 7 parts, got 13.
# Skipping 3spzvbk-0.png: Expected 7 parts, got 5.
# Skipping 5dq1c-0.png: Expected 5 parts, got 4.
# Skipping z2nsf2-0.png: Expected 6 parts, got 9.
# Skipping xjj1a-0.png: Expected 5 parts, got 3.
# Skipping s7wqfx5-0.png: Expected 7 parts, got 8.
# Skipping nccdj42-0.png: Expected 7 parts, got 6.
# Skipping 88ke95d-0.png: Expected 7 parts, got 8.
# Skipping za3i9-0.png: Expected 5 parts, got 6.
# Skipping 6sdnex1-0.png: Expected 7 parts, got 6.
# Skipping yo4y5o28-0.png: Expected 8 parts, got 14.
# Skipping l48fphev-0.png: Expected 8 parts, got 11.
# Skipping qybzy5g-0.png: Expected 7 parts, got 0.
# Skipping ribsz3wh-0.png: Expected 8 parts, got 7.
# Skipping 3n7opqn4-0.png: Expected 8 parts, got 17.
# Skipping u8lwt7-0.png: Expected 6 parts, got 10.
# Skipping si6ffqow-0.png: Expected 8 parts, got 7.
# Skipping dmurgvfm-0.png: Expected 8 parts, got 11.
# Skipping yfkx4v1-0.png: Expected 7 parts, got 6.
# Skipping qr2jeoq-0.png: Expected 7 parts, got 6.
# Skipping h97e2we-0.png: Expected 7 parts, got 6.
# Skipping hz3y-0.png: Expected 4 parts, got 1.
# Skipping 8ff3g25-0.png: Expected 7 parts, got 6.
# Skipping p4jdm22-0.png: Expected 7 parts, got 8.
# Skipping jy0bo5-0.png: Expected 6 parts, got 7.
# Skipping 3qi961-0.png: Expected 6 parts, got 5.
# Skipping q1nkm64t-0.png: Expected 8 parts, got 9.
# Skipping oy3tamb-0.png: Expected 7 parts, got 5.
# Skipping mzf7h89-0.png: Expected 7 parts, got 11.
# Skipping vti0kdl-0.png: Expected 7 parts, got 2.
# Skipping rm7xw9x9-0.png: Expected 8 parts, got 11.
# Skipping 010b-0.png: Expected 4 parts, got 7.
# Skipping 6toeeyqt-0.png: Expected 8 parts, got 6.
# Skipping 86il2ko-0.png: Expected 7 parts, got 6.
# Skipping 5e3iz5d5-0.png: Expected 8 parts, got 11.
# Skipping qtkwzp-0.png: Expected 6 parts, got 7.
# Skipping 854d4-0.png: Expected 5 parts, got 6.
# Skipping g7zqyv6-0.png: Expected 7 parts, got 8.
# Skipping i12ua77h-0.png: Expected 8 parts, got 11.
# Skipping f260-0.png: Expected 4 parts, got 5.
# Skipping ilrj-0.png: Expected 4 parts, got 2.
# Skipping rpsgjbyv-0.png: Expected 8 parts, got 11.
# Skipping dys8qz5r-0.png: Expected 8 parts, got 12.
# Skipping cl0s446-0.png: Expected 7 parts, got 0.
# Skipping xcgi0h-0.png: Expected 6 parts, got 5.
# Skipping 20tzku6e-0.png: Expected 8 parts, got 3.
# Skipping wvl2i6-0.png: Expected 6 parts, got 1.
# Skipping nf4e8m-0.png: Expected 6 parts, got 8.
# Skipping ayz3rk-0.png: Expected 6 parts, got 7.
# Skipping k62r-0.png: Expected 4 parts, got 0.
# Skipping 9tm4-0.png: Expected 4 parts, got 6.
# Skipping kntzog3u-0.png: Expected 8 parts, got 7.
# Skipping 3parb27i-0.png: Expected 8 parts, got 7.
# Skipping mf1a02-0.png: Expected 6 parts, got 4.
# Skipping 1dzo-0.png: Expected 4 parts, got 5.
# Skipping km969u-0.png: Expected 6 parts, got 0.
# Skipping 4scgi3rp-0.png: Expected 8 parts, got 17.
# Skipping sxkr-0.png: Expected 4 parts, got 3.
# Skipping dkxo-0.png: Expected 4 parts, got 2.
# Skipping d6vw-0.png: Expected 4 parts, got 1.
# Skipping 0mjig-0.png: Expected 5 parts, got 2.
# Skipping efcpy-0.png: Expected 5 parts, got 7.
# Skipping paxwvg-0.png: Expected 6 parts, got 11.
# Skipping 6rl2cm8-0.png: Expected 7 parts, got 8.
# Skipping 88iaqi-0.png: Expected 6 parts, got 8.
# Skipping 4vatp9k7-0.png: Expected 8 parts, got 4.
# Skipping htwa-0.png: Expected 4 parts, got 3.
# Skipping fwv6pb-0.png: Expected 6 parts, got 8.
# Skipping df99hi2-0.png: Expected 7 parts, got 10.
# Skipping y2bbp-0.png: Expected 5 parts, got 6.
# Skipping mkb7-0.png: Expected 4 parts, got 3.
# Skipping ou3nh4h-0.png: Expected 7 parts, got 4.
# Skipping upro-0.png: Expected 4 parts, got 5.
# Skipping c0axp6o-0.png: Expected 7 parts, got 16.
# Skipping g7m1-0.png: Expected 4 parts, got 7.
# Skipping 0mygmeg-0.png: Expected 7 parts, got 12.
# Skipping n0664-0.png: Expected 5 parts, got 3.
# Skipping f5ks8b44-0.png: Expected 8 parts, got 5.
# Skipping hvgqwz-0.png: Expected 6 parts, got 8.
# Skipping htyxx-0.png: Expected 5 parts, got 6.
# Skipping 48vwz-0.png: Expected 5 parts, got 6.
# Skipping tiim-0.png: Expected 4 parts, got 0.
# Skipping 5w2p2-0.png: Expected 5 parts, got 6.
# Skipping fwrbox-0.png: Expected 6 parts, got 5.
# Skipping g93jxkj-0.png: Expected 7 parts, got 8.
# Skipping dh1nyw09-0.png: Expected 8 parts, got 7.
# Skipping sfhep-0.png: Expected 5 parts, got 4.
# Skipping gkz37nn-0.png: Expected 7 parts, got 6.
# Skipping etizrd-0.png: Expected 6 parts, got 7.
# Skipping xhtn0gj-0.png: Expected 7 parts, got 6.
# Skipping 3tvbwkj-0.png: Expected 7 parts, got 5.
# Skipping 9edys4-0.png: Expected 6 parts, got 7.
# Skipping wb1apa1-0.png: Expected 7 parts, got 6.
# Skipping k4qb-0.png: Expected 4 parts, got 7.
# Skipping ihcir0z-0.png: Expected 7 parts, got 12.
# Skipping o3g186f-0.png: Expected 7 parts, got 6.
# Skipping r8im-0.png: Expected 4 parts, got 5.
# Skipping 5jcv-0.png: Expected 4 parts, got 7.
# Skipping 8ouita-0.png: Expected 6 parts, got 4.
# Skipping kw1hp2q-0.png: Expected 7 parts, got 0.
# Skipping bmtlc-0.png: Expected 5 parts, got 7.
# Skipping bulfkk-0.png: Expected 6 parts, got 4.
# Skipping mkwuh4-0.png: Expected 6 parts, got 9.
# Skipping py0kh-0.png: Expected 5 parts, got 4.
# Skipping 1b88c2-0.png: Expected 6 parts, got 8.
# Skipping l8jvyooi-0.png: Expected 8 parts, got 3.
# Skipping oh34j-0.png: Expected 5 parts, got 7.
# Skipping y6qxq2p-0.png: Expected 7 parts, got 5.
# Skipping a8eqi-0.png: Expected 5 parts, got 8.
# Skipping xcr6yg-0.png: Expected 6 parts, got 2.
# Skipping bm18g5d-0.png: Expected 7 parts, got 4.
# Skipping endgv7-0.png: Expected 6 parts, got 5.
# Skipping mitrx-0.png: Expected 5 parts, got 4.
# Skipping 1udt-0.png: Expected 4 parts, got 6.
# Skipping vauetjkk-0.png: Expected 8 parts, got 7.
# Skipping wagpa-0.png: Expected 5 parts, got 6.
# Skipping uct5592j-0.png: Expected 8 parts, got 6.
# Skipping scwj6qac-0.png: Expected 8 parts, got 11.
# Skipping uj1w3ww-0.png: Expected 7 parts, got 6.
# Skipping i3lamtg-0.png: Expected 7 parts, got 6.
# Skipping u1a1g-0.png: Expected 5 parts, got 4.
# Skipping jvtfzm0m-0.png: Expected 8 parts, got 5.
# Skipping kutzp7uh-0.png: Expected 8 parts, got 3.
# Skipping hhk7sx-0.png: Expected 6 parts, got 5.
# Skipping wsy867-0.png: Expected 6 parts, got 2.
# Skipping 08mse1o-0.png: Expected 7 parts, got 9.
# Skipping 115cip-0.png: Expected 6 parts, got 4.
# Skipping o7uyoadg-0.png: Expected 8 parts, got 7.
# Skipping lmz28qs-0.png: Expected 7 parts, got 8.
# Skipping s306ymq-0.png: Expected 7 parts, got 6.
# Skipping 5jae-0.png: Expected 4 parts, got 3.
# Skipping jeh265bm-0.png: Expected 8 parts, got 7.
# Skipping 06xg-0.png: Expected 4 parts, got 6.
# Skipping 2f48g-0.png: Expected 5 parts, got 3.
# Skipping awfmdz2-0.png: Expected 7 parts, got 13.
# Skipping ylby0t0a-0.png: Expected 8 parts, got 7.
# Skipping lfqfjrd-0.png: Expected 7 parts, got 0.
# Skipping p8sp-0.png: Expected 4 parts, got 2.
# Skipping 38ap-0.png: Expected 4 parts, got 5.
# Skipping 5vd4-0.png: Expected 4 parts, got 6.
# Skipping 8sq2w6z-0.png: Expected 7 parts, got 2.
# Skipping 6r3kp9-0.png: Expected 6 parts, got 7.
# Skipping r48sp-0.png: Expected 5 parts, got 2.
# Skipping o43h15z8-0.png: Expected 8 parts, got 5.
# Skipping hi1vi-0.png: Expected 5 parts, got 4.
# Skipping p4v8atio-0.png: Expected 8 parts, got 5.
# Skipping 77a0h0i-0.png: Expected 7 parts, got 8.
# Skipping 2fvmeb4-0.png: Expected 7 parts, got 8.
# Skipping 1becisn-0.png: Expected 7 parts, got 8.
# Skipping 0xfmd4-0.png: Expected 6 parts, got 8.
# Skipping wad3n3e-0.png: Expected 7 parts, got 4.
# Skipping c5cj-0.png: Expected 4 parts, got 1.
# Skipping 5u3y3t-0.png: Expected 6 parts, got 4.
# Skipping knq2uh2-0.png: Expected 7 parts, got 8.
# Skipping yf1skt-0.png: Expected 6 parts, got 5.
# Skipping 6ftv-0.png: Expected 4 parts, got 8.
# Skipping k2erja-0.png: Expected 6 parts, got 7.
# Skipping tjzw2-0.png: Expected 5 parts, got 4.
# Skipping kjt9-0.png: Expected 4 parts, got 5.
# Skipping 53axfl-0.png: Expected 6 parts, got 7.
# Skipping 0kl57-0.png: Expected 5 parts, got 3.
# Skipping i8jn-0.png: Expected 4 parts, got 3.
# Skipping afbed1u1-0.png: Expected 8 parts, got 9.
# Skipping lkjh3-0.png: Expected 5 parts, got 4.
# Skipping vcwgf-0.png: Expected 5 parts, got 4.
# Skipping lu9xlcb-0.png: Expected 7 parts, got 6.
# Skipping s7xtcj3-0.png: Expected 7 parts, got 8.
# Skipping 6soqfbku-0.png: Expected 8 parts, got 6.
# Skipping xomtqn2-0.png: Expected 7 parts, got 3.
# Skipping ohke-0.png: Expected 4 parts, got 5.
# Skipping 0imxqb2-0.png: Expected 7 parts, got 1.
# Skipping fxtix-0.png: Expected 5 parts, got 4.
# Skipping grz2t-0.png: Expected 5 parts, got 4.
# Skipping om9t6d-0.png: Expected 6 parts, got 7.
# Skipping q9k0po8-0.png: Expected 7 parts, got 6.
# Skipping johi-0.png: Expected 4 parts, got 5.
# Skipping houb-0.png: Expected 4 parts, got 3.
# Skipping 1vob8r-0.png: Expected 6 parts, got 8.
# Skipping gusva7nt-0.png: Expected 8 parts, got 19.
# Skipping ct9ucv-0.png: Expected 6 parts, got 10.
# Skipping yj8alup-0.png: Expected 7 parts, got 5.
# Skipping wsyakkt-0.png: Expected 7 parts, got 8.
# Skipping fiq8pl-0.png: Expected 6 parts, got 5.
# Skipping c9zphih-0.png: Expected 7 parts, got 6.
# Skipping ei9ms-0.png: Expected 5 parts, got 6.
# Skipping rripcy3d-0.png: Expected 8 parts, got 15.
# Skipping pqadfz-0.png: Expected 6 parts, got 5.
# Skipping truhx27-0.png: Expected 7 parts, got 4.
# Skipping atbuef-0.png: Expected 6 parts, got 2.
# Skipping xs4hgq-0.png: Expected 6 parts, got 7.
# Skipping tsr9iid-0.png: Expected 7 parts, got 5.
# Skipping ru72s-0.png: Expected 5 parts, got 6.
# Skipping bs4e-0.png: Expected 4 parts, got 2.
# Skipping 3um65ck5-0.png: Expected 8 parts, got 13.
# Skipping ggnw0us-0.png: Expected 7 parts, got 3.
# Skipping 5vgjp-0.png: Expected 5 parts, got 4.
# Skipping vrzow-0.png: Expected 5 parts, got 4.
# Skipping zj7qxhs-0.png: Expected 7 parts, got 6.
# Skipping 9a2xdo-0.png: Expected 6 parts, got 7.
# Skipping 1bjj6-0.png: Expected 5 parts, got 7.
# Skipping c8wfok00-0.png: Expected 8 parts, got 9.
# Skipping bazbx2-0.png: Expected 6 parts, got 8.
# Skipping 8qup-0.png: Expected 4 parts, got 3.
# Skipping 3qm2p1m-0.png: Expected 7 parts, got 6.
# Skipping 96gvsow-0.png: Expected 7 parts, got 6.
# Skipping 422g0b-0.png: Expected 6 parts, got 12.
# Skipping ytwd-0.png: Expected 4 parts, got 5.
# Skipping 3l7brc-0.png: Expected 6 parts, got 4.
# Skipping ojqva-0.png: Expected 5 parts, got 0.
# Skipping 057ea-0.png: Expected 5 parts, got 6.
# Skipping hy1l1pcv-0.png: Expected 8 parts, got 3.
# Skipping 7heenhd-0.png: Expected 7 parts, got 0.
# Skipping ojwru-0.png: Expected 5 parts, got 3.
# Skipping zkk6dy-0.png: Expected 6 parts, got 8.
# Skipping 92xyvp-0.png: Expected 6 parts, got 8.
# Skipping 2yi4hq-0.png: Expected 6 parts, got 8.
# Skipping pfx5-0.png: Expected 4 parts, got 6.
# Skipping nhig-0.png: Expected 4 parts, got 3.
# Skipping nqvhwngj-0.png: Expected 8 parts, got 5.
# Skipping ozgr-0.png: Expected 4 parts, got 2.
# Skipping 9173l-0.png: Expected 5 parts, got 4.
# Skipping wcuvl-0.png: Expected 5 parts, got 4.
# Skipping vund0i-0.png: Expected 6 parts, got 9.
# Skipping hddhmm-0.png: Expected 6 parts, got 8.
# Skipping 08xj75-0.png: Expected 6 parts, got 7.
# Skipping pqwvj76-0.png: Expected 7 parts, got 6.
# Skipping tqp3gxkv-0.png: Expected 8 parts, got 12.
# Skipping 7qr4opg-0.png: Expected 7 parts, got 5.
# Skipping 93hssl-0.png: Expected 6 parts, got 7.
# Skipping s8fq-0.png: Expected 4 parts, got 3.
# Skipping nqgkbqy-0.png: Expected 7 parts, got 8.
# Skipping hcsnr6-0.png: Expected 6 parts, got 7.
# Skipping 7qip4-0.png: Expected 5 parts, got 6.
# Skipping te58y6-0.png: Expected 6 parts, got 7.
# Skipping 589bxgz-0.png: Expected 7 parts, got 8.
# Skipping ohnndm6a-0.png: Expected 8 parts, got 9.
# Skipping 1x0dmb6-0.png: Expected 7 parts, got 8.
# Skipping k3q5832h-0.png: Expected 8 parts, got 10.
# Skipping rfomrn-0.png: Expected 6 parts, got 7.
# Skipping m2fak3-0.png: Expected 6 parts, got 7.
# Skipping wk5eatvs-0.png: Expected 8 parts, got 11.
# Skipping 6wdcs-0.png: Expected 5 parts, got 6.
# Skipping gtxplr-0.png: Expected 6 parts, got 4.
# Skipping tswixy-0.png: Expected 6 parts, got 5.
# Skipping pj1svxla-0.png: Expected 8 parts, got 3.
# Skipping wgdi6-0.png: Expected 5 parts, got 12.
# Skipping 8u2yxjmu-0.png: Expected 8 parts, got 11.
# Skipping qic72um-0.png: Expected 7 parts, got 5.
# Skipping jx9n6ubl-0.png: Expected 8 parts, got 7.
# Skipping 1lib-0.png: Expected 4 parts, got 3.
# Skipping ptfmc0-0.png: Expected 6 parts, got 5.
# Skipping ut6vavy-0.png: Expected 7 parts, got 6.
# Skipping 4ft9k7qn-0.png: Expected 8 parts, got 0.
# Skipping wiv1fq-0.png: Expected 6 parts, got 10.
# Skipping kb4sk1f-0.png: Expected 7 parts, got 5.
# Skipping siefa4-0.png: Expected 6 parts, got 8.
# Skipping v8li-0.png: Expected 4 parts, got 3.
# Skipping um32i8t-0.png: Expected 7 parts, got 2.
# Skipping nen67r-0.png: Expected 6 parts, got 5.
# Skipping snw9-0.png: Expected 4 parts, got 3.
# Skipping 21n98a3-0.png: Expected 7 parts, got 9.
# Skipping 4zwzcs8-0.png: Expected 7 parts, got 8.
# Skipping vverai6p-0.png: Expected 8 parts, got 7.
# Skipping hbb7n5-0.png: Expected 6 parts, got 7.
# Skipping 0bcjvo4p-0.png: Expected 8 parts, got 10.
# Skipping shwx-0.png: Expected 4 parts, got 5.
# Skipping hs5kr5-0.png: Expected 6 parts, got 8.
# Skipping 59nl1yr5-0.png: Expected 8 parts, got 6.
# Skipping onre-0.png: Expected 4 parts, got 3.
# Skipping 6qil8wt-0.png: Expected 7 parts, got 8.
# Skipping elp8-0.png: Expected 4 parts, got 3.
# Skipping key9p4-0.png: Expected 6 parts, got 10.
# Skipping 1yyo-0.png: Expected 4 parts, got 6.
# Skipping 80v0-0.png: Expected 4 parts, got 3.
# Skipping axmv78k-0.png: Expected 7 parts, got 13.
# Skipping ajw67-0.png: Expected 5 parts, got 4.
# Skipping efc2o9ch-0.png: Expected 8 parts, got 9.
# Skipping 34aiclk-0.png: Expected 7 parts, got 10.
# Skipping vlwit1ft-0.png: Expected 8 parts, got 7.
# Skipping 6vnazff-0.png: Expected 7 parts, got 4.
# Skipping 6ocl0d1-0.png: Expected 7 parts, got 6.
# Skipping 8ce92-0.png: Expected 5 parts, got 7.
# Skipping nmued43-0.png: Expected 7 parts, got 5.
# Skipping z1elw-0.png: Expected 5 parts, got 0.
# Skipping cbk0lufx-0.png: Expected 8 parts, got 3.
# Skipping mjcvm04v-0.png: Expected 8 parts, got 10.
# Skipping t6bi-0.png: Expected 4 parts, got 3.
# Skipping wnef2p-0.png: Expected 6 parts, got 7.
# Skipping 9w06x-0.png: Expected 5 parts, got 11.
# Skipping vipst6u8-0.png: Expected 8 parts, got 6.
# Skipping 6nabq-0.png: Expected 5 parts, got 4.
# Skipping mo1bf-0.png: Expected 5 parts, got 7.
# Skipping 76sp8v-0.png: Expected 6 parts, got 9.
# Skipping pqr7-0.png: Expected 4 parts, got 3.
# Skipping bmz614y7-0.png: Expected 8 parts, got 7.
# Skipping jxv1-0.png: Expected 4 parts, got 3.
# Skipping tq670mv5-0.png: Expected 8 parts, got 9.
# Skipping e8rnuz-0.png: Expected 6 parts, got 5.
# Skipping ao5gk-0.png: Expected 5 parts, got 6.
# Skipping bh6diykw-0.png: Expected 8 parts, got 7.
# Skipping maf6639-0.png: Expected 7 parts, got 10.
# Skipping db1htemj-0.png: Expected 8 parts, got 13.
# Skipping gobjzwo-0.png: Expected 7 parts, got 6.
# Skipping pebs8msl-0.png: Expected 8 parts, got 6.
# Skipping hwagcn-0.png: Expected 6 parts, got 5.
# Skipping qawvz-0.png: Expected 5 parts, got 6.
# Skipping 6li3fynq-0.png: Expected 8 parts, got 7.
# Skipping 50vhxk-0.png: Expected 6 parts, got 19.
# Skipping vtw6ql-0.png: Expected 6 parts, got 7.
# Skipping ugfl4192-0.png: Expected 8 parts, got 6.
# Skipping wz20rqfv-0.png: Expected 8 parts, got 9.
# Skipping sovo-0.png: Expected 4 parts, got 6.
# Skipping lxmnbuk-0.png: Expected 7 parts, got 6.
# Skipping 2uknf1-0.png: Expected 6 parts, got 0.
# Skipping ickhdz5p-0.png: Expected 8 parts, got 5.
# Skipping uu84n43-0.png: Expected 7 parts, got 8.
# Skipping ctumzv55-0.png: Expected 8 parts, got 9.
# Skipping uanva92-0.png: Expected 7 parts, got 8.
# Skipping 4tu9fi2-0.png: Expected 7 parts, got 4.
# Skipping ihdo-0.png: Expected 4 parts, got 10.
# Skipping euovy1t-0.png: Expected 7 parts, got 6.
# Skipping 4wy55-0.png: Expected 5 parts, got 4.
# Skipping 2zimhl0-0.png: Expected 7 parts, got 10.
# Skipping oo5vtop-0.png: Expected 7 parts, got 8.
# Skipping mk7t1nl4-0.png: Expected 8 parts, got 5.
# Skipping rnfyi-0.png: Expected 5 parts, got 9.
# Skipping cb7pekr-0.png: Expected 7 parts, got 10.
# Skipping 9otpv3f-0.png: Expected 7 parts, got 5.
# Skipping ukzbg-0.png: Expected 5 parts, got 4.
# Skipping kyiyz-0.png: Expected 5 parts, got 8.
# Skipping 06w6m8y-0.png: Expected 7 parts, got 8.
# Skipping 7c9819-0.png: Expected 6 parts, got 11.
# Skipping tidnbz6-0.png: Expected 7 parts, got 8.
# Skipping yaxwtssg-0.png: Expected 8 parts, got 0.
# Skipping dq3by0v-0.png: Expected 7 parts, got 8.
# Skipping 7tz8-0.png: Expected 4 parts, got 3.
# Skipping lwb4u4f-0.png: Expected 7 parts, got 13.
# Skipping e11xcxtx-0.png: Expected 8 parts, got 5.
# Skipping mh4fjm-0.png: Expected 6 parts, got 5.
# Skipping 5ait-0.png: Expected 4 parts, got 3.
# Skipping 0hox6-0.png: Expected 5 parts, got 3.
# Skipping ed57g-0.png: Expected 5 parts, got 4.
# Skipping 5ifb3-0.png: Expected 5 parts, got 0.
# Skipping fw9k8ue6-0.png: Expected 8 parts, got 11.
# Skipping t45da-0.png: Expected 5 parts, got 4.
# Skipping 39em-0.png: Expected 4 parts, got 3.
# Skipping ua0c-0.png: Expected 4 parts, got 5.
# Skipping mx6ia-0.png: Expected 5 parts, got 2.
# Skipping 0v6ng2do-0.png: Expected 8 parts, got 7.
# Skipping l72bbvv4-0.png: Expected 8 parts, got 6.
# Skipping oaoowk1c-0.png: Expected 8 parts, got 12.
# Skipping ouoflqm8-0.png: Expected 8 parts, got 7.
# Skipping t4gj8p3-0.png: Expected 7 parts, got 8.
# Skipping akcs-0.png: Expected 4 parts, got 7.
# Skipping 1m4h-0.png: Expected 4 parts, got 3.
# Skipping izo40u-0.png: Expected 6 parts, got 9.
# Skipping 0iee8z9-0.png: Expected 7 parts, got 6.
# Skipping gvmi8p-0.png: Expected 6 parts, got 7.
# Skipping 4q433u82-0.png: Expected 8 parts, got 9.
# Skipping cccjvgm-0.png: Expected 7 parts, got 3.
# Skipping enzkgn-0.png: Expected 6 parts, got 5.
# Skipping 701n0f-0.png: Expected 6 parts, got 8.
# Skipping oh2fvz-0.png: Expected 6 parts, got 11.
# Skipping vu9gosqe-0.png: Expected 8 parts, got 7.
# Skipping 1vw0zvpw-0.png: Expected 8 parts, got 12.
# Skipping ohp6fuk4-0.png: Expected 8 parts, got 7.
# Skipping 1x2ti-0.png: Expected 5 parts, got 6.
# Skipping ruc5p-0.png: Expected 5 parts, got 1.
# Skipping anc4-0.png: Expected 4 parts, got 3.
# Skipping xv8p-0.png: Expected 4 parts, got 3.
# Skipping cu6ju3-0.png: Expected 6 parts, got 8.
# Skipping 3xh6-0.png: Expected 4 parts, got 5.
# Skipping 0v4n-0.png: Expected 4 parts, got 6.
# Skipping p9kut-0.png: Expected 5 parts, got 4.
# Skipping 34og7pyo-0.png: Expected 8 parts, got 11.
# Skipping w8likg-0.png: Expected 6 parts, got 3.
# Skipping xjnijun1-0.png: Expected 8 parts, got 7.
# Skipping nlbf56w-0.png: Expected 7 parts, got 8.
# Skipping hcck03w9-0.png: Expected 8 parts, got 7.
# Skipping ysd1x7xl-0.png: Expected 8 parts, got 6.
# Skipping f07h-0.png: Expected 4 parts, got 3.
# Skipping pvza-0.png: Expected 4 parts, got 5.
# Skipping 449ftp-0.png: Expected 6 parts, got 8.
# Skipping i9tep8-0.png: Expected 6 parts, got 7.
# Skipping bhwfu-0.png: Expected 5 parts, got 0.
# Skipping oxul2m-0.png: Expected 6 parts, got 0.
# Skipping 1u5bgi1-0.png: Expected 7 parts, got 6.
# Skipping a3mup-0.png: Expected 5 parts, got 4.
# Skipping fcs7t4f-0.png: Expected 7 parts, got 2.
# Skipping e470c-0.png: Expected 5 parts, got 2.
# Skipping nbsei-0.png: Expected 5 parts, got 4.
# Skipping gy7nps-0.png: Expected 6 parts, got 7.
# Skipping ks7as23l-0.png: Expected 8 parts, got 7.
# Skipping zqqi-0.png: Expected 4 parts, got 2.
# Skipping alnnvyuq-0.png: Expected 8 parts, got 10.
# Skipping 1hznv-0.png: Expected 5 parts, got 4.
# Skipping c7o42x-0.png: Expected 6 parts, got 7.
# Skipping ifs71-0.png: Expected 5 parts, got 3.
# Skipping 7ih0-0.png: Expected 4 parts, got 5.
# Skipping b6fd80x-0.png: Expected 7 parts, got 8.
# Skipping wg3pj3rn-0.png: Expected 8 parts, got 7.
# Skipping oqiqe4t-0.png: Expected 7 parts, got 6.
# Skipping 41ufgg-0.png: Expected 6 parts, got 16.
# Skipping j72fad6r-0.png: Expected 8 parts, got 9.
# Skipping 92bw-0.png: Expected 4 parts, got 3.
# Skipping 7rl3w0-0.png: Expected 6 parts, got 2.
# Skipping 1vbc15z-0.png: Expected 7 parts, got 4.
# Skipping z7gl-0.png: Expected 4 parts, got 6.
# Skipping yml9m-0.png: Expected 5 parts, got 4.
# Skipping borjd7j-0.png: Expected 7 parts, got 6.
# Skipping ksy8-0.png: Expected 4 parts, got 5.
# Skipping pz2q-0.png: Expected 4 parts, got 6.
# Skipping vydnm-0.png: Expected 5 parts, got 6.
# Skipping jocyop-0.png: Expected 6 parts, got 5.
# Skipping x296eg-0.png: Expected 6 parts, got 3.
# Skipping e5ycb-0.png: Expected 5 parts, got 4.
# Skipping h7j0-0.png: Expected 4 parts, got 3.
# Skipping fi03i01-0.png: Expected 7 parts, got 6.
# Skipping 0i7o-0.png: Expected 4 parts, got 6.
# Skipping kzsc56xl-0.png: Expected 8 parts, got 4.
# Skipping tm9kmer-0.png: Expected 7 parts, got 5.
# Skipping a1pmqmw-0.png: Expected 7 parts, got 6.
# Skipping 8cahjsap-0.png: Expected 8 parts, got 9.
# Skipping el118ka5-0.png: Expected 8 parts, got 7.
# Skipping rva7rn-0.png: Expected 6 parts, got 7.
# Skipping nx1pmgl-0.png: Expected 7 parts, got 6.
# Skipping j7nms07-0.png: Expected 7 parts, got 14.
# Skipping u7npos0c-0.png: Expected 8 parts, got 7.
# Skipping nhotstv-0.png: Expected 7 parts, got 6.
# Skipping h6t7wqs-0.png: Expected 7 parts, got 8.
# Skipping q4av-0.png: Expected 4 parts, got 3.
# Skipping nzttd-0.png: Expected 5 parts, got 4.
# Skipping 5ycx-0.png: Expected 4 parts, got 5.
# Skipping lv64wfq-0.png: Expected 7 parts, got 6.
# Skipping 6vwvgo6-0.png: Expected 7 parts, got 6.
# Skipping 3otukim-0.png: Expected 7 parts, got 6.
# Skipping m31nh-0.png: Expected 5 parts, got 6.
# Skipping yjshxc-0.png: Expected 6 parts, got 1.
# Skipping shg00zt-0.png: Expected 7 parts, got 6.
# Skipping f6nkvll-0.png: Expected 7 parts, got 12.
# Skipping m27yku-0.png: Expected 6 parts, got 10.
# Skipping 6829y4j-0.png: Expected 7 parts, got 11.
# Skipping 1s8ii3-0.png: Expected 6 parts, got 3.
# Skipping ibum-0.png: Expected 4 parts, got 3.
# Skipping 77jd-0.png: Expected 4 parts, got 5.
# Skipping 3zm7idy-0.png: Expected 7 parts, got 6.
# Skipping 7o8sa-0.png: Expected 5 parts, got 3.
# Skipping j3w44drh-0.png: Expected 8 parts, got 7.
# Skipping js6z1ddl-0.png: Expected 8 parts, got 7.
# Skipping 81x9da4a-0.png: Expected 8 parts, got 4.
# Skipping sar2j25a-0.png: Expected 8 parts, got 5.
# Skipping cni116j-0.png: Expected 7 parts, got 5.
# Skipping fl6h8ipq-0.png: Expected 8 parts, got 6.
# Skipping 7hqqs7-0.png: Expected 6 parts, got 9.
# Skipping tfvc-0.png: Expected 4 parts, got 3.
# Skipping bqxqj67-0.png: Expected 7 parts, got 5.
# Skipping lwtl-0.png: Expected 4 parts, got 9.
# Skipping 75hetxz-0.png: Expected 7 parts, got 5.
# Skipping ai87f-0.png: Expected 5 parts, got 7.
# Skipping a672-0.png: Expected 4 parts, got 5.
# Skipping 5f928u-0.png: Expected 6 parts, got 5.
# Skipping tuarq-0.png: Expected 5 parts, got 3.
# Skipping 00fh-0.png: Expected 4 parts, got 0.
# Skipping vueex1o4-0.png: Expected 8 parts, got 10.
# Skipping xbck6d-0.png: Expected 6 parts, got 7.
# Skipping tdiereaf-0.png: Expected 8 parts, got 6.
# Skipping clc5lmda-0.png: Expected 8 parts, got 6.
# Skipping amj2afk-0.png: Expected 7 parts, got 6.
# Skipping hp48uegi-0.png: Expected 8 parts, got 7.
# Skipping plelck-0.png: Expected 6 parts, got 4.
# Skipping h8izw79-0.png: Expected 7 parts, got 6.
# Skipping ciyrfilw-0.png: Expected 8 parts, got 9.
# Skipping f49cj0-0.png: Expected 6 parts, got 5.
# Skipping a9ymonr-0.png: Expected 7 parts, got 4.
# Skipping 7py6rx41-0.png: Expected 8 parts, got 5.
# Skipping nya7f5-0.png: Expected 6 parts, got 8.
# Skipping 31kz-0.png: Expected 4 parts, got 2.
# Skipping zaig9-0.png: Expected 5 parts, got 4.
# Skipping 0kxu0w-0.png: Expected 6 parts, got 1.
# Skipping yaqnusi5-0.png: Expected 8 parts, got 9.
# Skipping 75qb0jc9-0.png: Expected 8 parts, got 10.
# Skipping dhvtl1o-0.png: Expected 7 parts, got 8.
# Skipping mockky9e-0.png: Expected 8 parts, got 10.
# Skipping lim18csq-0.png: Expected 8 parts, got 9.
# Skipping krmz-0.png: Expected 4 parts, got 3.
# Skipping 0ihk7bk-0.png: Expected 7 parts, got 3.
# Skipping j40v-0.png: Expected 4 parts, got 6.
# Skipping r29d2-0.png: Expected 5 parts, got 6.
# Skipping 8q9r-0.png: Expected 4 parts, got 3.
# Skipping oyr2fs6-0.png: Expected 7 parts, got 8.
# Skipping e765w48d-0.png: Expected 8 parts, got 9.
# Skipping hgjwswrc-0.png: Expected 8 parts, got 7.
# Skipping sjbse48d-0.png: Expected 8 parts, got 6.
# Skipping vxhtnoi-0.png: Expected 7 parts, got 9.
# Skipping lae1mbyf-0.png: Expected 8 parts, got 5.
# Skipping tc7cx8-0.png: Expected 6 parts, got 5.
# Skipping lj2aw6u-0.png: Expected 7 parts, got 5.
# Skipping mauvs-0.png: Expected 5 parts, got 7.
# Skipping cs9a-0.png: Expected 4 parts, got 3.
# Skipping cn9t-0.png: Expected 4 parts, got 2.
# Skipping rgcr6h4v-0.png: Expected 8 parts, got 11.
# Skipping szfy-0.png: Expected 4 parts, got 2.
# Skipping ooyc6m9-0.png: Expected 7 parts, got 8.
# Skipping rq7c8-0.png: Expected 5 parts, got 4.
# Skipping rtds69-0.png: Expected 6 parts, got 7.
# Skipping c3sco-0.png: Expected 5 parts, got 3.
# Skipping ef6uszg-0.png: Expected 7 parts, got 11.
# Skipping ebuvib0-0.png: Expected 7 parts, got 5.
# Skipping nwew7s-0.png: Expected 6 parts, got 5.
# Skipping 8gr6z-0.png: Expected 5 parts, got 4.
# Skipping ndm51-0.png: Expected 5 parts, got 4.
# Skipping cchiy0a-0.png: Expected 7 parts, got 3.
# Skipping cwa10k7-0.png: Expected 7 parts, got 3.
# Skipping sgnj-0.png: Expected 4 parts, got 5.
# Skipping fpyrmh-0.png: Expected 6 parts, got 7.
# Skipping 4bkgh-0.png: Expected 5 parts, got 4.
# Skipping 0no6-0.png: Expected 4 parts, got 3.
# Skipping o2owk3z-0.png: Expected 7 parts, got 8.
# Skipping mjmkskl-0.png: Expected 7 parts, got 5.
# Skipping jzvf1-0.png: Expected 5 parts, got 4.
# Skipping ipzim1-0.png: Expected 6 parts, got 5.
# Skipping n8n4ol-0.png: Expected 6 parts, got 2.
# Skipping oxdb-0.png: Expected 4 parts, got 5.
# Skipping qkqv-0.png: Expected 4 parts, got 2.
# Skipping ubwtip-0.png: Expected 6 parts, got 2.
# Skipping k7e032c-0.png: Expected 7 parts, got 5.
# Skipping 447hq49-0.png: Expected 7 parts, got 4.
# Skipping bhral-0.png: Expected 5 parts, got 6.
# Skipping 0axhfa-0.png: Expected 6 parts, got 5.
# Skipping 2ogcaj-0.png: Expected 6 parts, got 9.
# Skipping orzpjyd0-0.png: Expected 8 parts, got 7.
# Skipping 1y13dk-0.png: Expected 6 parts, got 7.
# Skipping 82gu-0.png: Expected 4 parts, got 3.
# Skipping megjopf-0.png: Expected 7 parts, got 6.
# Skipping 3sksn-0.png: Expected 5 parts, got 3.
# Skipping pq3nng-0.png: Expected 6 parts, got 11.
# Skipping 25b4edqd-0.png: Expected 8 parts, got 7.
# Skipping e7ll4ytu-0.png: Expected 8 parts, got 9.
# Skipping u1x2-0.png: Expected 4 parts, got 10.
# Skipping 99mqhb-0.png: Expected 6 parts, got 3.
# Skipping pyk8ah-0.png: Expected 6 parts, got 5.
# Skipping hamyu-0.png: Expected 5 parts, got 8.
# Skipping d6f5y7-0.png: Expected 6 parts, got 1.
# Skipping hu3d0c-0.png: Expected 6 parts, got 7.
# Skipping h2z3yc-0.png: Expected 6 parts, got 9.
# Skipping stx1upye-0.png: Expected 8 parts, got 0.
# Skipping r63au5-0.png: Expected 6 parts, got 7.
# Skipping t1wxni-0.png: Expected 6 parts, got 5.
# Skipping b0qod-0.png: Expected 5 parts, got 4.
# Skipping al7qec9-0.png: Expected 7 parts, got 6.
# Skipping d5eci-0.png: Expected 5 parts, got 6.
# Skipping 6bynqp6-0.png: Expected 7 parts, got 5.
# Skipping dhwb79-0.png: Expected 6 parts, got 8.
# Skipping t7vtt4bn-0.png: Expected 8 parts, got 9.
# Skipping 77sbo-0.png: Expected 5 parts, got 10.
# Skipping tqch-0.png: Expected 4 parts, got 3.
# Skipping uneor2j2-0.png: Expected 8 parts, got 11.
# Skipping 1g3ro-0.png: Expected 5 parts, got 6.
# Skipping c5quk-0.png: Expected 5 parts, got 8.
# Skipping 7y0cynw-0.png: Expected 7 parts, got 6.
# Skipping gf6j-0.png: Expected 4 parts, got 5.
# Skipping 0hs60bw-0.png: Expected 7 parts, got 8.
# Skipping ipl47rlz-0.png: Expected 8 parts, got 6.
# Skipping q3io1xdp-0.png: Expected 8 parts, got 9.
# Skipping jutq59s6-0.png: Expected 8 parts, got 10.
# Skipping n0vq-0.png: Expected 4 parts, got 3.
# Skipping aqdlgv9-0.png: Expected 7 parts, got 6.
# Skipping dctp4-0.png: Expected 5 parts, got 6.
# Skipping 3yfc6jy-0.png: Expected 7 parts, got 1.
# Skipping rtphiefz-0.png: Expected 8 parts, got 5.
# Skipping wicsy-0.png: Expected 5 parts, got 6.
# Skipping mmprgvdi-0.png: Expected 8 parts, got 9.
# Skipping o9uthdb-0.png: Expected 7 parts, got 6.
# Skipping kzs7-0.png: Expected 4 parts, got 5.
# Skipping znv9k7-0.png: Expected 6 parts, got 4.
# Skipping c81p-0.png: Expected 4 parts, got 2.
# Skipping 4dmk7-0.png: Expected 5 parts, got 7.
# Skipping ouda1xx5-0.png: Expected 8 parts, got 7.
# Skipping lwvrpx-0.png: Expected 6 parts, got 7.
# Skipping xqzv9s11-0.png: Expected 8 parts, got 6.
# Skipping c4y1nmb9-0.png: Expected 8 parts, got 11.
# Skipping unmhvy3-0.png: Expected 7 parts, got 4.
# Skipping qzo99n7e-0.png: Expected 8 parts, got 12.
# Skipping 2qj98he-0.png: Expected 7 parts, got 12.
# Skipping 0dw9b7hd-0.png: Expected 8 parts, got 7.
# Skipping 9t29noq-0.png: Expected 7 parts, got 12.
# Skipping 440cq-0.png: Expected 5 parts, got 6.
# Skipping eg5rri6c-0.png: Expected 8 parts, got 7.
# Skipping iae52wx-0.png: Expected 7 parts, got 6.
# Skipping o8u33-0.png: Expected 5 parts, got 3.
# Skipping crpheoi-0.png: Expected 7 parts, got 5.
# Skipping 7p6te6h-0.png: Expected 7 parts, got 5.
# Skipping rytxwi7c-0.png: Expected 8 parts, got 5.
# Skipping g9lxn7-0.png: Expected 6 parts, got 5.
# Skipping nt0h-0.png: Expected 4 parts, got 5.
# Skipping nbr2qi-0.png: Expected 6 parts, got 7.
# Skipping lc5pcvlo-0.png: Expected 8 parts, got 16.
# Skipping pt0wspi-0.png: Expected 7 parts, got 8.
# Skipping 57p8ql2-0.png: Expected 7 parts, got 8.
# Skipping adhti9b-0.png: Expected 7 parts, got 8.
# Skipping ncukrvs-0.png: Expected 7 parts, got 6.
# Skipping ijsux-0.png: Expected 5 parts, got 4.
# Skipping de07r-0.png: Expected 5 parts, got 3.
# Skipping ffj6o-0.png: Expected 5 parts, got 4.
# Skipping fuf5nyca-0.png: Expected 8 parts, got 12.
# Skipping nva648p-0.png: Expected 7 parts, got 10.
# Skipping 0uijz-0.png: Expected 5 parts, got 6.
# Skipping 2aofi-0.png: Expected 5 parts, got 3.
# Skipping nke74-0.png: Expected 5 parts, got 6.
# Skipping trfjarm-0.png: Expected 7 parts, got 8.
# Skipping tjegr-0.png: Expected 5 parts, got 6.
# Skipping 7genwgh-0.png: Expected 7 parts, got 8.
# Skipping g92337-0.png: Expected 6 parts, got 4.
# Skipping reyheumd-0.png: Expected 8 parts, got 10.
# Skipping uzzy-0.png: Expected 4 parts, got 5.
# Skipping dt6vc9bj-0.png: Expected 8 parts, got 9.
# Skipping htd6-0.png: Expected 4 parts, got 3.
# Skipping fvlsb-0.png: Expected 5 parts, got 8.
# Skipping 5vd9-0.png: Expected 4 parts, got 2.
# Skipping j4bgpn-0.png: Expected 6 parts, got 3.
# Skipping bqx81ij-0.png: Expected 7 parts, got 6.
# Skipping cws8nr-0.png: Expected 6 parts, got 8.
# Skipping euw7rt-0.png: Expected 6 parts, got 3.
# Skipping clgrt-0.png: Expected 5 parts, got 4.
# Skipping dzamiuf-0.png: Expected 7 parts, got 6.
# Skipping u9hkbjog-0.png: Expected 8 parts, got 6.
# Skipping hw53-0.png: Expected 4 parts, got 5.
# Skipping 80a79g-0.png: Expected 6 parts, got 4.
# Skipping 52qoqji-0.png: Expected 7 parts, got 6.
# Skipping 1wpkup-0.png: Expected 6 parts, got 9.
# Skipping 9i3yk9-0.png: Expected 6 parts, got 7.
# Skipping 43u1voui-0.png: Expected 8 parts, got 5.
# Skipping fia6-0.png: Expected 4 parts, got 5.
# Skipping 7exis-0.png: Expected 5 parts, got 6.
# Skipping 3qi9bll-0.png: Expected 7 parts, got 3.
# Skipping 9bj5m0m-0.png: Expected 7 parts, got 6.
# Skipping qmxb0t-0.png: Expected 6 parts, got 2.
# Skipping 7zm7-0.png: Expected 4 parts, got 5.
# Skipping 09bki-0.png: Expected 5 parts, got 6.
# Skipping 9i3vx-0.png: Expected 5 parts, got 3.
# Skipping nthjkxv-0.png: Expected 7 parts, got 8.
# Skipping gip53-0.png: Expected 5 parts, got 1.
# Skipping hw0vz5j1-0.png: Expected 8 parts, got 12.
# Skipping tbjp74y-0.png: Expected 7 parts, got 5.
# Skipping a70ond9c-0.png: Expected 8 parts, got 5.
# Skipping n2di-0.png: Expected 4 parts, got 3.
# Skipping 7onsn-0.png: Expected 5 parts, got 3.
# Skipping ol28rdv6-0.png: Expected 8 parts, got 0.
# Skipping ffua-0.png: Expected 4 parts, got 3.
# Skipping pi6x-0.png: Expected 4 parts, got 3.
# Skipping 9g2c5k6-0.png: Expected 7 parts, got 6.
# Skipping s7ap7nc9-0.png: Expected 8 parts, got 10.
# Skipping ogx4mnx4-0.png: Expected 8 parts, got 7.
# Skipping kav80wfd-0.png: Expected 8 parts, got 9.
# Skipping n8w3ks1-0.png: Expected 7 parts, got 6.
# Skipping jzt2a5-0.png: Expected 6 parts, got 13.
# Skipping ojb96mm-0.png: Expected 7 parts, got 6.
# Skipping b0vupan-0.png: Expected 7 parts, got 0.
# Skipping ao7k-0.png: Expected 4 parts, got 7.
# Skipping 92q7-0.png: Expected 4 parts, got 1.
# Skipping fnl9-0.png: Expected 4 parts, got 2.
# Skipping ob32-0.png: Expected 4 parts, got 6.
# Skipping wspv3d-0.png: Expected 6 parts, got 8.
# Skipping o25xvm-0.png: Expected 6 parts, got 7.
# Skipping jlcq-0.png: Expected 4 parts, got 5.
# Skipping 8663ssg-0.png: Expected 7 parts, got 4.
# Skipping zjcal-0.png: Expected 5 parts, got 4.
# Skipping zfcem-0.png: Expected 5 parts, got 9.
# Skipping kqrpa-0.png: Expected 5 parts, got 6.
# Skipping o9k9tv-0.png: Expected 6 parts, got 4.
# Skipping zeh6cgv-0.png: Expected 7 parts, got 8.
# Skipping 2hr9d9-0.png: Expected 6 parts, got 9.
# Skipping l5ape5g-0.png: Expected 7 parts, got 13.
# Skipping rapb-0.png: Expected 4 parts, got 1.
# Skipping 52tqpn0e-0.png: Expected 8 parts, got 11.
# Skipping rf72xa-0.png: Expected 6 parts, got 3.
# Skipping 5treqnua-0.png: Expected 8 parts, got 7.
# Skipping y0qo-0.png: Expected 4 parts, got 0.
# Skipping 6erqxw2-0.png: Expected 7 parts, got 9.
# Skipping 5qxdu-0.png: Expected 5 parts, got 4.
# Skipping lf63g-0.png: Expected 5 parts, got 0.
# Skipping w84icrg6-0.png: Expected 8 parts, got 7.
# Skipping b8ceaq6-0.png: Expected 7 parts, got 6.
# Skipping yq85o-0.png: Expected 5 parts, got 4.
# Skipping qax34c8d-0.png: Expected 8 parts, got 9.
# Skipping 3ts5-0.png: Expected 4 parts, got 3.
# Skipping qbf9k-0.png: Expected 5 parts, got 4.
# Skipping fmghg7-0.png: Expected 6 parts, got 5.
# Skipping vznffj3f-0.png: Expected 8 parts, got 9.
# Skipping g9jyi-0.png: Expected 5 parts, got 6.
# Skipping cmpmk8r7-0.png: Expected 8 parts, got 13.
# Skipping jvmdfqbp-0.png: Expected 8 parts, got 7.
# Skipping 4bbd15-0.png: Expected 6 parts, got 7.
# Skipping 9cubvzql-0.png: Expected 8 parts, got 17.
# Skipping pqw4akqd-0.png: Expected 8 parts, got 9.
# Skipping ywrljt-0.png: Expected 6 parts, got 5.
# Skipping 356ccu-0.png: Expected 6 parts, got 9.
# Skipping xoi1-0.png: Expected 4 parts, got 5.
# Skipping vvvc2lx-0.png: Expected 7 parts, got 5.
# Skipping lbpm-0.png: Expected 4 parts, got 0.
# Skipping y74bsx-0.png: Expected 6 parts, got 5.
# Skipping mauq-0.png: Expected 4 parts, got 0.
# Skipping mupzvuqx-0.png: Expected 8 parts, got 9.
# Skipping m8lit3g3-0.png: Expected 8 parts, got 5.
# Skipping 10sj-0.png: Expected 4 parts, got 3.
# Skipping y8cc-0.png: Expected 4 parts, got 3.
# Skipping 6xrf-0.png: Expected 4 parts, got 3.
# Skipping 8kghth-0.png: Expected 6 parts, got 7.
# Skipping g58ect-0.png: Expected 6 parts, got 5.
# Skipping 42o75-0.png: Expected 5 parts, got 8.
# Skipping srumau-0.png: Expected 6 parts, got 7.
# Skipping 5g243-0.png: Expected 5 parts, got 4.
# Skipping 7nxwy-0.png: Expected 5 parts, got 2.
# Skipping wkiiqi4n-0.png: Expected 8 parts, got 5.
# Skipping 53o8o2-0.png: Expected 6 parts, got 5.
# Skipping 1b30y-0.png: Expected 5 parts, got 4.
# Skipping yqeg-0.png: Expected 4 parts, got 7.
# Skipping oy6rm-0.png: Expected 5 parts, got 6.
# Skipping pnyiab8j-0.png: Expected 8 parts, got 9.
# Skipping 1jgt-0.png: Expected 4 parts, got 1.
# Skipping i515bt-0.png: Expected 6 parts, got 5.
# Skipping eido-0.png: Expected 4 parts, got 5.
# Skipping aj57sgg-0.png: Expected 7 parts, got 9.
# Skipping cur2rqt-0.png: Expected 7 parts, got 1.
# Skipping zqi7ffi-0.png: Expected 7 parts, got 8.
# Skipping 441bz-0.png: Expected 5 parts, got 7.
# Skipping z8od6bk3-0.png: Expected 8 parts, got 11.
# Skipping rkudk5p-0.png: Expected 7 parts, got 3.
# Skipping 0jl4-0.png: Expected 4 parts, got 3.
# Skipping y31w-0.png: Expected 4 parts, got 7.
# Skipping 4i58-0.png: Expected 4 parts, got 6.
# Skipping ade9tbi9-0.png: Expected 8 parts, got 7.
# Skipping meb7r3yh-0.png: Expected 8 parts, got 7.
# Skipping nywafr-0.png: Expected 6 parts, got 4.
# Skipping 80qxfez1-0.png: Expected 8 parts, got 7.
# Skipping 0d0vp1-0.png: Expected 6 parts, got 5.
# Skipping j1as7r-0.png: Expected 6 parts, got 3.
# Skipping ai0wt-0.png: Expected 5 parts, got 2.
# Skipping 2kl2-0.png: Expected 4 parts, got 3.
# ...
# Skipping w53w-0.png: Expected 4 parts, got 5.
# Skipping e2nv3y-0.png: Expected 6 parts, got 7.
# Skipping y0cq-0.png: Expected 4 parts, got 2.
# Skipping nn01d-0.png: Expected 5 parts, got 3.
# Skipping jrrr-0.png: Expected 4 parts, got 3.
# Skipping 2uba9hkt-0.png: Expected 8 parts, got 6.
# Skipping legnz0ed-0.png: Expected 8 parts, got 0.
# Skipping n4lfm4-0.png: Expected 6 parts, got 7.
# Skipping 9e3j1oj-0.png: Expected 7 parts, got 4.
# Skipping j4uk1hha-0.png: Expected 8 parts, got 10.
# Skipping rioon8n-0.png: Expected 7 parts, got 6.
# Skipping z5kg-0.png: Expected 4 parts, got 3.
# Skipping abk180z-0.png: Expected 7 parts, got 11.
# Skipping kx3a-0.png: Expected 4 parts, got 3.
# Skipping t73j19vi-0.png: Expected 8 parts, got 7.
# Skipping e3aguc4-0.png: Expected 7 parts, got 12.
# Skipping 71pk-0.png: Expected 4 parts, got 5.
# Skipping 5ie69wtf-0.png: Expected 8 parts, got 7.
# Skipping fsstrk-0.png: Expected 6 parts, got 5.
# Skipping k7wak-0.png: Expected 5 parts, got 6.
# Skipping ga3x9qf4-0.png: Expected 8 parts, got 11.
# Skipping 0tmvvyfp-0.png: Expected 8 parts, got 7.
# Skipping cpuwhul-0.png: Expected 7 parts, got 11.
# Skipping emggqtz-0.png: Expected 7 parts, got 14.
# Skipping u9c4j-0.png: Expected 5 parts, got 6.
# Skipping 4pa6-0.png: Expected 4 parts, got 5.
# Skipping bz0l1a19-0.png: Expected 8 parts, got 6.
# Skipping s8xp0uq-0.png: Expected 7 parts, got 5.
# Skipping 480c-0.png: Expected 4 parts, got 3.
# Skipping 74r1c319-0.png: Expected 8 parts, got 9.
# Skipping k6ewkg-0.png: Expected 6 parts, got 7.
# Skipping 9vmzjqlt-0.png: Expected 8 parts, got 12.
# Skipping ldwubndg-0.png: Expected 8 parts, got 7.
# Skipping mhobc8t-0.png: Expected 7 parts, got 6.
# Skipping ts4cw-0.png: Expected 5 parts, got 6.
# Skipping z35a3z2-0.png: Expected 7 parts, got 6.
# Skipping nq56i-0.png: Expected 5 parts, got 4.
# Skipping d2lc-0.png: Expected 4 parts, got 5.
# Skipping u5v4xaxl-0.png: Expected 8 parts, got 7.
# Skipping 65cywmk1-0.png: Expected 8 parts, got 9.
# Skipping fl3a1c-0.png: Expected 6 parts, got 5.
# Skipping jqtiry-0.png: Expected 6 parts, got 13.
# Skipping tqioef-0.png: Expected 6 parts, got 1.
# Skipping dba526yt-0.png: Expected 8 parts, got 9.
# Skipping qv5fkrv-0.png: Expected 7 parts, got 8.
# Skipping cr9v-0.png: Expected 4 parts, got 3.
# Skipping 7twrv-0.png: Expected 5 parts, got 3.
# Skipping qxuo-0.png: Expected 4 parts, got 5.
# Skipping ai12-0.png: Expected 4 parts, got 2.
# Skipping 7urzpkn-0.png: Expected 7 parts, got 6.
# Skipping v5fng1sj-0.png: Expected 8 parts, got 9.
# Skipping mfynzg-0.png: Expected 6 parts, got 7.
# Skipping rsk019k4-0.png: Expected 8 parts, got 7.
# Skipping we3ex-0(1).png: Expected 5 parts, got 7.
# Skipping bmxj3cd-0.png: Expected 7 parts, got 10.
# Skipping b76ojrh-0.png: Expected 7 parts, got 8.
# Skipping 3kyutzk-0.png: Expected 7 parts, got 8.
# Skipping ty56x-0.png: Expected 5 parts, got 6.
# Skipping xr8b2-0.png: Expected 5 parts, got 7.
# Skipping oc42gn64-0.png: Expected 8 parts, got 11.
# Skipping 9edktm-0.png: Expected 6 parts, got 5.
# Skipping qygn-0.png: Expected 4 parts, got 5.
# Skipping 8x8k3-0.png: Expected 5 parts, got 11.
# Skipping ntjnuoi-0.png: Expected 7 parts, got 3.
# Skipping xp1jmtc-0.png: Expected 7 parts, got 6.
# Skipping f24o-0.png: Expected 4 parts, got 2.
# Skipping 3xf2-0.png: Expected 4 parts, got 3.
# Skipping s1he2-0.png: Expected 5 parts, got 3.
# Skipping 3qru0m-0.png: Expected 6 parts, got 11.
# Skipping pooqawbn-0.png: Expected 8 parts, got 7.
# Skipping 9u6f46c-0.png: Expected 7 parts, got 15.
# Skipping 2fgthyo9-0.png: Expected 8 parts, got 6.
# Skipping zrkni-0.png: Expected 5 parts, got 6.
# Skipping fhxcckp-0.png: Expected 7 parts, got 9.
# Skipping 1dpd7v-0.png: Expected 6 parts, got 7.
# Skipping 444z9exx-0.png: Expected 8 parts, got 7.
# Skipping rlwm5gas-0.png: Expected 8 parts, got 11.
# Skipping 9z4p-0.png: Expected 4 parts, got 2.
# Skipping iqmsp0-0.png: Expected 6 parts, got 5.
# Skipping n6z1-0.png: Expected 4 parts, got 5.
# Skipping laynfv-0.png: Expected 6 parts, got 7.
# Skipping 9vd77ol2-0.png: Expected 8 parts, got 2.
# Skipping 3ns6o1dj-0.png: Expected 8 parts, got 7.
# Skipping fp3awbi-0.png: Expected 7 parts, got 8.
# Skipping z2cah9-0.png: Expected 6 parts, got 4.
# Skipping uah0-0.png: Expected 4 parts, got 2.
# Skipping vkqilkuo-0.png: Expected 8 parts, got 20.
# Skipping 12y6y1y-0.png: Expected 7 parts, got 6.
# Skipping 0bag6mnf-0.png: Expected 8 parts, got 9.
# Skipping suv8wrs-0.png: Expected 7 parts, got 6.
# Skipping neqglc4-0.png: Expected 7 parts, got 4.
# Skipping bktqjwm7-0.png: Expected 8 parts, got 9.
# Skipping ywurlaja-0.png: Expected 8 parts, got 7.
# Skipping pme8-0.png: Expected 4 parts, got 3.
# Skipping w51m8lf-0.png: Expected 7 parts, got 5.
# Skipping pd5v1-0.png: Expected 5 parts, got 6.
# Skipping 8nogbc-0.png: Expected 6 parts, got 3.
# Skipping yjbykv-0.png: Expected 6 parts, got 7.
# Skipping m6d0ul-0.png: Expected 6 parts, got 5.
# Skipping zfk708q-0.png: Expected 7 parts, got 8.
# Skipping hr516373-0.png: Expected 8 parts, got 9.
# Skipping zk1kks-0.png: Expected 6 parts, got 9.
# Skipping 26x1pa-0.png: Expected 6 parts, got 16.
# Skipping daqbbg84-0.png: Expected 8 parts, got 7.
# Skipping jbro8l9x-0.png: Expected 8 parts, got 5.
# Skipping 51oap8f-0.png: Expected 7 parts, got 8.
# Skipping u1xqt-0.png: Expected 5 parts, got 4.
# Skipping b2ba-0.png: Expected 4 parts, got 5.
# Skipping f1xrpj4u-0.png: Expected 8 parts, got 9.
# Skipping vseps0-0.png: Expected 6 parts, got 7.
# Skipping q5bsxfwd-0.png: Expected 8 parts, got 16.
# Skipping orcbf-0.png: Expected 5 parts, got 2.
# Skipping cpxb-0.png: Expected 4 parts, got 5.
# Skipping pdvo1eu-0.png: Expected 7 parts, got 6.
# Skipping e7tdx-0.png: Expected 5 parts, got 3.
# Skipping ea3hucju-0.png: Expected 8 parts, got 5.
# Skipping qdxs-0.png: Expected 4 parts, got 3.
# Skipping osbro-0.png: Expected 5 parts, got 1.
# Skipping zhjgqs-0.png: Expected 6 parts, got 3.
# Skipping g5aftz-0.png: Expected 6 parts, got 3.
# Skipping ylal-0.png: Expected 4 parts, got 5.
# Skipping xoxpcun-0.png: Expected 7 parts, got 6.
# Skipping zwvt087-0.png: Expected 7 parts, got 9.
# Skipping wt45sey-0.png: Expected 7 parts, got 8.
# Skipping 6ioem8o-0.png: Expected 7 parts, got 3.
# Skipping mbi0yuwp-0.png: Expected 8 parts, got 6.
# Skipping foa7x26p-0.png: Expected 8 parts, got 7.
# Skipping khqsfa-0.png: Expected 6 parts, got 15.
# Skipping v8ndsxc-0.png: Expected 7 parts, got 6.
# Skipping ts90mw-0.png: Expected 6 parts, got 10.
# Skipping 7o68a-0.png: Expected 5 parts, got 4.
# Skipping sb7gou4u-0.png: Expected 8 parts, got 6.
# Skipping 6l1aljwp-0.png: Expected 8 parts, got 5.
# Skipping 227hgav-0.png: Expected 7 parts, got 18.
# Skipping 32917thd-0.png: Expected 8 parts, got 9.
# Skipping o7c24c2-0.png: Expected 7 parts, got 14.
# Skipping 7qy4-0.png: Expected 4 parts, got 2.
# Skipping 7iv4-0.png: Expected 4 parts, got 3.
# Skipping s0v7n-0.png: Expected 5 parts, got 6.
# Skipping h28drs7-0.png: Expected 7 parts, got 9.
# Skipping oehni9-0.png: Expected 6 parts, got 7.
# Skipping v5vwc-0.png: Expected 5 parts, got 4.
# Skipping k2g1vfa-0.png: Expected 7 parts, got 3.
# Skipping jdp40cu-0.png: Expected 7 parts, got 6.
# Skipping 5fk4me-0.png: Expected 6 parts, got 4.
# Skipping 2wf8ae3g-0.png: Expected 8 parts, got 4.
# Skipping y6rjq-0.png: Expected 5 parts, got 6.
# Skipping ipbp8-0.png: Expected 5 parts, got 3.
# Skipping y5s7pz-0.png: Expected 6 parts, got 11.
# Skipping gv85x-0.png: Expected 5 parts, got 6.
# Skipping 9d5xyo-0.png: Expected 6 parts, got 4.
# Skipping zw3i6-0.png: Expected 5 parts, got 7.
# Skipping 1d9gd-0.png: Expected 5 parts, got 3.
# Skipping s82e83i-0.png: Expected 7 parts, got 6.
# Skipping fwxtwn-0.png: Expected 6 parts, got 5.
# Skipping 24uyja-0.png: Expected 6 parts, got 4.
# Skipping duj9-0.png: Expected 4 parts, got 7.
# Skipping r35bs85p-0.png: Expected 8 parts, got 4.
# Skipping hvlr3f9y-0.png: Expected 8 parts, got 13.
# Skipping mqjd0t-0.png: Expected 6 parts, got 7.
# Skipping may8q61z-0.png: Expected 8 parts, got 7.
# Skipping 8x7l-0.png: Expected 4 parts, got 2.
# Skipping mmnyyde-0.png: Expected 7 parts, got 8.
# Skipping mrtcx-0.png: Expected 5 parts, got 4.
# Skipping oira0k7h-0.png: Expected 8 parts, got 7.
# Skipping pemle5r-0.png: Expected 7 parts, got 13.
# Skipping qsd5edc-0.png: Expected 7 parts, got 8.
# Skipping 187k8-0.png: Expected 5 parts, got 8.
# Skipping k0f6-0.png: Expected 4 parts, got 6.
# Skipping dhui6z-0.png: Expected 6 parts, got 7.
# Skipping cusx9f-0.png: Expected 6 parts, got 1.
# Skipping qv1b-0.png: Expected 4 parts, got 9.
# Skipping py8x-0.png: Expected 4 parts, got 3.
# Skipping nqrqhs4p-0.png: Expected 8 parts, got 3.
# Skipping rckoihd-0.png: Expected 7 parts, got 8.
# Skipping fjre-0.png: Expected 4 parts, got 3.
# Skipping r6qkf9uy-0.png: Expected 8 parts, got 7.
# Skipping e7ee3-0.png: Expected 5 parts, got 11.
# Skipping x6vfpozk-0.png: Expected 8 parts, got 9.
# Skipping s8of-0.png: Expected 4 parts, got 1.
# Skipping 3kev7t-0.png: Expected 6 parts, got 7.
# Skipping lxdp-0.png: Expected 4 parts, got 2.
# Skipping 7fptq5ti-0.png: Expected 8 parts, got 4.
# Skipping osiai-0.png: Expected 5 parts, got 7.
# Skipping q8l04ku-0.png: Expected 7 parts, got 2.
# Skipping tjhv-0.png: Expected 4 parts, got 5.
# Skipping s52h6c-0.png: Expected 6 parts, got 5.
# Skipping 1wmebgw-0.png: Expected 7 parts, got 0.
# Skipping ymva5s55-0.png: Expected 8 parts, got 10.
# Skipping f8ytwd7u-0.png: Expected 8 parts, got 7.
# Skipping nrw3o7m-0.png: Expected 7 parts, got 8.
# Skipping 96b7kz4p-0.png: Expected 8 parts, got 10.
# Skipping f0na5-0.png: Expected 5 parts, got 8.
# Skipping 86gf-0.png: Expected 4 parts, got 3.
# Skipping uzaj85-0.png: Expected 6 parts, got 11.
# Skipping 2hmi-0.png: Expected 4 parts, got 6.
# Skipping kbkap9-0.png: Expected 6 parts, got 5.
# Skipping v2lrfu-0.png: Expected 6 parts, got 4.
# Skipping n5ca-0.png: Expected 4 parts, got 3.
# Skipping id3wmx-0.png: Expected 6 parts, got 9.
# Skipping p17nq99-0.png: Expected 7 parts, got 5.
# Skipping 6igl-0.png: Expected 4 parts, got 5.
# Skipping 9dfu3gfs-0.png: Expected 8 parts, got 6.
# Skipping it49-0.png: Expected 4 parts, got 3.
# Skipping 4ff7pwx-0.png: Expected 7 parts, got 12.
# Skipping lhrq7w-0.png: Expected 6 parts, got 9.
# Skipping 32o7-0.png: Expected 4 parts, got 6.
# Skipping 78hw61-0.png: Expected 6 parts, got 7.
# Skipping j33j2-0.png: Expected 5 parts, got 4.
# Skipping m1el7ggi-0.png: Expected 8 parts, got 9.
# Skipping wa52ybn1-0.png: Expected 8 parts, got 7.
# Skipping ou0hdsa-0.png: Expected 7 parts, got 5.
# Skipping fsb68-0.png: Expected 5 parts, got 6.
# Skipping aix8-0.png: Expected 4 parts, got 3.
# Skipping ehvk1-0.png: Expected 5 parts, got 0.
# Skipping 4kocxrt-0.png: Expected 7 parts, got 6.
# Skipping 3k0n3pad-0.png: Expected 8 parts, got 13.
# Skipping shme5903-0.png: Expected 8 parts, got 4.
# Skipping 5l0eu5c-0.png: Expected 7 parts, got 6.
# Skipping a5tch15i-0.png: Expected 8 parts, got 7.
# Skipping qieallb-0.png: Expected 7 parts, got 9.
# Skipping yps8t-0.png: Expected 5 parts, got 4.
# Skipping uv02ed9-0.png: Expected 7 parts, got 6.
# Skipping xm23a-0.png: Expected 5 parts, got 6.
# Skipping 5cjs-0.png: Expected 4 parts, got 5.
# Skipping vkte-0.png: Expected 4 parts, got 3.
# Skipping hgdikcb-0.png: Expected 7 parts, got 6.
# Skipping yof332no-0.png: Expected 8 parts, got 10.
# Skipping kwp5v-0.png: Expected 5 parts, got 3.
# Skipping ffrn3h1-0.png: Expected 7 parts, got 8.
# Skipping ywwwm-0.png: Expected 5 parts, got 8.
# Skipping 6dc54h4-0.png: Expected 7 parts, got 6.
# Skipping usg0v7g-0.png: Expected 7 parts, got 9.
# Skipping x9ukcz3t-0.png: Expected 8 parts, got 0.
# Skipping g8qe34e-0.png: Expected 7 parts, got 8.
# Skipping z91dr-0.png: Expected 5 parts, got 3.
# Skipping q3d6z-0.png: Expected 5 parts, got 6.
# Skipping 2pf7bpt5-0.png: Expected 8 parts, got 7.
# Skipping otl7fnd-0.png: Expected 7 parts, got 5.
# Skipping 11pkel8-0.png: Expected 7 parts, got 10.
# Skipping de9ehwc-0.png: Expected 7 parts, got 6.
# Skipping kbal3lh-0.png: Expected 7 parts, got 8.
# Skipping kj9jw20y-0.png: Expected 8 parts, got 9.
# Skipping rlcnd-0.png: Expected 5 parts, got 7.
# Skipping 6uno-0.png: Expected 4 parts, got 6.
# Skipping xmw8-0.png: Expected 4 parts, got 5.
# Skipping 1hue9-0.png: Expected 5 parts, got 3.
# Skipping 5rbfpwt-0.png: Expected 7 parts, got 10.
# Skipping nz6w6-0.png: Expected 5 parts, got 7.
# Skipping thv0ym7p-0.png: Expected 8 parts, got 5.
# Skipping 0xnsjn-0.png: Expected 6 parts, got 5.
# Skipping 8o8379d-0.png: Expected 7 parts, got 3.
# Skipping 4lxvy-0.png: Expected 5 parts, got 6.
# Skipping dy5s36-0.png: Expected 6 parts, got 5.
# Skipping vijr-0.png: Expected 4 parts, got 5.
# Skipping v66jx27k-0.png: Expected 8 parts, got 10.
# Skipping bvrejwz-0.png: Expected 7 parts, got 6.
# Skipping o2vlo-0.png: Expected 5 parts, got 3.
# Skipping umagbsh-0.png: Expected 7 parts, got 5.
# Skipping 0m5gzz-0.png: Expected 6 parts, got 5.
# Skipping 3es0-0.png: Expected 4 parts, got 1.
# Skipping sp43pxpi-0.png: Expected 8 parts, got 10.
# Skipping fu0aa-0.png: Expected 5 parts, got 3.
# Skipping 3lkh9-0.png: Expected 5 parts, got 6.
# Skipping wtlp1wls-0.png: Expected 8 parts, got 20.
# Skipping 1pksa7t-0.png: Expected 7 parts, got 6.
# Skipping atl6-0.png: Expected 4 parts, got 5.
# Skipping u89h-0.png: Expected 4 parts, got 1.
# Skipping 93s68fxh-0.png: Expected 8 parts, got 9.
# Skipping xgedtm-0.png: Expected 6 parts, got 10.
# Skipping ndsiluy-0.png: Expected 7 parts, got 6.
# Skipping eggxt3ug-0.png: Expected 8 parts, got 4.
# Skipping pzqi-0.png: Expected 4 parts, got 5.
# Skipping kphzrqg2-0.png: Expected 8 parts, got 9.
# Skipping 1dswg3sc-0.png: Expected 8 parts, got 4.
# Skipping 9fsuvt-0.png: Expected 6 parts, got 4.
# Skipping i4sg1hp-0.png: Expected 7 parts, got 8.
# Skipping i57psax-0.png: Expected 7 parts, got 6.
# Skipping qhi5yn5j-0.png: Expected 8 parts, got 3.
# Skipping kzvtgak8-0.png: Expected 8 parts, got 4.
# Skipping lmnmuq-0.png: Expected 6 parts, got 10.
# Skipping 6481t20-0.png: Expected 7 parts, got 10.
# Skipping qjpzqyx-0.png: Expected 7 parts, got 8.
# Skipping 9rfhh-0.png: Expected 5 parts, got 8.
# Skipping khzj8bf-0.png: Expected 7 parts, got 5.
# Skipping vyg2wz-0.png: Expected 6 parts, got 4.
# Skipping ax2ckk-0.png: Expected 6 parts, got 5.
# Skipping 4z292-0.png: Expected 5 parts, got 4.
# Skipping h3iydumz-0.png: Expected 8 parts, got 4.
# Skipping 2l2a3-0.png: Expected 5 parts, got 8.
# Skipping 6pnn74-0.png: Expected 6 parts, got 3.
# Skipping mxr8db8w-0.png: Expected 8 parts, got 9.
# Skipping pqljg-0.png: Expected 5 parts, got 6.
# Skipping tig3zgh-0.png: Expected 7 parts, got 6.
# Skipping 07smvpl-0.png: Expected 7 parts, got 9.
# Skipping o7a4burc-0.png: Expected 8 parts, got 7.
# Skipping l3h3dwp-0.png: Expected 7 parts, got 4.
# Skipping 68slr50-0.png: Expected 7 parts, got 8.
# Skipping ku6hg-0.png: Expected 5 parts, got 3.
# Skipping m4ov4-0.png: Expected 5 parts, got 6.
# Skipping y2nq-0.png: Expected 4 parts, got 5.
# Skipping vggdclx-0.png: Expected 7 parts, got 18.
# Skipping ddlhp8nh-0.png: Expected 8 parts, got 17.
# Skipping 69et9-0.png: Expected 5 parts, got 6.
# Skipping 55vrsa8p-0.png: Expected 8 parts, got 5.
# Skipping 4194-0.png: Expected 4 parts, got 9.
# Skipping t9owh-0.png: Expected 5 parts, got 6.
# Skipping j2dop-0.png: Expected 5 parts, got 6.
# Skipping ygaju-0.png: Expected 5 parts, got 4.
# Skipping nulq4-0.png: Expected 5 parts, got 3.
# Skipping 8173pa-0.png: Expected 6 parts, got 5.
# Skipping o4ienv-0.png: Expected 6 parts, got 5.
# Skipping 4rso377-0.png: Expected 7 parts, got 8.
# Skipping p1fi7h3-0.png: Expected 7 parts, got 6.
# Skipping cmrau12w-0.png: Expected 8 parts, got 6.
# Skipping nc27-0.png: Expected 4 parts, got 8.
# Skipping f103t-0.png: Expected 5 parts, got 3.
# Skipping we3ex-0.png: Expected 5 parts, got 7.
# Skipping mftqigej-0.png: Expected 8 parts, got 9.
# Skipping 4sobk9id-0.png: Expected 8 parts, got 9.
# Skipping cwbx7k8-0.png: Expected 7 parts, got 8.
# Skipping 4o1cgem-0.png: Expected 7 parts, got 6.
# Skipping qzpv5d-0.png: Expected 6 parts, got 5.
# Skipping 1f8m0nu-0.png: Expected 7 parts, got 6.
# Skipping ffy3glsp-0.png: Expected 8 parts, got 9.
# Skipping iw7wtm-0.png: Expected 6 parts, got 0.
# Skipping d5ri1u-0.png: Expected 6 parts, got 4.
# Skipping tuxl-0.png: Expected 4 parts, got 2.
# Processing complete! Segmented characters are saved in /home/liauzhanyi/cs4243/data/segmented_train
# Total skipped: 1528

# %%
def augment_and_save_images(input_dir, output_dir, augment_count=3):
    """Augment images from `input_dir` and save them with proper naming to `output_dir`."""
    os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists

    # Define a more controlled data augmentation pipeline
    datagen = ImageDataGenerator(
        rotation_range=10,          # Small rotation for better quality
        width_shift_range=0.05,     # Slight horizontal shift
        height_shift_range=0.05,    # Slight vertical shift
        shear_range=0.1,            # Mild shearing
        zoom_range=0.1,             # Mild zoom
        fill_mode='nearest'         # Avoid introducing artifacts
    )

    # Loop through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Load the original image
            image_path = os.path.join(input_dir, filename)
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Expand dimensions for augmentation
            img = np.expand_dims(img, axis=-1)  # Add channel dimension
            img = np.expand_dims(img, axis=0)   # Add batch dimension

            # Extract the base filename without extension (e.g., 'abc-o')
            base_name = filename.split('.')[0]

            # Generate and save augmented images
            for i, batch in enumerate(datagen.flow(img, batch_size=1)):
                # Save each augmented image with proper naming
                augmented_filename = f"{base_name}-{i + 1}.png"
                augmented_path = os.path.join(output_dir, augmented_filename)

                # Save the augmented image
                cv2.imwrite(augmented_path, batch[0].squeeze().astype(np.uint8))

                # Stop after generating `augment_count` images per original image
                if i + 1 >= augment_count:
                    break

    print(f"Augmentation complete! Augmented images saved in {output_dir}")


# Example usage
input_dir = SEGMENTED_TRAIN_DATASET_PATH
output_dir = AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH
augment_and_save_images(input_dir, output_dir)
# Out:
# Augmentation complete! Augmented images saved in /home/liauzhanyi/cs4243/data/augmented_segmented_train

# %%
from sklearn.model_selection import train_test_split

output_dir = AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH

# Define character set (e.g., 0-9, a-z)
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_TO_IDX = {char: idx for idx, char in enumerate(CHAR_SET)}

def load_dataset(data_dir):
    images = []
    labels = []

    for filename in os.listdir(data_dir):
        if filename.endswith('.png'):
            # Extract the character from the filename (e.g., 'o' from 'oq1j-o.png')
            char_label = filename.split('-')[1][0]

            if char_label in CHAR_TO_IDX:
                # Load the image in grayscale
                image_path = os.path.join(data_dir, filename)
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

                # Resize to 28x28 (if needed)
                img = cv2.resize(img, (28, 28))
                img = img / 255.0  # Normalize pixel values to [0, 1]

                # Store the image and label
                images.append(img)
                labels.append(CHAR_TO_IDX[char_label])

    # Convert to numpy arrays
    images = np.array(images).reshape(-1, 28, 28, 1)  # Add channel dimension
    labels = np.array(labels)

    return images, labels

# Load the dataset
images, labels = load_dataset(output_dir)
print(f"Loaded {len(images)} images with {len(set(labels))} unique labels.")
# Out:
# Loaded 112638 images with 36 unique labels.

# %%
# Split the data into training and validation sets (80% train, 20% validation)
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

print(f"Training set size: {X_train.shape[0]}, Validation set size: {X_val.shape[0]}")
# Out:
# Training set size: 90110, Validation set size: 22528

# %%
#MODEL 1 ~8%

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# def build_model(num_classes):
#     model = Sequential([
#         Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
#         MaxPooling2D((2, 2)),
#         Dropout(0.2),

#         Conv2D(64, (3, 3), activation='relu'),
#         MaxPooling2D((2, 2)),
#         Dropout(0.2),

#         Flatten(),
#         Dense(128, activation='relu'),
#         Dropout(0.5),
#         Dense(num_classes, activation='softmax')
#     ])

#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#     return model

# # Build the model for 36 classes (0-9, a-z)
# num_classes = len(CHAR_SET)
# model = build_model(num_classes)
# model.summary()

# %%
#MODEL 2 ~24%

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Dropout, ReLU

# def build_custom_cnn(num_classes):
#     model = Sequential()

#     # First Conv Block
#     model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Second Conv Block
#     model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Third Conv Block
#     model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Fully Connected Layers
#     model.add(Flatten())
#     model.add(Dropout(0.5))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(36, activation='softmax'))  # 36 classes: 0-9 + a-z

#     # Compile the model
#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])

#     return model


# num_classes = len(CHAR_SET)
# model = build_model(num_classes)
# model.summary()

# %%
# #MODEL 3 ~33% (AlexNet)

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, ReLU

# def build_alexnet():
#     model = Sequential()

#     # 1st Convolutional Layer
#     model.add(Conv2D(64, (3, 3), strides=1, padding='same', input_shape=(28, 28, 1)))
#     model.add(BatchNormalization())
#     model.add(ReLU())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # 2nd Convolutional Layer
#     model.add(Conv2D(128, (3, 3), strides=1, padding='same'))
#     model.add(BatchNormalization())
#     model.add(ReLU())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # 3rd Convolutional Layer
#     model.add(Conv2D(256, (3, 3), strides=1, padding='same'))
#     model.add(BatchNormalization())
#     model.add(ReLU())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Flatten the output for Fully Connected Layers
#     model.add(Flatten())

#     # 1st Fully Connected Layer
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.5))

#     # 2nd Fully Connected Layer
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.5))

#     # Output Layer
#     model.add(Dense(36, activation='softmax'))

#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])

#     return model

# model = build_alexnet()
# model.summary()

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

def build_crnn_model(input_shape=(28, 28, 1), num_classes=36, dropout_rate=0.5):
    inputs = layers.Input(shape=input_shape)

    # Convolutional layers
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(inputs)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = layers.MaxPooling2D(pool_size=(2, 2))(x)

    x = layers.Conv2D(128, (3, 3), padding='same', activation='relu')(x)

    # Adding a Dropout layer after convolutional layers
    x = layers.Dropout(dropout_rate)(x)

    # Calculate the new shape
    height = x.shape[1]  # height after convolution and pooling
    width = x.shape[2]   # width after convolution and pooling
    channels = x.shape[3]  # channels after convolution
    new_shape = (height, width * channels)  # Reshape to (time_steps, features)

    # Reshape for LSTM input
    x = layers.Reshape(target_shape=new_shape)(x)

    # Recurrent layers
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(dropout_rate)(x)  # Adding dropout after the first LSTM

    x = layers.Bidirectional(layers.LSTM(128, return_sequences=False))(x)
    x = layers.Dropout(dropout_rate)(x)  # Adding dropout after the second LSTM

    # Output layer
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# Build the CRNN model
model = build_crnn_model()
model.summary()
# Out:
# I0000 00:00:1729907801.861060    6907 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2259 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 896)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 7, 256)         │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 36)             │         9,252 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,545,764 (5.90 MB)
#  Trainable params: 1,545,764 (5.90 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3
)

# Train the model with EarlyStopping
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Convert to a DataFrame
import pandas as pd
history_df = pd.DataFrame(history.history)

# Visualize the History
import plotly.express as px
fig = px.line(history_df, y=["loss", "val_loss"], title="Learning Curve")
fig.update_layout(
    xaxis_title="Epochs",
    yaxis_title="Sparse Categorical Crossentropy",
)
fig.show()

# %%
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

# %%
# Save the trained model
def save_model(model, dir_path, model_name="character_recognition_model.h5"):
    # Ensure the directory exists
    os.makedirs(dir_path, exist_ok=True)

    # Create the full path to the model file
    model_path = os.path.join(dir_path, model_name)

    # Save the model
    model.save(model_path)
    print(f"Model saved successfully at: {model_path}")

# Example usage
save_dir = DATA_PATH + '/model'
save_model(model, save_dir, 'crnn_85_37.keras')

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
MODEL_PATH = DATA_PATH + '/model/alexnet_v2.keras'
model = load_model(MODEL_PATH)

# Define the character set used during training
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_MAP = {idx: char for idx, char in enumerate(CHAR_SET)}

def preprocess_image(image_path):
    """Preprocess the image using the same steps as in training."""
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = cv2.bitwise_not(image)
    image = erode(image, kernel_size=(2, 2))
    image = cv2.bitwise_not(image)
    image = scipy.ndimage.median_filter(image, (3, 1))
    image = scipy.ndimage.median_filter(image, (1, 3))
    image = gaussian_thresholding(image, kernel=(5, 5), block_size=11, C=2)
    image = erode(image, kernel_size=(2, 2))
    image = gaussian_thresholding(image, kernel=(5, 5), block_size=11, C=2)
    image = erode(image, kernel_size=(2, 2))
    return image

def predict_character(image, model):
    """Predict a single character using the trained model."""
    img = cv2.resize(image, (28, 28)) / 255.0  # Resize and normalize
    img = np.expand_dims(img, axis=[0, -1])  # Add batch and channel dimensions

    prediction = model.predict(img)
    predicted_label = np.argmax(prediction)
    predicted_char = CHAR_MAP[predicted_label]
    return predicted_char

def predict_captcha_string(image_path, model):
    """Predict the entire CAPTCHA string from the input image."""
    # Preprocess the image
    processed_image = preprocess_image(image_path)

    # Segment the characters
    char_images = segment_characters(processed_image)

    # Predict each character and reconstruct the string
    predicted_string = ""
    for char_img in char_images:
        predicted_char = predict_character(char_img, model)
        predicted_string += predicted_char

    return predicted_string

# Example usage
captcha_image_path = TEST_DATASET_PATH + "/2d76-0.png"
predicted_string = predict_captcha_string(captcha_image_path, model)
print(f"Predicted CAPTCHA string: {predicted_string}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted CAPTCHA string: 2d76

# %%
import os

def evaluate_on_unseen_data(unseen_dir, model, num_images=20):
    """Evaluate the model on the first `num_images` from the unseen directory."""
    correct_predictions = 0
    total_images = 0

    # Get the first `num_images` files from the directory
    all_files = [f for f in os.listdir(unseen_dir) if f.endswith('.png')]
    all_files = sorted(all_files)[:num_images]  # Limit to first `num_images`

    for filename in all_files:
        # Extract the true label from the filename (e.g., '2d76' from '2d76-0.png')
        true_label = filename.split('-')[0]

        # Get the full path to the image
        image_path = os.path.join(unseen_dir, filename)

        # Predict the CAPTCHA string
        predicted_string = predict_captcha_string(image_path, model)
        print(f"True: {true_label}, Predicted: {predicted_string}")

        # Compare the predicted string with the true label
        if predicted_string == true_label:
            correct_predictions += 1

        total_images += 1

    # Calculate accuracy
    accuracy = correct_predictions / total_images * 100
    print(f"\nAccuracy on the first {num_images} images: {accuracy:.2f}%")

# Example usage
unseen_dir = TEST_DATASET_PATH
evaluate_on_unseen_data(unseen_dir, model, 1000)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 002e23, Predicted: 002e23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 03yl9s, Predicted: 03yi9s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# True: 03yuav5, Predicted: 03yuav5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 03zl9o, Predicted: 03zl9o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 04zqohgi, Predicted: tya7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 05htm, Predicted: 05htm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# True: 05pb, Predicted: o5pb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 07oj, Predicted: 070j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# True: 07z0, Predicted: 07z0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 08ft2e2z, Predicted: oeft2e2z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 08nxd77, Predicted: 08nxd77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 08otejfi, Predicted: 080tejfi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 08sba, Predicted: qgsba
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# True: 09popm, Predicted: 09popm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0a7sh2wp, Predicted: r6rq7wz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0al4pl, Predicted: 01i0s0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0c3dp, Predicted: 0c3dp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0c7mgdmd, Predicted: 0c7mgdmd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0chnm34, Predicted: 0mn4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0col7w, Predicted: ocol3w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0cr6, Predicted: nuiirc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0dx9, Predicted: 0doxc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0fa6qtkn, Predicted: 0tabqlkn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0favtnx, Predicted: ofavtnx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0fee, Predicted: rz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0gil, Predicted: 0gii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0gzwaq8, Predicted: ogzwaqm1i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 0h5ya8, Predicted: 0h5ya8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0i7uom, Predicted: ui1iioi8i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 0ilhsr2t, Predicted: 5ilhsr27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0iqk95h, Predicted: olqk95x
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0k2lyyc, Predicted: 0k7yyc
# True: 0lfjfob, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0me2a, Predicted: ome2a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0mgnhi, Predicted: 0iir9iihre
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 0msi, Predicted: 0msi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0n5546, Predicted: 0n5546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0nq0e, Predicted: i0i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0nucs59, Predicted: 0nucs59
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0pglswc, Predicted: 0pgi8wo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0pv2w1t, Predicted: 0pv2wit
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0qtjdlvt, Predicted: ji9tjjlgl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 0rlbarm, Predicted: qrlbarm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0rq9qn, Predicted: 0rq9q0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0rw4sjk, Predicted: srw4sjk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0s2rn2o, Predicted: 0s2rn20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 0scs, Predicted: 0scs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0sia, Predicted: 05fa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0sm8cb4c, Predicted: 3smo6cb4c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 0tbe, Predicted: o5zx
# True: 0u0y5, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0u4aj, Predicted: ou4aj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0v4o0p, Predicted: 0u4o0p
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0vug13, Predicted: q8dz1o1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0w0pankd, Predicted: 0ucjpgnnku
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0wcz1w, Predicted: owcz7w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 0wla, Predicted: f4i3l3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 0wy4otel, Predicted: 0wy40tei
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0yoxyw5, Predicted: 0y0xyw5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 11nm, Predicted: 11nm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1324mrg, Predicted: 1324mrg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 13be3kf, Predicted: l3bf3kf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 13bsgn2, Predicted: ilrpy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# True: 13v4msh, Predicted: 13v4msh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 13xy, Predicted: l3xy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 153tt0, Predicted: b3ttu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 17z8030, Predicted: ilzi1ljiii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# True: 18gg, Predicted: 18qg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 19hz, Predicted: 19hz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1asdyrv, Predicted: 1asdyrv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: 1avc, Predicted: 1avc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1awqu, Predicted: 1qwqu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1bu55hc, Predicted: 18u55hc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1c3bi3zm, Predicted: 1csbanzm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1cfa40wy, Predicted: 1cfa40wy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1ctc5l, Predicted: ckw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# True: 1dhcacd, Predicted: 1dhcacd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1dy0p, Predicted: 1dy0b
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1e1qxwyz, Predicted: z4jre2yjrqxwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1ed0i9xz, Predicted: 1edod9xz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1ewgub4, Predicted: 1ew6ub4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 1ewq, Predicted: 1ewp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1fh4thm, Predicted: lfh4thm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1gbu5qus, Predicted: 1gbu5qu9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 1ghx0spj, Predicted: ighxospj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1hiqbpx3, Predicted: ihrqbpx9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# True: 1imwt, Predicted: iitli
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1irn, Predicted: iih7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 1iwe, Predicted: iiwe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1j2xhu, Predicted: 1j2xhu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1k94, Predicted: iis94
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1kfm, Predicted: 1hfm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1ku9bzoy, Predicted: 1ku9bzoy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 1mrffz, Predicted: lmffz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1mwa, Predicted: 1mwa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 1nyd, Predicted: inyd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1o5kcof, Predicted: io5kcof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 1ozltu, Predicted: r20llru
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1qp4885m, Predicted: 1qp4886m
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1rhud8rx, Predicted: kwdxx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1sil9, Predicted: 1sil9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 1tyn, Predicted: 1tyn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 1u81r, Predicted: 0iii2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1ulul, Predicted: 7ulul
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 1wu0cul, Predicted: 1wd0cul
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1x44n7nx, Predicted: i1ii1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 1x8ljpi, Predicted: in8lypi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1xut0w4, Predicted: lxut0wy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 1zcg2o, Predicted: zr60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 20ka8wmo, Predicted: 20ka8wm0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 21iyxsn, Predicted: ziiyxsn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 21z1y, Predicted: 2iziy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 220ofgki, Predicted: 220of9ki
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 23osam, Predicted: 23osam
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 24idbq3f, Predicted: 24idbq3f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 24y0s85, Predicted: 24y0sb5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 265qfy, Predicted: 265qfy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 26pw3, Predicted: 26pw3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 273u, Predicted: 273u
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 27hibrae, Predicted: 27hzlbrae
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 29bgk, Predicted: 29bgk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 29or, Predicted: 21xor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2aidl, Predicted: 2aldl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 2bdh, Predicted: 2bdh
# True: 2bjj1pos, Predicted:
# True: 2c5ol, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2cteaog, Predicted: 2ctea0g
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2d0qj, Predicted: 200qj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 2d76, Predicted: 2d76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 2ennujkj, Predicted: 2ennujkj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2flvu7n, Predicted: 2flvu7n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2fxu0s, Predicted: 2fxuo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 2fyohm, Predicted: 2flyuhm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2gbiw7, Predicted: 2c75lnv7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 2gquin1i, Predicted: 2gquin1i
# True: 2gslhci, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# True: 2iulzl, Predicted: 2uulzl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# True: 2k1xlp, Predicted: 2k1xlp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 2m1qu1e4, Predicted: 2m1quiew
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# True: 2mo9qj39, Predicted: 2m09qj39
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# True: 2mvjsa, Predicted: 2mvjsa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# True: 2n2it3lx, Predicted: 2n2it3lx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 2njlt4, Predicted: 7nj111i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# True: 2o6f, Predicted: 2o6f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 2oa73, Predicted: 2oa7j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 2oy2f9, Predicted: 2oy2f9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# True: 2p6wwybk, Predicted: 2p6wwybk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2q9zjsun, Predicted: qzjsun
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: 2qhqtv2, Predicted: 74itvii7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2rs4jvyr, Predicted: 2rs4uvyr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2sp9gvbi, Predicted: 2sp9gv8l
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2sxkz2vj, Predicted: 2sxkz2uj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2t02x, Predicted: 2to2x
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2txh8, Predicted: 7txr8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 2tyw3, Predicted: mrny
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2u6t6, Predicted: 2u6t6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2v2n13je, Predicted: 2v2n13je
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# True: 2vapwy, Predicted: 2vapwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2w02hmo, Predicted: 2wo2hmo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2x7qps0, Predicted: aryi7r0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2y11w, Predicted: 2y11w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2y43vf, Predicted: 2ya3af
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2ybig03, Predicted: 2ybigq3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2yjiz, Predicted: 2yj1z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# True: 2yjoie, Predicted: yjoie
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 2yqdk, Predicted: 2yqdk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2zkfhs1n, Predicted: 2zkfhs1n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2zs3, Predicted: 2zs3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 30rju0c, Predicted: 30rju0c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# True: 30znefk, Predicted: 3oznefk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 31qyiq, Predicted: 31qyiq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 327gm, Predicted: 327gm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 32evcjk8, Predicted: 32eycjkb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 32llr, Predicted: 3211r
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 33yxl, Predicted: xx11xij
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 345ar, Predicted: 345ar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 35av6, Predicted: 35av6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 36ev8oj, Predicted: 36qv8oi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 379cfumx, Predicted: 379cfunk
# True: 386h7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 38v2mv, Predicted: 3by2ny
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 39fyn9, Predicted: 39fyn9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 39uww47, Predicted: m9uww47
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 3aa8, Predicted: 3eo8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 3aut4, Predicted: 3aut4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ...
# True: h7f9, Predicted: h7f9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: h8tg, Predicted: hatg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hagreh, Predicted: hagreh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: ham46lpd, Predicted: ham46lpd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: haps2, Predicted: vibsy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hb5fz, Predicted: hb5fz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hbll9, Predicted: hb1l9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hc0ulqk, Predicted: k04k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hc5rx39, Predicted: nncskxy9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hc8jk3, Predicted: hxjk3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hciv7, Predicted: xuriu19i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hcwgu, Predicted: hcwgu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: he7grud, Predicted: he7grud
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hetibp, Predicted: hetibp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: hj5ms, Predicted: hj5ms
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hjbj, Predicted: hibi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hkmy29, Predicted: hkmy29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: hl79, Predicted: hl79
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hljv6, Predicted: 4iz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hm5osaq, Predicted: hr1s0b7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: hnns4, Predicted: hnns4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: ho6v2tsw, Predicted: hc6u2tsw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hptym6, Predicted: xpty36
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hqo6slvr, Predicted: hqo6slvi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: hrdksy8, Predicted: hrdksy8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hsb1tie, Predicted: hsb1tie
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hsnd7hq, Predicted: hgnd7jd1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hvch2er7, Predicted: hucheer7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: hvgp, Predicted: hvgp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hvj6wg, Predicted: ilii1ihiih1ii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hvk6, Predicted: hvk6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hw6ta6, Predicted: 7p6g1cg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hwev766, Predicted: hwey766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hxtahp3, Predicted: hxtahp3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hy850xk1, Predicted: hy85oxki
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hy8d, Predicted: ii4ra4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hyj870q, Predicted: hyj870q
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: hynvxdz, Predicted: r2zc4dz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: hyp3tvwt, Predicted: ulkitvet
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: i1yipm08, Predicted: i1ipihfrs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: i23xg1a8, Predicted: i23xgb8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: i2d24k, Predicted: j2d24k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: i2j3gfg, Predicted: i2j3gfg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: i2tc, Predicted: i2tc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: i2ximgo, Predicted: 12x1mgo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: i3hsnv, Predicted: i3hsnoj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: i3ijtc, Predicted: i3ijtc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i3jpjs, Predicted: i3jpjs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: i3reuje, Predicted: l3reuje
# True: i3vv4b7, Predicted:
# True: i4yahaly, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i5aa1, Predicted: i1fi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i5kd0omr, Predicted: i5kd00rr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: i6i6e, Predicted: i6i6e
# True: i7hqc7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i9dhn60, Predicted: igdhn6o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i9n9a, Predicted: j9n9a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: iackdv2, Predicted: iack0v2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: iazoykf, Predicted: 1avyki
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: ib7372l, Predicted: jp1312l
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: ibkmxh, Predicted: ibkmxh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: ibn9ph, Predicted: ibn9pa
#
# Accuracy on the first 1000 images: 37.50%
