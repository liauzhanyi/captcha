# %%
TRAIN_DATASET_PATH = '/Users/jjtiong/Desktop/captcha_dataset/train'
TEST_DATASET_PATH = '/Users/jjtiong/Desktop/captcha_dataset/test'
OUTPUT_PATH = '/Users/jjtiong/Desktop/captcha_dataset/segmented_train'
SEGMENTED_TRAIN_DATASET_PATH = '/Users/jjtiong/Desktop/captcha_dataset/segmented_train'
AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH = '/Users/jjtiong/Desktop/captcha_dataset/augmented_segmented_train'
MODEL_PATH = '/Users/jjtiong/Desktop/captcha_dataset/model2/character_recognition_model.h5'

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt


def gaussian_thresholding(image):
    # Use gaussian blur to make characters thicker before thresholding 
    blur = cv2.GaussianBlur(image, (5, 5), 0)
    thresholded_image = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
        cv2.THRESH_BINARY, blockSize=11, C=2
    )
    return image

def dilate(image):
    #  Remove noise via dilation
    kernel = np.ones((3,3), np.uint8)
    dilation = cv2.dilate(image, kernel, iterations=1)
    
    return dilation

# def adaptive_thresholding(image):
#     thresholded_image = cv2.adaptiveThreshold(
#         image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
#         cv2.THRESH_BINARY, blockSize=11, C=2
#     )
#     return thresholded_image

# def remove_noise(image):
#     kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
#     cleaned_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel, iterations=1)
#     cleaned_image = cv2.morphologyEx(cleaned_image, cv2.MORPH_CLOSE, kernel, iterations=1)
#     return cleaned_image

# def remove_lines(image):
#     lines = cv2.HoughLinesP(image, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)
#     if lines is not None:
#         for line in lines:
#             x1, y1, x2, y2 = line[0]
#             cv2.line(image, (x1, y1), (x2, y2), 0, thickness=2)
#     return image

def segment_characters(image):
    inverted_image = cv2.bitwise_not(image)
    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    char_images = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if h > 10:  # Filter small noise
            char_img = image[y:y+h, x:x+w]
            char_images.append((x, char_img))
    char_images = sorted(char_images, key=lambda c: c[0])  # Sort by x-coordinate

    return [char[1] for char in char_images]

def process_and_save_images(input_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Keep track of how many captchas were skipped
    skipped_count = 0

    # Process each image in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Extract the true label from the filename
            base_name = filename.split('-')[0]

            # Load and preprocess the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Apply preprocessing steps
            image = gaussian_thresholding(image)
            image = dilate(image)
            # image = remove_lines(image)

            # Segment characters
            char_images = segment_characters(image)

            # Validate the number of segmented parts
            if len(char_images) != len(base_name):
                print(f"Skipping {filename}: Expected {len(base_name)} parts, got {len(char_images)}.")
                skipped_count += 1
                continue  # Skip saving this image

            # Save each segmented character follow the naming convention <label_str>-<char>.png
            for idx, char_img in enumerate(char_images):
                char_label = base_name[idx]
                save_name = f"{base_name}-{char_label}.png"
                save_path = os.path.join(output_dir, save_name)

                # Save the segmented character
                cv2.imwrite(save_path, char_img)

    print(f"Processing complete! Segmented characters are saved in {output_dir}")
    print(f"Total skipped: {skipped_count}")


process_and_save_images(TRAIN_DATASET_PATH, SEGMENTED_TRAIN_DATASET_PATH)
# Out:
# Skipping 2zimhl0-0.png: Expected 7 parts, got 0.
# Skipping stx1upye-0.png: Expected 8 parts, got 0.
# Skipping nip6-0.png: Expected 4 parts, got 1.
# Skipping vmii-0.png: Expected 4 parts, got 5.
# Skipping 4rcb-0.png: Expected 4 parts, got 0.
# Skipping yyvv0kit-0.png: Expected 8 parts, got 1.
# Skipping y0cq-0.png: Expected 4 parts, got 2.
# Skipping hdu5-0.png: Expected 4 parts, got 1.
# Skipping 8d2y98-0.png: Expected 6 parts, got 5.
# Skipping aswhu3-0.png: Expected 6 parts, got 7.
# Skipping b764czl-0.png: Expected 7 parts, got 4.
# Skipping qkyk15f-0.png: Expected 7 parts, got 6.
# Skipping dwzv-0.png: Expected 4 parts, got 0.
# Skipping 9a2xdo-0.png: Expected 6 parts, got 0.
# Skipping usskt-0.png: Expected 5 parts, got 0.
# Skipping pk0k8c3-0.png: Expected 7 parts, got 10.
# Skipping 0hhit-0.png: Expected 5 parts, got 7.
# Skipping g0o1-0.png: Expected 4 parts, got 1.
# Skipping ts90mw-0.png: Expected 6 parts, got 11.
# Skipping wg3pj3rn-0.png: Expected 8 parts, got 7.
# Skipping i5t4f5-0.png: Expected 6 parts, got 4.
# Skipping tm364-0.png: Expected 5 parts, got 4.
# Skipping 1hznv-0.png: Expected 5 parts, got 4.
# Skipping mg1po-0.png: Expected 5 parts, got 3.
# Skipping mkwuh4-0.png: Expected 6 parts, got 0.
# Skipping v8li-0.png: Expected 4 parts, got 0.
# Skipping 7ypolv8-0.png: Expected 7 parts, got 8.
# Skipping nwhjcd1l-0.png: Expected 8 parts, got 9.
# Skipping jkbsth6-0.png: Expected 7 parts, got 0.
# Skipping jjlqvh-0.png: Expected 6 parts, got 1.
# Skipping lon1nsi-0.png: Expected 7 parts, got 5.
# Skipping dmx8md-0.png: Expected 6 parts, got 8.
# Skipping 1k2r-0.png: Expected 4 parts, got 3.
# Skipping 2qugryl-0.png: Expected 7 parts, got 6.
# Skipping 8cyjlhnp-0.png: Expected 8 parts, got 7.
# Skipping rvld-0.png: Expected 4 parts, got 5.
# Skipping ugfwgd-0.png: Expected 6 parts, got 8.
# Skipping 9iu2gmpe-0.png: Expected 8 parts, got 0.
# Skipping 9nc3xnm-0.png: Expected 7 parts, got 5.
# Skipping 07r8f9or-0.png: Expected 8 parts, got 5.
# Skipping bwbqywq-0.png: Expected 7 parts, got 9.
# Skipping uz2w0-0.png: Expected 5 parts, got 7.
# Skipping 91nok-0.png: Expected 5 parts, got 6.
# Skipping mf1a02-0.png: Expected 6 parts, got 2.
# Skipping im28xht-0.png: Expected 7 parts, got 5.
# Skipping 50vy-0.png: Expected 4 parts, got 0.
# Skipping u0pimd1w-0.png: Expected 8 parts, got 3.
# Skipping 4bek73-0.png: Expected 6 parts, got 3.
# Skipping gi00g-0.png: Expected 5 parts, got 9.
# Skipping smabmix-0.png: Expected 7 parts, got 5.
# Skipping vf1n2ewf-0.png: Expected 8 parts, got 7.
# Skipping h2h3h09-0.png: Expected 7 parts, got 6.
# Skipping wad3n3e-0.png: Expected 7 parts, got 5.
# Skipping yzikl-0.png: Expected 5 parts, got 0.
# Skipping nn01d-0.png: Expected 5 parts, got 3.
# Skipping knsvzw9-0.png: Expected 7 parts, got 5.
# Skipping 5f928u-0.png: Expected 6 parts, got 9.
# Skipping uhhsj-0.png: Expected 5 parts, got 0.
# Skipping e06k4rkg-0.png: Expected 8 parts, got 0.
# Skipping 765iii9-0.png: Expected 7 parts, got 4.
# Skipping 2urroi-0.png: Expected 6 parts, got 8.
# Skipping 58bp1pgm-0.png: Expected 8 parts, got 7.
# Skipping e2ytrd3s-0.png: Expected 8 parts, got 4.
# Skipping 4o8zt-0.png: Expected 5 parts, got 2.
# Skipping o8u33-0.png: Expected 5 parts, got 0.
# Skipping mnzu-0.png: Expected 4 parts, got 1.
# Skipping maf6639-0.png: Expected 7 parts, got 5.
# Skipping 9c42y-0.png: Expected 5 parts, got 0.
# Skipping 4i29-0.png: Expected 4 parts, got 0.
# Skipping ea3hucju-0.png: Expected 8 parts, got 0.
# Skipping whdq30-0.png: Expected 6 parts, got 8.
# Skipping k3rdv6w-0.png: Expected 7 parts, got 6.
# Skipping oy6rm-0.png: Expected 5 parts, got 7.
# Skipping 9sfm-0.png: Expected 4 parts, got 1.
# Skipping aofzk-0.png: Expected 5 parts, got 4.
# Skipping dlqcyv-0.png: Expected 6 parts, got 4.
# Skipping syrra17g-0.png: Expected 8 parts, got 7.
# Skipping ngj4nyi8-0.png: Expected 8 parts, got 12.
# Skipping dq5n-0.png: Expected 4 parts, got 5.
# Skipping pd5la-0.png: Expected 5 parts, got 3.
# Skipping 666o5ez0-0.png: Expected 8 parts, got 7.
# Skipping qs1h-0.png: Expected 4 parts, got 5.
# Skipping mbcetlnd-0.png: Expected 8 parts, got 10.
# Skipping 4yh2-0.png: Expected 4 parts, got 0.
# Skipping v5fng1sj-0.png: Expected 8 parts, got 6.
# Skipping e1fr-0.png: Expected 4 parts, got 3.
# Skipping 9otpv3f-0.png: Expected 7 parts, got 5.
# Skipping dhwb79-0.png: Expected 6 parts, got 10.
# Skipping mitrx-0.png: Expected 5 parts, got 0.
# Skipping kntzog3u-0.png: Expected 8 parts, got 7.
# Skipping tfmd-0.png: Expected 4 parts, got 5.
# Skipping rytxwi7c-0.png: Expected 8 parts, got 5.
# Skipping thv0ym7p-0.png: Expected 8 parts, got 1.
# Skipping sww2-0.png: Expected 4 parts, got 5.
# Skipping h6zu4ymn-0.png: Expected 8 parts, got 7.
# Skipping 0sw1nb-0.png: Expected 6 parts, got 9.
# Skipping gfmh9-0.png: Expected 5 parts, got 3.
# Skipping ctqbhvet-0.png: Expected 8 parts, got 0.
# Skipping jf7wsdg-0.png: Expected 7 parts, got 8.
# Skipping sn0ablc-0.png: Expected 7 parts, got 2.
# Skipping vxhtnoi-0.png: Expected 7 parts, got 0.
# Skipping 1y50dcgt-0.png: Expected 8 parts, got 1.
# Skipping hq31kmw-0.png: Expected 7 parts, got 5.
# Skipping 78hab06-0.png: Expected 7 parts, got 11.
# Skipping e6mh-0.png: Expected 4 parts, got 1.
# Skipping winr-0.png: Expected 4 parts, got 2.
# Skipping rkudk5p-0.png: Expected 7 parts, got 5.
# Skipping i8bi-0.png: Expected 4 parts, got 3.
# Skipping ozgr-0.png: Expected 4 parts, got 1.
# Skipping 6k23-0.png: Expected 4 parts, got 1.
# Skipping xrb5-0.png: Expected 4 parts, got 2.
# Skipping fsstrk-0.png: Expected 6 parts, got 3.
# Skipping b384b-0.png: Expected 5 parts, got 8.
# Skipping iuisngw3-0.png: Expected 8 parts, got 9.
# Skipping 0v4n-0.png: Expected 4 parts, got 0.
# Skipping cun2-0.png: Expected 4 parts, got 0.
# Skipping e7ysg8q-0.png: Expected 7 parts, got 0.
# Skipping s681vc-0.png: Expected 6 parts, got 7.
# Skipping 8ce92-0.png: Expected 5 parts, got 2.
# Skipping k2erja-0.png: Expected 6 parts, got 7.
# Skipping 43i4-0.png: Expected 4 parts, got 3.
# Skipping 777h0nq-0.png: Expected 7 parts, got 5.
# Skipping n1r9hlf-0.png: Expected 7 parts, got 5.
# Skipping h9mri-0.png: Expected 5 parts, got 6.
# Skipping g58ect-0.png: Expected 6 parts, got 0.
# Skipping bgotnjj2-0.png: Expected 8 parts, got 9.
# Skipping 3ns6o1dj-0.png: Expected 8 parts, got 10.
# Skipping ts4cw-0.png: Expected 5 parts, got 4.
# Skipping 8x0pjn-0.png: Expected 6 parts, got 11.
# Skipping ofmbvmx-0.png: Expected 7 parts, got 6.
# Skipping ieqhcc-0.png: Expected 6 parts, got 0.
# Skipping x296eg-0.png: Expected 6 parts, got 0.
# Skipping 4vzc-0.png: Expected 4 parts, got 1.
# Skipping 99mqhb-0.png: Expected 6 parts, got 4.
# Skipping ktzefibh-0.png: Expected 8 parts, got 6.
# Skipping hwq0huvj-0.png: Expected 8 parts, got 0.
# Skipping 2g0fg-0.png: Expected 5 parts, got 4.
# Skipping lim18csq-0.png: Expected 8 parts, got 3.
# Skipping 92q7-0.png: Expected 4 parts, got 1.
# Skipping rripcy3d-0.png: Expected 8 parts, got 14.
# Skipping dg7v3-0.png: Expected 5 parts, got 6.
# Skipping eqmm-0.png: Expected 4 parts, got 5.
# Skipping gzsv58-0.png: Expected 6 parts, got 5.
# Skipping auijw0-0.png: Expected 6 parts, got 2.
# Skipping s0r5bi-0.png: Expected 6 parts, got 8.
# Skipping jniucu-0.png: Expected 6 parts, got 9.
# Skipping 88py-0.png: Expected 4 parts, got 10.
# Skipping 2hr9d9-0.png: Expected 6 parts, got 10.
# Skipping 3k0n3pad-0.png: Expected 8 parts, got 0.
# Skipping wtptlsfb-0.png: Expected 8 parts, got 7.
# Skipping op2sa-0.png: Expected 5 parts, got 2.
# Skipping m1el7ggi-0.png: Expected 8 parts, got 6.
# Skipping 57s14-0.png: Expected 5 parts, got 3.
# Skipping lsxla-0.png: Expected 5 parts, got 0.
# Skipping c0axp6o-0.png: Expected 7 parts, got 10.
# Skipping orcbf-0.png: Expected 5 parts, got 0.
# Skipping 0vopim-0.png: Expected 6 parts, got 8.
# Skipping 2ogcaj-0.png: Expected 6 parts, got 4.
# Skipping 7nxwy-0.png: Expected 5 parts, got 3.
# Skipping vseps0-0.png: Expected 6 parts, got 0.
# Skipping 39em-0.png: Expected 4 parts, got 3.
# Skipping 29k2a-0.png: Expected 5 parts, got 0.
# Skipping endgv7-0.png: Expected 6 parts, got 2.
# Skipping 6l1aljwp-0.png: Expected 8 parts, got 3.
# Skipping suv8wrs-0.png: Expected 7 parts, got 6.
# Skipping n0hcy-0.png: Expected 5 parts, got 0.
# Skipping 6od31q-0.png: Expected 6 parts, got 3.
# Skipping 1jnus8-0.png: Expected 6 parts, got 7.
# Skipping azn2jroe-0.png: Expected 8 parts, got 0.
# Skipping 0wczk9o8-0.png: Expected 8 parts, got 2.
# Skipping env5d-0.png: Expected 5 parts, got 2.
# Skipping q64sp-0.png: Expected 5 parts, got 0.
# Skipping vrd63n-0.png: Expected 6 parts, got 7.
# Skipping yf1skt-0.png: Expected 6 parts, got 0.
# Skipping sy8gspl-0.png: Expected 7 parts, got 2.
# Skipping n0vq-0.png: Expected 4 parts, got 2.
# Skipping fbs39-0.png: Expected 5 parts, got 0.
# Skipping ywurlaja-0.png: Expected 8 parts, got 7.
# Skipping ca1td7e-0.png: Expected 7 parts, got 2.
# Skipping f7xtzu-0.png: Expected 6 parts, got 7.
# Skipping jrr5n-0.png: Expected 5 parts, got 7.
# Skipping dt01-0.png: Expected 4 parts, got 0.
# Skipping i4ejkg-0.png: Expected 6 parts, got 5.
# Skipping xxblrq9s-0.png: Expected 8 parts, got 10.
# Skipping scwj6qac-0.png: Expected 8 parts, got 11.
# Skipping mrtcx-0.png: Expected 5 parts, got 4.
# Skipping hz3qcw-0.png: Expected 6 parts, got 0.
# Skipping c5cj-0.png: Expected 4 parts, got 0.
# Skipping les8-0.png: Expected 4 parts, got 0.
# Skipping emggqtz-0.png: Expected 7 parts, got 14.
# Skipping xwgvm-0.png: Expected 5 parts, got 4.
# Skipping fvlsb-0.png: Expected 5 parts, got 7.
# Skipping ll1y-0.png: Expected 4 parts, got 1.
# Skipping t2ec2e-0.png: Expected 6 parts, got 7.
# Skipping w3wo2-0.png: Expected 5 parts, got 9.
# Skipping gq1x558-0.png: Expected 7 parts, got 0.
# Skipping fx1divs-0.png: Expected 7 parts, got 5.
# Skipping nccdj42-0.png: Expected 7 parts, got 6.
# Skipping 50rknq-0.png: Expected 6 parts, got 4.
# Skipping 63xvslow-0.png: Expected 8 parts, got 7.
# Skipping pk0r-0.png: Expected 4 parts, got 1.
# Skipping lh019d-0.png: Expected 6 parts, got 3.
# Skipping 32917thd-0.png: Expected 8 parts, got 0.
# Skipping zf1s4-0.png: Expected 5 parts, got 3.
# Skipping 4xqp4g-0.png: Expected 6 parts, got 5.
# Skipping fxd87i-0.png: Expected 6 parts, got 5.
# Skipping l72bbvv4-0.png: Expected 8 parts, got 9.
# Skipping spfq-0.png: Expected 4 parts, got 3.
# Skipping 1mijuxy-0.png: Expected 7 parts, got 5.
# Skipping 07smvpl-0.png: Expected 7 parts, got 6.
# Skipping k4qb-0.png: Expected 4 parts, got 0.
# Skipping 0wwhwf-0.png: Expected 6 parts, got 5.
# Skipping 1vbc15z-0.png: Expected 7 parts, got 1.
# Skipping aqdlgv9-0.png: Expected 7 parts, got 6.
# Skipping i8jn-0.png: Expected 4 parts, got 3.
# Skipping panbwwn-0.png: Expected 7 parts, got 1.
# Skipping ggxxb1-0.png: Expected 6 parts, got 5.
# Skipping h8e6p-0.png: Expected 5 parts, got 0.
# Skipping oqryn-0.png: Expected 5 parts, got 0.
# Skipping e7f2zg-0.png: Expected 6 parts, got 7.
# Skipping jeh265bm-0.png: Expected 8 parts, got 1.
# Skipping 440cq-0.png: Expected 5 parts, got 9.
# Skipping gevq89j1-0.png: Expected 8 parts, got 13.
# Skipping h9qn90x0-0.png: Expected 8 parts, got 3.
# Skipping 4mb632-0.png: Expected 6 parts, got 0.
# Skipping dw5iz8-0.png: Expected 6 parts, got 10.
# Skipping o7c24c2-0.png: Expected 7 parts, got 16.
# Skipping luwh3-0.png: Expected 5 parts, got 6.
# Skipping m7gxu6u-0.png: Expected 7 parts, got 10.
# Skipping t45da-0.png: Expected 5 parts, got 4.
# Skipping 0lov-0.png: Expected 4 parts, got 3.
# Skipping ymva5s55-0.png: Expected 8 parts, got 9.
# Skipping i45h2-0.png: Expected 5 parts, got 2.
# Skipping 9lhs3-0.png: Expected 5 parts, got 4.
# Skipping 7fnlfb4t-0.png: Expected 8 parts, got 6.
# Skipping j4uk1hha-0.png: Expected 8 parts, got 9.
# Skipping qygn-0.png: Expected 4 parts, got 0.
# Skipping axmv78k-0.png: Expected 7 parts, got 0.
# Skipping 1g02nte-0.png: Expected 7 parts, got 5.
# Skipping 95cld-0.png: Expected 5 parts, got 7.
# Skipping xdwmowd-0.png: Expected 7 parts, got 2.
# Skipping lecmgsre-0.png: Expected 8 parts, got 9.
# Skipping bs4e-0.png: Expected 4 parts, got 0.
# Skipping d6564x-0.png: Expected 6 parts, got 5.
# Skipping o8to93-0.png: Expected 6 parts, got 0.
# Skipping dsc30-0.png: Expected 5 parts, got 1.
# Skipping 4wy55-0.png: Expected 5 parts, got 4.
# Skipping g47ff-0.png: Expected 5 parts, got 0.
# Skipping hgwxg-0.png: Expected 5 parts, got 9.
# Skipping p4oj4-0.png: Expected 5 parts, got 10.
# Skipping ihcir0z-0.png: Expected 7 parts, got 6.
# Skipping df99hi2-0.png: Expected 7 parts, got 10.
# Skipping ld20x-0.png: Expected 5 parts, got 4.
# Skipping aiomvg-0.png: Expected 6 parts, got 5.
# Skipping s9tfav-0.png: Expected 6 parts, got 5.
# Skipping pt21-0.png: Expected 4 parts, got 0.
# Skipping 6ks0nbja-0.png: Expected 8 parts, got 9.
# Skipping qybzy5g-0.png: Expected 7 parts, got 0.
# Skipping 369b4-0.png: Expected 5 parts, got 6.
# Skipping jgxn19-0.png: Expected 6 parts, got 11.
# Skipping wtvaivr-0.png: Expected 7 parts, got 5.
# Skipping p1gcp-0.png: Expected 5 parts, got 3.
# Skipping hd2f9h06-0.png: Expected 8 parts, got 7.
# Skipping x7ru6bb-0.png: Expected 7 parts, got 6.
# Skipping 5t6g-0.png: Expected 4 parts, got 2.
# Skipping 9wy7o0l-0.png: Expected 7 parts, got 8.
# Skipping 93s68fxh-0.png: Expected 8 parts, got 12.
# Skipping bo56c-0.png: Expected 5 parts, got 8.
# Skipping 6e5ax-0.png: Expected 5 parts, got 6.
# Skipping rh7al4-0.png: Expected 6 parts, got 1.
# Skipping s1he2-0.png: Expected 5 parts, got 3.
# Skipping 7q8888-0.png: Expected 6 parts, got 8.
# Skipping lae1mbyf-0.png: Expected 8 parts, got 3.
# Skipping wb2q-0.png: Expected 4 parts, got 0.
# Skipping bmtlc-0.png: Expected 5 parts, got 0.
# Skipping lhilaj-0.png: Expected 6 parts, got 5.
# Skipping u7pu-0.png: Expected 4 parts, got 3.
# Skipping 2qzvpp-0.png: Expected 6 parts, got 4.
# Skipping yl55oswh-0.png: Expected 8 parts, got 9.
# Skipping 07zdo-0.png: Expected 5 parts, got 4.
# Skipping 854d4-0.png: Expected 5 parts, got 0.
# Skipping srawhd-0.png: Expected 6 parts, got 4.
# Skipping hrgvp2t-0.png: Expected 7 parts, got 5.
# Skipping sar2j25a-0.png: Expected 8 parts, got 7.
# Skipping fj57-0.png: Expected 4 parts, got 2.
# Skipping beb35hd-0.png: Expected 7 parts, got 10.
# Skipping wmx8-0.png: Expected 4 parts, got 5.
# Skipping dmsl-0.png: Expected 4 parts, got 1.
# Skipping s7p3mm5-0.png: Expected 7 parts, got 11.
# Skipping bqko95-0.png: Expected 6 parts, got 7.
# Skipping rgcr6h4v-0.png: Expected 8 parts, got 11.
# Skipping 6uno-0.png: Expected 4 parts, got 6.
# Skipping va10u75b-0.png: Expected 8 parts, got 4.
# Skipping 8pfi4-0.png: Expected 5 parts, got 2.
# Skipping haqq6lx-0.png: Expected 7 parts, got 0.
# Skipping f5v050lm-0.png: Expected 8 parts, got 6.
# Skipping 06yx8nkv-0.png: Expected 8 parts, got 7.
# Skipping yizefh-0.png: Expected 6 parts, got 4.
# Skipping 7hqqs7-0.png: Expected 6 parts, got 12.
# Skipping jwrb-0.png: Expected 4 parts, got 3.
# Skipping 19hoe-0.png: Expected 5 parts, got 4.
# Skipping 7p6te6h-0.png: Expected 7 parts, got 0.
# Skipping w4tk19h-0.png: Expected 7 parts, got 8.
# Skipping 7twrv-0.png: Expected 5 parts, got 4.
# Skipping lgurn-0.png: Expected 5 parts, got 7.
# Skipping 5w2p2-0.png: Expected 5 parts, got 9.
# Skipping 0qf323yb-0.png: Expected 8 parts, got 9.
# Skipping lq4h-0.png: Expected 4 parts, got 5.
# Skipping 0rvn5xke-0.png: Expected 8 parts, got 5.
# Skipping 569lml-0.png: Expected 6 parts, got 0.
# Skipping 3tvbwkj-0.png: Expected 7 parts, got 0.
# Skipping 6yxdy-0.png: Expected 5 parts, got 6.
# Skipping afu4n-0.png: Expected 5 parts, got 6.
# Skipping oz3h-0.png: Expected 4 parts, got 2.
# Skipping iy5v-0.png: Expected 4 parts, got 3.
# Skipping 21y76j6-0.png: Expected 7 parts, got 0.
# Skipping sltmu3i-0.png: Expected 7 parts, got 0.
# Skipping 1wpkup-0.png: Expected 6 parts, got 0.
# Skipping broehy23-0.png: Expected 8 parts, got 13.
# Skipping 329cx08-0.png: Expected 7 parts, got 0.
# Skipping j0oxw3q7-0.png: Expected 8 parts, got 9.
# Skipping ijv1-0.png: Expected 4 parts, got 1.
# Skipping e9nhvc-0.png: Expected 6 parts, got 0.
# Skipping 4i669we-0.png: Expected 7 parts, got 1.
# Skipping 9do065v-0.png: Expected 7 parts, got 2.
# Skipping m0l7c-0.png: Expected 5 parts, got 3.
# Skipping 0kxu0w-0.png: Expected 6 parts, got 0.
# Skipping 8mcwv-0.png: Expected 5 parts, got 0.
# Skipping q3nihnf-0.png: Expected 7 parts, got 9.
# Skipping yvhei-0.png: Expected 5 parts, got 4.
# Skipping uf31dw21-0.png: Expected 8 parts, got 6.
# Skipping dxrs1r-0.png: Expected 6 parts, got 1.
# Skipping v5wya9z-0.png: Expected 7 parts, got 2.
# Skipping w53ztkz-0.png: Expected 7 parts, got 8.
# Skipping 25b4edqd-0.png: Expected 8 parts, got 6.
# Skipping hvvzh1-0.png: Expected 6 parts, got 2.
# Skipping 3sksn-0.png: Expected 5 parts, got 2.
# Skipping 7brd8h00-0.png: Expected 8 parts, got 4.
# Skipping om9t6d-0.png: Expected 6 parts, got 4.
# Skipping g1c0dhgw-0.png: Expected 8 parts, got 4.
# Skipping r8im-0.png: Expected 4 parts, got 5.
# Skipping 6sre2n-0.png: Expected 6 parts, got 2.
# Skipping x9ukcz3t-0.png: Expected 8 parts, got 0.
# Skipping k62r-0.png: Expected 4 parts, got 0.
# Skipping 0xxukpj-0.png: Expected 7 parts, got 5.
# Skipping 5u3y3t-0.png: Expected 6 parts, got 5.
# Skipping k7g4n-0.png: Expected 5 parts, got 0.
# Skipping ifg6ly-0.png: Expected 6 parts, got 8.
# Skipping e7ll4ytu-0.png: Expected 8 parts, got 9.
# Skipping ht4n0qk-0.png: Expected 7 parts, got 6.
# Skipping rsk019k4-0.png: Expected 8 parts, got 10.
# Skipping x5hzzzf-0.png: Expected 7 parts, got 5.
# Skipping ak8p9t-0.png: Expected 6 parts, got 5.
# Skipping gqp4i-0.png: Expected 5 parts, got 6.
# Skipping gqecdru-0.png: Expected 7 parts, got 8.
# Skipping orzpjyd0-0.png: Expected 8 parts, got 0.
# Skipping qxuo-0.png: Expected 4 parts, got 5.
# Skipping cu6ju3-0.png: Expected 6 parts, got 8.
# Skipping tq670mv5-0.png: Expected 8 parts, got 0.
# Skipping 15t4an-0.png: Expected 6 parts, got 8.
# Skipping j88ticou-0.png: Expected 8 parts, got 3.
# Skipping j33j2-0.png: Expected 5 parts, got 8.
# Skipping 8yv00c-0.png: Expected 6 parts, got 0.
# Skipping ejw4e-0.png: Expected 5 parts, got 0.
# Skipping kuzm4-0.png: Expected 5 parts, got 2.
# Skipping i0c8ehrm-0.png: Expected 8 parts, got 3.
# Skipping qru5nm-0.png: Expected 6 parts, got 11.
# Skipping hhm4t7h-0.png: Expected 7 parts, got 8.
# Skipping h5ft1-0.png: Expected 5 parts, got 6.
# Skipping v1ni-0.png: Expected 4 parts, got 2.
# Skipping jlgsevt-0.png: Expected 7 parts, got 6.
# Skipping nhg9-0.png: Expected 4 parts, got 0.
# Skipping 4va4qss-0.png: Expected 7 parts, got 8.
# Skipping a7w16-0.png: Expected 5 parts, got 3.
# Skipping tm9kmer-0.png: Expected 7 parts, got 0.
# Skipping 68apdma-0.png: Expected 7 parts, got 8.
# Skipping 6xl3aw-0.png: Expected 6 parts, got 7.
# Skipping drfoa-0.png: Expected 5 parts, got 2.
# Skipping 3amh-0.png: Expected 4 parts, got 2.
# Skipping ezqs43ph-0.png: Expected 8 parts, got 5.
# Skipping dsgrtai-0.png: Expected 7 parts, got 6.
# Skipping 3j9gcdp-0.png: Expected 7 parts, got 1.
# Skipping a1x6gze-0.png: Expected 7 parts, got 1.
# Skipping jiznmz-0.png: Expected 6 parts, got 1.
# Skipping qzo99n7e-0.png: Expected 8 parts, got 13.
# Skipping o30sk-0.png: Expected 5 parts, got 0.
# Skipping 99xgc9m2-0.png: Expected 8 parts, got 7.
# Skipping kh8gqa-0.png: Expected 6 parts, got 8.
# Skipping 1nov0r3o-0.png: Expected 8 parts, got 10.
# Skipping dpfh9-0.png: Expected 5 parts, got 3.
# Skipping rapb-0.png: Expected 4 parts, got 1.
# Skipping 33naz-0.png: Expected 5 parts, got 2.
# Skipping wcum5y-0.png: Expected 6 parts, got 7.
# Skipping dqn5o-0.png: Expected 5 parts, got 1.
# Skipping 0kl57-0.png: Expected 5 parts, got 4.
# Skipping od49s5t-0.png: Expected 7 parts, got 9.
# Skipping 8ptz473-0.png: Expected 7 parts, got 5.
# Skipping 6ocl0d1-0.png: Expected 7 parts, got 6.
# Skipping y50vlby-0.png: Expected 7 parts, got 1.
# Skipping qv1b-0.png: Expected 4 parts, got 8.
# Skipping 00o47-0.png: Expected 5 parts, got 7.
# Skipping oqtqd59-0.png: Expected 7 parts, got 4.
# Skipping cmrau12w-0.png: Expected 8 parts, got 6.
# Skipping 0x2b-0.png: Expected 4 parts, got 1.
# Skipping 1udt-0.png: Expected 4 parts, got 2.
# Skipping 7s265-0.png: Expected 5 parts, got 4.
# Skipping w89e-0.png: Expected 4 parts, got 5.
# Skipping mgdla2-0.png: Expected 6 parts, got 0.
# Skipping o0wx0vh-0.png: Expected 7 parts, got 9.
# Skipping o3rpt-0.png: Expected 5 parts, got 7.
# Skipping py0kh-0.png: Expected 5 parts, got 4.
# Skipping 8cxf97n1-0.png: Expected 8 parts, got 5.
# Skipping v9h5gyb-0.png: Expected 7 parts, got 8.
# Skipping a67mw6w6-0.png: Expected 8 parts, got 10.
# Skipping le9ut-0.png: Expected 5 parts, got 7.
# Skipping x37wgc3-0.png: Expected 7 parts, got 1.
# Skipping 5ai8ko-0.png: Expected 6 parts, got 7.
# Skipping xlwwmr-0.png: Expected 6 parts, got 2.
# Skipping omm2yo-0.png: Expected 6 parts, got 0.
# Skipping i40a6-0.png: Expected 5 parts, got 6.
# Skipping dymxr-0.png: Expected 5 parts, got 4.
# Skipping 06xg-0.png: Expected 4 parts, got 1.
# Skipping 60j6f-0.png: Expected 5 parts, got 2.
# Skipping io9h-0.png: Expected 4 parts, got 2.
# Skipping p1u5zre-0.png: Expected 7 parts, got 8.
# Skipping 498brbe-0.png: Expected 7 parts, got 0.
# Skipping mwsf7ura-0.png: Expected 8 parts, got 10.
# Skipping 4fw61vc-0.png: Expected 7 parts, got 6.
# Skipping k6oiqhlq-0.png: Expected 8 parts, got 7.
# Skipping kyiyz-0.png: Expected 5 parts, got 8.
# Skipping vueex1o4-0.png: Expected 8 parts, got 10.
# Skipping e5ycb-0.png: Expected 5 parts, got 4.
# Skipping we3ex-0.png: Expected 5 parts, got 0.
# Skipping 74h0lpb-0.png: Expected 7 parts, got 0.
# Skipping p1fi7h3-0.png: Expected 7 parts, got 6.
# Skipping cgku-0.png: Expected 4 parts, got 5.
# Skipping 2at5l1k9-0.png: Expected 8 parts, got 0.
# Skipping y5h7lmio-0.png: Expected 8 parts, got 3.
# Skipping gkz37nn-0.png: Expected 7 parts, got 0.
# Skipping jy7448-0.png: Expected 6 parts, got 10.
# Skipping dtfo-0.png: Expected 4 parts, got 3.
# Skipping izrqif5-0.png: Expected 7 parts, got 8.
# Skipping vda5c-0.png: Expected 5 parts, got 2.
# Skipping 6sdnex1-0.png: Expected 7 parts, got 0.
# Skipping ie1n-0.png: Expected 4 parts, got 3.
# Skipping tuoul-0.png: Expected 5 parts, got 0.
# Skipping q8u74-0.png: Expected 5 parts, got 0.
# Skipping rdme6xyo-0.png: Expected 8 parts, got 4.
# Skipping pnyiab8j-0.png: Expected 8 parts, got 0.
# Skipping om3iu5-0.png: Expected 6 parts, got 7.
# Skipping jx9n6ubl-0.png: Expected 8 parts, got 2.
# Skipping 4kht8-0.png: Expected 5 parts, got 0.
# Skipping xh82f9f7-0.png: Expected 8 parts, got 9.
# Skipping s6w5wq-0.png: Expected 6 parts, got 5.
# Skipping skrrc-0.png: Expected 5 parts, got 0.
# Skipping bsqscu70-0.png: Expected 8 parts, got 9.
# Skipping xg0vobc-0.png: Expected 7 parts, got 8.
# Skipping q9hov1-0.png: Expected 6 parts, got 0.
# Skipping sqyy-0.png: Expected 4 parts, got 2.
# Skipping q4av-0.png: Expected 4 parts, got 3.
# Skipping 8h218ub-0.png: Expected 7 parts, got 1.
# Skipping 2fvrrfg-0.png: Expected 7 parts, got 8.
# Skipping ffua-0.png: Expected 4 parts, got 3.
# Skipping fmli6nsb-0.png: Expected 8 parts, got 14.
# Skipping o3g186f-0.png: Expected 7 parts, got 6.
# Skipping m4bp0wm-0.png: Expected 7 parts, got 1.
# Skipping iw7wtm-0.png: Expected 6 parts, got 0.
# Skipping sc3i-0.png: Expected 4 parts, got 2.
# Skipping bqxqj67-0.png: Expected 7 parts, got 5.
# Skipping 0d6qvz4x-0.png: Expected 8 parts, got 2.
# Skipping rw9mdbn8-0.png: Expected 8 parts, got 6.
# Skipping hp8ca7b-0.png: Expected 7 parts, got 5.
# Skipping hkipzjc-0.png: Expected 7 parts, got 6.
# Skipping 9z4p-0.png: Expected 4 parts, got 2.
# Skipping g3u2v-0.png: Expected 5 parts, got 4.
# Skipping 1nk93g-0.png: Expected 6 parts, got 5.
# Skipping 08xj75-0.png: Expected 6 parts, got 1.
# Skipping n4il-0.png: Expected 4 parts, got 0.
# Skipping afbed1u1-0.png: Expected 8 parts, got 10.
# Skipping ozszvz1-0.png: Expected 7 parts, got 5.
# Skipping h8izw79-0.png: Expected 7 parts, got 5.
# Skipping 9t29noq-0.png: Expected 7 parts, got 12.
# Skipping hvlr3f9y-0.png: Expected 8 parts, got 13.
# Skipping 25927mqe-0.png: Expected 8 parts, got 12.
# Skipping jhob1-0.png: Expected 5 parts, got 4.
# Skipping t272uk-0.png: Expected 6 parts, got 7.
# Skipping 6vwq2ve-0.png: Expected 7 parts, got 6.
# Skipping bvsu9t8-0.png: Expected 7 parts, got 5.
# Skipping 422g0b-0.png: Expected 6 parts, got 10.
# Skipping dy5s36-0.png: Expected 6 parts, got 5.
# Skipping p4v8atio-0.png: Expected 8 parts, got 5.
# Skipping iuzr7-0.png: Expected 5 parts, got 0.
# Skipping rsel3ge8-0.png: Expected 8 parts, got 7.
# Skipping qc61bz-0.png: Expected 6 parts, got 3.
# Skipping r4dutce-0.png: Expected 7 parts, got 0.
# Skipping rvb8o9v-0.png: Expected 7 parts, got 2.
# Skipping sc4ltrv-0.png: Expected 7 parts, got 6.
# Skipping jms4vcf7-0.png: Expected 8 parts, got 2.
# Skipping ai12-0.png: Expected 4 parts, got 1.
# Skipping p4fe-0.png: Expected 4 parts, got 5.
# Skipping ugfl4192-0.png: Expected 8 parts, got 10.
# Skipping hxpar9a-0.png: Expected 7 parts, got 1.
# Skipping 1xk809q-0.png: Expected 7 parts, got 10.
# Skipping mupzvuqx-0.png: Expected 8 parts, got 12.
# Skipping a7yflo7-0.png: Expected 7 parts, got 4.
# Skipping m31nh-0.png: Expected 5 parts, got 6.
# Skipping 78hw61-0.png: Expected 6 parts, got 7.
# Skipping xfzlg-0.png: Expected 5 parts, got 7.
# Skipping qdxgdkk-0.png: Expected 7 parts, got 14.
# Skipping mauq-0.png: Expected 4 parts, got 0.
# Skipping yml9m-0.png: Expected 5 parts, got 2.
# Skipping ygaju-0.png: Expected 5 parts, got 4.
# Skipping 8npspa-0.png: Expected 6 parts, got 3.
# Skipping 1t0y82oj-0.png: Expected 8 parts, got 7.
# Skipping nz89zgfq-0.png: Expected 8 parts, got 0.
# Skipping 638o-0.png: Expected 4 parts, got 0.
# Skipping h8fs-0.png: Expected 4 parts, got 0.
# Skipping ai6hk2b-0.png: Expected 7 parts, got 6.
# Skipping czvnjld-0.png: Expected 7 parts, got 1.
# Skipping z6cg04-0.png: Expected 6 parts, got 4.
# Skipping xnrr-0.png: Expected 4 parts, got 2.
# Skipping 0csa-0.png: Expected 4 parts, got 1.
# Skipping i3bq-0.png: Expected 4 parts, got 3.
# Skipping fvdaomqc-0.png: Expected 8 parts, got 5.
# Skipping 1zsaac-0.png: Expected 6 parts, got 0.
# Skipping yoj2-0.png: Expected 4 parts, got 5.
# Skipping 441bz-0.png: Expected 5 parts, got 7.
# Skipping 9ljr9-0.png: Expected 5 parts, got 10.
# Skipping jpye-0.png: Expected 4 parts, got 3.
# Skipping ku6hg-0.png: Expected 5 parts, got 4.
# Skipping jtncj-0.png: Expected 5 parts, got 3.
# Skipping yqeg-0.png: Expected 4 parts, got 8.
# Skipping kygo3-0.png: Expected 5 parts, got 4.
# Skipping 7m4dsw-0.png: Expected 6 parts, got 4.
# Skipping 20rym-0.png: Expected 5 parts, got 4.
# Skipping r56n1n-0.png: Expected 6 parts, got 0.
# Skipping gobjzwo-0.png: Expected 7 parts, got 0.
# Skipping 1yvb-0.png: Expected 4 parts, got 5.
# Skipping 6op8-0.png: Expected 4 parts, got 0.
# Skipping 3m8al-0.png: Expected 5 parts, got 4.
# Skipping 7heenhd-0.png: Expected 7 parts, got 0.
# Skipping qunj-0.png: Expected 4 parts, got 5.
# Skipping 2l2a3-0.png: Expected 5 parts, got 0.
# Skipping oc42gn64-0.png: Expected 8 parts, got 0.
# Skipping 9aeol3h-0.png: Expected 7 parts, got 12.
# Skipping lwppl-0.png: Expected 5 parts, got 4.
# Skipping ibtj-0.png: Expected 4 parts, got 0.
# Skipping 1yyo-0.png: Expected 4 parts, got 5.
# Skipping pda2igde-0.png: Expected 8 parts, got 5.
# Skipping ywwwm-0.png: Expected 5 parts, got 7.
# Skipping hwxmjb-0.png: Expected 6 parts, got 0.
# Skipping 80qxfez1-0.png: Expected 8 parts, got 1.
# Skipping ywmln43-0.png: Expected 7 parts, got 9.
# Skipping 115cip-0.png: Expected 6 parts, got 4.
# Skipping a8eqi-0.png: Expected 5 parts, got 10.
# Skipping 8pvuo2gt-0.png: Expected 8 parts, got 5.
# Skipping e7ee3-0.png: Expected 5 parts, got 1.
# Skipping xwh3nqxx-0.png: Expected 8 parts, got 3.
# Skipping ffy3glsp-0.png: Expected 8 parts, got 9.
# Skipping 6xrf-0.png: Expected 4 parts, got 3.
# Skipping 9t9u1-0.png: Expected 5 parts, got 6.
# Skipping 9hkp78js-0.png: Expected 8 parts, got 1.
# Skipping vlw3lq-0.png: Expected 6 parts, got 1.
# Skipping io26vp4-0.png: Expected 7 parts, got 1.
# Skipping 0n8v9-0.png: Expected 5 parts, got 4.
# Skipping efcpy-0.png: Expected 5 parts, got 6.
# Skipping hbgkwmxy-0.png: Expected 8 parts, got 7.
# Skipping 3s2k5-0.png: Expected 5 parts, got 3.
# Skipping wec58-0.png: Expected 5 parts, got 0.
# Skipping hygee-0.png: Expected 5 parts, got 6.
# Skipping daqbbg84-0.png: Expected 8 parts, got 0.
# Skipping h7e5h-0.png: Expected 5 parts, got 0.
# Skipping 0jl4-0.png: Expected 4 parts, got 0.
# Skipping xp1jmtc-0.png: Expected 7 parts, got 4.
# Skipping 4iu4cjd-0.png: Expected 7 parts, got 5.
# Skipping hb2g1quc-0.png: Expected 8 parts, got 6.
# Skipping 5vd9-0.png: Expected 4 parts, got 2.
# Skipping jvyom0-0.png: Expected 6 parts, got 8.
# Skipping v0h91y-0.png: Expected 6 parts, got 7.
# Skipping o4ienv-0.png: Expected 6 parts, got 1.
# Skipping wh21g4-0.png: Expected 6 parts, got 4.
# Skipping c8wfok00-0.png: Expected 8 parts, got 4.
# Skipping w53w-0.png: Expected 4 parts, got 2.
# Skipping r288-0.png: Expected 4 parts, got 7.
# Skipping tne6if2-0.png: Expected 7 parts, got 4.
# Skipping 6dc54h4-0.png: Expected 7 parts, got 4.
# Skipping 96gvsow-0.png: Expected 7 parts, got 0.
# Skipping aki6-0.png: Expected 4 parts, got 3.
# Skipping 9u6f46c-0.png: Expected 7 parts, got 11.
# Skipping 59xhq-0.png: Expected 5 parts, got 4.
# Skipping xv0ozy3-0.png: Expected 7 parts, got 0.
# Skipping lcuwk6-0.png: Expected 6 parts, got 7.
# Skipping btw6mvzi-0.png: Expected 8 parts, got 7.
# Skipping j74sh7xy-0.png: Expected 8 parts, got 3.
# Skipping v66jx27k-0.png: Expected 8 parts, got 10.
# Skipping nt0h-0.png: Expected 4 parts, got 1.
# Skipping sc1t-0.png: Expected 4 parts, got 3.
# Skipping 41a67-0.png: Expected 5 parts, got 3.
# Skipping 77sbo-0.png: Expected 5 parts, got 4.
# Skipping wsy867-0.png: Expected 6 parts, got 0.
# Skipping jz1of2-0.png: Expected 6 parts, got 11.
# Skipping pebs8msl-0.png: Expected 8 parts, got 0.
# Skipping gxj1fsg-0.png: Expected 7 parts, got 10.
# Skipping rbtd-0.png: Expected 4 parts, got 0.
# Skipping 8qdh-0.png: Expected 4 parts, got 5.
# Skipping kohf0b-0.png: Expected 6 parts, got 5.
# Skipping nz6w6-0.png: Expected 5 parts, got 7.
# Skipping vmquc-0.png: Expected 5 parts, got 3.
# Skipping l12c-0.png: Expected 4 parts, got 0.
# Skipping 0my5m1b-0.png: Expected 7 parts, got 0.
# Skipping e5ha-0.png: Expected 4 parts, got 0.
# Skipping ggnw0us-0.png: Expected 7 parts, got 5.
# Skipping hy83z7q-0.png: Expected 7 parts, got 9.
# Skipping k8c4-0.png: Expected 4 parts, got 8.
# Skipping 7gk0bha-0.png: Expected 7 parts, got 0.
# Skipping sl8w-0.png: Expected 4 parts, got 3.
# Skipping 42x8-0.png: Expected 4 parts, got 1.
# Skipping mzjraw-0.png: Expected 6 parts, got 3.
# Skipping akcs-0.png: Expected 4 parts, got 8.
# Skipping 9rfhh-0.png: Expected 5 parts, got 0.
# Skipping 4x4d2-0.png: Expected 5 parts, got 0.
# Skipping 82vxl6vy-0.png: Expected 8 parts, got 1.
# Skipping dkxo-0.png: Expected 4 parts, got 0.
# Skipping dq3by0v-0.png: Expected 7 parts, got 11.
# Skipping wq1w-0.png: Expected 4 parts, got 3.
# Skipping c9cb-0.png: Expected 4 parts, got 5.
# Skipping 0sle-0.png: Expected 4 parts, got 2.
# Skipping ysv1jv2-0.png: Expected 7 parts, got 3.
# Skipping o8jm-0.png: Expected 4 parts, got 5.
# Skipping 9abwl0a-0.png: Expected 7 parts, got 5.
# Skipping u5rx8w4-0.png: Expected 7 parts, got 8.
# Skipping fu02t-0.png: Expected 5 parts, got 2.
# Skipping kx3a-0.png: Expected 4 parts, got 0.
# Skipping l6smu2-0.png: Expected 6 parts, got 8.
# Skipping f3dqdsi-0.png: Expected 7 parts, got 8.
# Skipping py8x-0.png: Expected 4 parts, got 7.
# Skipping s0v7n-0.png: Expected 5 parts, got 0.
# Skipping dew6-0.png: Expected 4 parts, got 6.
# Skipping qjpzqyx-0.png: Expected 7 parts, got 6.
# Skipping ky2w-0.png: Expected 4 parts, got 5.
# Skipping 2wf8ae3g-0.png: Expected 8 parts, got 6.
# Skipping 5zge-0.png: Expected 4 parts, got 3.
# Skipping 6erqxw2-0.png: Expected 7 parts, got 2.
# Skipping h97e2we-0.png: Expected 7 parts, got 6.
# Skipping y90mbh-0.png: Expected 6 parts, got 0.
# Skipping ai935-0.png: Expected 5 parts, got 3.
# Skipping 6fhd3k-0.png: Expected 6 parts, got 5.
# Skipping vlwit1ft-0.png: Expected 8 parts, got 0.
# Skipping 7iv4-0.png: Expected 4 parts, got 3.
# Skipping z56ar6-0.png: Expected 6 parts, got 5.
# Skipping 2x65-0.png: Expected 4 parts, got 2.
# Skipping 4ih1w4-0.png: Expected 6 parts, got 7.
# Skipping 2dkp9x-0.png: Expected 6 parts, got 4.
# Skipping qo7o-0.png: Expected 4 parts, got 7.
# Skipping ly3bvt-0.png: Expected 6 parts, got 2.
# Skipping otwx-0.png: Expected 4 parts, got 3.
# Skipping ozawr6-0.png: Expected 6 parts, got 7.
# Skipping hihs-0.png: Expected 4 parts, got 0.
# Skipping hd6za8-0.png: Expected 6 parts, got 2.
# Skipping 68slr50-0.png: Expected 7 parts, got 6.
# Skipping 44y4ih3-0.png: Expected 7 parts, got 5.
# Skipping pmyv-0.png: Expected 4 parts, got 6.
# Skipping cdz1t-0.png: Expected 5 parts, got 0.
# Skipping l0axq0o-0.png: Expected 7 parts, got 8.
# Skipping 2aofi-0.png: Expected 5 parts, got 2.
# Skipping eido-0.png: Expected 4 parts, got 0.
# Skipping w7in-0.png: Expected 4 parts, got 5.
# Skipping 35mziw-0.png: Expected 6 parts, got 9.
# Skipping fjre-0.png: Expected 4 parts, got 0.
# Skipping md308sm0-0.png: Expected 8 parts, got 0.
# Skipping 6tch63a-0.png: Expected 7 parts, got 8.
# Skipping u89h-0.png: Expected 4 parts, got 2.
# Skipping 1vgz-0.png: Expected 4 parts, got 0.
# Skipping i8cc6-0.png: Expected 5 parts, got 4.
# Skipping y0qo-0.png: Expected 4 parts, got 0.
# Skipping qawvz-0.png: Expected 5 parts, got 1.
# Skipping fe7ous-0.png: Expected 6 parts, got 5.
# Skipping nbsei-0.png: Expected 5 parts, got 0.
# Skipping qv5fkrv-0.png: Expected 7 parts, got 0.
# Skipping sn3bhmq-0.png: Expected 7 parts, got 0.
# Skipping b1em6-0.png: Expected 5 parts, got 0.
# Skipping lxq7k-0.png: Expected 5 parts, got 4.
# Skipping ib0hh-0.png: Expected 5 parts, got 0.
# Skipping lquft3d-0.png: Expected 7 parts, got 0.
# Skipping 6toeeyqt-0.png: Expected 8 parts, got 7.
# Skipping 8sq2w6z-0.png: Expected 7 parts, got 0.
# Skipping 2m4e97yo-0.png: Expected 8 parts, got 9.
# Skipping ciyrfilw-0.png: Expected 8 parts, got 1.
# Skipping 8q58-0.png: Expected 4 parts, got 5.
# Skipping r51h42v-0.png: Expected 7 parts, got 8.
# Skipping f8ytwd7u-0.png: Expected 8 parts, got 6.
# Skipping 3wcsp3-0.png: Expected 6 parts, got 10.
# Skipping htwa-0.png: Expected 4 parts, got 3.
# Skipping 69et9-0.png: Expected 5 parts, got 0.
# Skipping j6kwpb-0.png: Expected 6 parts, got 5.
# Skipping o6k3o5-0.png: Expected 6 parts, got 10.
# Skipping zu313a-0.png: Expected 6 parts, got 5.
# Skipping kkdci6-0.png: Expected 6 parts, got 2.
# Skipping g7wi9ea-0.png: Expected 7 parts, got 5.
# Skipping zpj6n15-0.png: Expected 7 parts, got 6.
# Skipping u81wurpa-0.png: Expected 8 parts, got 9.
# Skipping gf6j-0.png: Expected 4 parts, got 6.
# Skipping 5poop-0.png: Expected 5 parts, got 4.
# Skipping i4pi8h-0.png: Expected 6 parts, got 7.
# Skipping tiim-0.png: Expected 4 parts, got 0.
# Skipping 5edl-0.png: Expected 4 parts, got 0.
# Skipping 227hgav-0.png: Expected 7 parts, got 15.
# Skipping 7y0cynw-0.png: Expected 7 parts, got 9.
# Skipping fyjy433o-0.png: Expected 8 parts, got 10.
# Skipping 0m5gzz-0.png: Expected 6 parts, got 5.
# Skipping topi-0.png: Expected 4 parts, got 0.
# Skipping vpdug7-0.png: Expected 6 parts, got 0.
# Skipping 9173l-0.png: Expected 5 parts, got 4.
# Skipping 30u6-0.png: Expected 4 parts, got 5.
# Skipping 6j50zg-0.png: Expected 6 parts, got 1.
# Skipping 4194-0.png: Expected 4 parts, got 7.
# Skipping hupgnmy-0.png: Expected 7 parts, got 10.
# Skipping eyiy30-0.png: Expected 6 parts, got 5.
# Skipping x2hgsu-0.png: Expected 6 parts, got 7.
# Skipping 0ihk7bk-0.png: Expected 7 parts, got 3.
# Skipping nhig-0.png: Expected 4 parts, got 3.
# Skipping 3zb67dd6-0.png: Expected 8 parts, got 7.
# Skipping oqtd8il1-0.png: Expected 8 parts, got 2.
# Skipping dn71uoy4-0.png: Expected 8 parts, got 2.
# Skipping 9vmzjqlt-0.png: Expected 8 parts, got 1.
# Skipping ag9g9-0.png: Expected 5 parts, got 4.
# Skipping ogx4mnx4-0.png: Expected 8 parts, got 7.
# Skipping bvrejwz-0.png: Expected 7 parts, got 6.
# Skipping mjh78bc-0.png: Expected 7 parts, got 11.
# Skipping 0hox6-0.png: Expected 5 parts, got 4.
# Skipping c91xf1o-0.png: Expected 7 parts, got 6.
# Skipping fxm7aeb-0.png: Expected 7 parts, got 3.
# Skipping jwbms-0.png: Expected 5 parts, got 4.
# Skipping rxf9ls5-0.png: Expected 7 parts, got 1.
# Skipping g1leisst-0.png: Expected 8 parts, got 3.
# Skipping wqvb7-0.png: Expected 5 parts, got 0.
# Skipping ay5a-0.png: Expected 4 parts, got 2.
# Skipping cic34bpi-0.png: Expected 8 parts, got 6.
# Skipping zj7qxhs-0.png: Expected 7 parts, got 6.
# Skipping tuarq-0.png: Expected 5 parts, got 0.
# Skipping 3pp1pc-0.png: Expected 6 parts, got 5.
# Skipping niq1q-0.png: Expected 5 parts, got 4.
# Skipping w5856q-0.png: Expected 6 parts, got 3.
# Skipping dgh2ddey-0.png: Expected 8 parts, got 4.
# Skipping xcr6yg-0.png: Expected 6 parts, got 3.
# Skipping sp43pxpi-0.png: Expected 8 parts, got 10.
# Skipping m8lit3g3-0.png: Expected 8 parts, got 5.
# Skipping u1b8lpv-0.png: Expected 7 parts, got 5.
# Skipping 2cg2og8e-0.png: Expected 8 parts, got 4.
# Skipping 38ccou-0.png: Expected 6 parts, got 4.
# Skipping 6829y4j-0.png: Expected 7 parts, got 13.
# Skipping f9wzjg7q-0.png: Expected 8 parts, got 0.
# Skipping 5fywtys-0.png: Expected 7 parts, got 1.
# Skipping 9e83qa-0.png: Expected 6 parts, got 10.
# Skipping 0gfm9dbw-0.png: Expected 8 parts, got 0.
# Skipping pdvo1eu-0.png: Expected 7 parts, got 6.
# Skipping 59nl1yr5-0.png: Expected 8 parts, got 0.
# Skipping 3lkh9-0.png: Expected 5 parts, got 6.
# Skipping w7uby78-0.png: Expected 7 parts, got 9.
# Skipping 5ggh8o-0.png: Expected 6 parts, got 0.
# Skipping 96b7kz4p-0.png: Expected 8 parts, got 12.
# Skipping x1oge-0.png: Expected 5 parts, got 2.
# Skipping hcck03w9-0.png: Expected 8 parts, got 6.
# Skipping yfkx4v1-0.png: Expected 7 parts, got 3.
# Skipping dtryz-0.png: Expected 5 parts, got 0.
# Skipping inl0y9o-0.png: Expected 7 parts, got 4.
# Skipping fy6k5lx-0.png: Expected 7 parts, got 6.
# Skipping 64wwh3j-0.png: Expected 7 parts, got 13.
# Skipping 8o8379d-0.png: Expected 7 parts, got 3.
# Skipping fwv6pb-0.png: Expected 6 parts, got 0.
# Skipping 1pbhtt6u-0.png: Expected 8 parts, got 9.
# Skipping wf0qh7-0.png: Expected 6 parts, got 1.
# Skipping ft5xxtan-0.png: Expected 8 parts, got 0.
# Skipping m8rweg4g-0.png: Expected 8 parts, got 11.
# Skipping qq6c4c-0.png: Expected 6 parts, got 8.
# Skipping bqx81ij-0.png: Expected 7 parts, got 0.
# Skipping y07ce-0.png: Expected 5 parts, got 0.
# Skipping kkizahl-0.png: Expected 7 parts, got 3.
# Skipping vjen4a-0.png: Expected 6 parts, got 5.
# Skipping 2lt1-0.png: Expected 4 parts, got 3.
# Skipping r29d2-0.png: Expected 5 parts, got 2.
# Skipping e80tdlt-0.png: Expected 7 parts, got 0.
# Skipping priw-0.png: Expected 4 parts, got 1.
# Skipping htd6-0.png: Expected 4 parts, got 3.
# Skipping rs1z3-0.png: Expected 5 parts, got 2.
# Skipping rf72xa-0.png: Expected 6 parts, got 0.
# Skipping jpe8-0.png: Expected 4 parts, got 2.
# Skipping ufwcg-0.png: Expected 5 parts, got 8.
# Skipping 32o7-0.png: Expected 4 parts, got 1.
# Skipping dys8qz5r-0.png: Expected 8 parts, got 12.
# Skipping wsyakkt-0.png: Expected 7 parts, got 0.
# Skipping 85i10jy-0.png: Expected 7 parts, got 0.
# Skipping 7qy4-0.png: Expected 4 parts, got 3.
# Skipping ei8c8mhy-0.png: Expected 8 parts, got 1.
# Skipping cdqbfb4-0.png: Expected 7 parts, got 1.
# Skipping mmnyyde-0.png: Expected 7 parts, got 8.
# Skipping i4sg1hp-0.png: Expected 7 parts, got 8.
# Skipping 9o8hs65-0.png: Expected 7 parts, got 11.
# Skipping xl2h-0.png: Expected 4 parts, got 3.
# Skipping h8emd-0.png: Expected 5 parts, got 4.
# Skipping qexa4dk-0.png: Expected 7 parts, got 8.
# Skipping 0gwk-0.png: Expected 4 parts, got 5.
# Skipping cc3ezr-0.png: Expected 6 parts, got 1.
# Skipping 4jl9-0.png: Expected 4 parts, got 3.
# Skipping s7j0i5-0.png: Expected 6 parts, got 3.
# Skipping lhkkxxb-0.png: Expected 7 parts, got 2.
# Skipping 8ggxk-0.png: Expected 5 parts, got 2.
# Skipping i1b2s-0.png: Expected 5 parts, got 4.
# Skipping cawx-0.png: Expected 4 parts, got 7.
# Skipping 6i18-0.png: Expected 4 parts, got 0.
# Skipping xm23a-0.png: Expected 5 parts, got 0.
# Skipping 81x9da4a-0.png: Expected 8 parts, got 0.
# Skipping 8ijm4l-0.png: Expected 6 parts, got 1.
# Skipping w85wq0mr-0.png: Expected 8 parts, got 9.
# Skipping d6z17-0.png: Expected 5 parts, got 7.
# Skipping rmtsp1w1-0.png: Expected 8 parts, got 0.
# Skipping pdpkbaxg-0.png: Expected 8 parts, got 0.
# Skipping o43h15z8-0.png: Expected 8 parts, got 5.
# Skipping 67chez9-0.png: Expected 7 parts, got 2.
# Skipping dmurgvfm-0.png: Expected 8 parts, got 1.
# Skipping z4qj18-0.png: Expected 6 parts, got 0.
# Skipping 8gxnsua3-0.png: Expected 8 parts, got 9.
# Skipping 4pafxd-0.png: Expected 6 parts, got 5.
# Skipping p5o9jrn9-0.png: Expected 8 parts, got 0.
# Skipping v1eynvy1-0.png: Expected 8 parts, got 0.
# Skipping lwvrpx-0.png: Expected 6 parts, got 7.
# Skipping ptfmc0-0.png: Expected 6 parts, got 0.
# Skipping 0no6-0.png: Expected 4 parts, got 8.
# Skipping pieg-0.png: Expected 4 parts, got 2.
# Skipping db1htemj-0.png: Expected 8 parts, got 0.
# Skipping 71pk-0.png: Expected 4 parts, got 5.
# Skipping ztlig-0.png: Expected 5 parts, got 4.
# Skipping c90guh0-0.png: Expected 7 parts, got 11.
# Skipping 8fjn-0.png: Expected 4 parts, got 0.
# Skipping o9k9tv-0.png: Expected 6 parts, got 4.
# Skipping l2y1-0.png: Expected 4 parts, got 6.
# Skipping 473dzh5-0.png: Expected 7 parts, got 5.
# Skipping 3kyutzk-0.png: Expected 7 parts, got 6.
# Skipping zbux3-0.png: Expected 5 parts, got 4.
# Skipping aix8-0.png: Expected 4 parts, got 0.
# Skipping eml3wo-0.png: Expected 6 parts, got 7.
# Skipping 1s8ii3-0.png: Expected 6 parts, got 2.
# Skipping bhral-0.png: Expected 5 parts, got 0.
# Skipping 8qvn-0.png: Expected 4 parts, got 6.
# Skipping wiv1fq-0.png: Expected 6 parts, got 0.
# Skipping 7uoz9keb-0.png: Expected 8 parts, got 7.
# Skipping oxdb-0.png: Expected 4 parts, got 1.
# Skipping yruoe-0.png: Expected 5 parts, got 6.
# Skipping g8elpi-0.png: Expected 6 parts, got 7.
# Skipping lgjj-0.png: Expected 4 parts, got 5.
# Skipping j0go-0.png: Expected 4 parts, got 0.
# Skipping k3zwfi8-0.png: Expected 7 parts, got 5.
# Skipping wk6ll3-0.png: Expected 6 parts, got 16.
# Skipping stice9p-0.png: Expected 7 parts, got 6.
# Skipping y47br5d3-0.png: Expected 8 parts, got 0.
# Skipping 76jot9a3-0.png: Expected 8 parts, got 7.
# Skipping 71ag-0.png: Expected 4 parts, got 5.
# Skipping df3k-0.png: Expected 4 parts, got 0.
# Skipping oocoa2j-0.png: Expected 7 parts, got 9.
# Skipping jf3x-0.png: Expected 4 parts, got 1.
# Skipping 3yc6be-0.png: Expected 6 parts, got 7.
# Skipping ultf5-0.png: Expected 5 parts, got 2.
# Skipping g67fpcz3-0.png: Expected 8 parts, got 0.
# Skipping nmq6-0.png: Expected 4 parts, got 3.
# Skipping 1099dths-0.png: Expected 8 parts, got 6.
# Skipping onre-0.png: Expected 4 parts, got 3.
# Skipping cs50-0.png: Expected 4 parts, got 0.
# Skipping omnx4fm-0.png: Expected 7 parts, got 3.
# Skipping jsf6-0.png: Expected 4 parts, got 3.
# Skipping ednqp-0.png: Expected 5 parts, got 0.
# Skipping 3xfvi-0.png: Expected 5 parts, got 6.
# Skipping nen67r-0.png: Expected 6 parts, got 4.
# Skipping cw0k-0.png: Expected 4 parts, got 5.
# Skipping q69no3f-0.png: Expected 7 parts, got 3.
# Skipping h1h994lq-0.png: Expected 8 parts, got 12.
# Skipping h2s8-0.png: Expected 4 parts, got 5.
# Skipping 0ykbzgvb-0.png: Expected 8 parts, got 0.
# Skipping hr516373-0.png: Expected 8 parts, got 4.
# Skipping clc5lmda-0.png: Expected 8 parts, got 6.
# Skipping 41w6qvtq-0.png: Expected 8 parts, got 10.
# Skipping vf3zdvo-0.png: Expected 7 parts, got 2.
# Skipping ut6vavy-0.png: Expected 7 parts, got 6.
# Skipping xbnek4sw-0.png: Expected 8 parts, got 6.
# Skipping foa7x26p-0.png: Expected 8 parts, got 6.
# Skipping dxx8nkp-0.png: Expected 7 parts, got 6.
# Skipping oh2fvz-0.png: Expected 6 parts, got 11.
# Skipping xxdlt4x1-0.png: Expected 8 parts, got 0.
# Skipping sjbse48d-0.png: Expected 8 parts, got 6.
# Skipping vo4wkb-0.png: Expected 6 parts, got 1.
# Skipping cpxbs1nv-0.png: Expected 8 parts, got 1.
# Skipping gqy9e-0.png: Expected 5 parts, got 0.
# Skipping f7yv78c5-0.png: Expected 8 parts, got 9.
# Skipping ir04zbp-0.png: Expected 7 parts, got 6.
# Skipping 2lylbmw-0.png: Expected 7 parts, got 6.
# Skipping ujlktwf-0.png: Expected 7 parts, got 5.
# Skipping 5qm9rwrq-0.png: Expected 8 parts, got 7.
# Skipping vu9gosqe-0.png: Expected 8 parts, got 7.
# Skipping i5rfxue-0.png: Expected 7 parts, got 3.
# Skipping vhb3-0.png: Expected 4 parts, got 5.
# Skipping f103t-0.png: Expected 5 parts, got 1.
# Skipping sf861ut-0.png: Expected 7 parts, got 5.
# Skipping dqeds7z-0.png: Expected 7 parts, got 6.
# Skipping kavnr-0.png: Expected 5 parts, got 2.
# Skipping 1hlt42-0.png: Expected 6 parts, got 7.
# Skipping rz3qtcx0-0.png: Expected 8 parts, got 0.
# Skipping 5w0cc-0.png: Expected 5 parts, got 6.
# Skipping ifmn-0.png: Expected 4 parts, got 6.
# Skipping tqioef-0.png: Expected 6 parts, got 0.
# Skipping ffj6o-0.png: Expected 5 parts, got 4.
# Skipping 2e6i-0.png: Expected 4 parts, got 0.
# Skipping 2b4d-0.png: Expected 4 parts, got 1.
# Skipping cw8yf-0.png: Expected 5 parts, got 8.
# Skipping d7wq3kvt-0.png: Expected 8 parts, got 2.
# Skipping q4k4-0.png: Expected 4 parts, got 0.
# Skipping xgedtm-0.png: Expected 6 parts, got 9.
# Skipping 7nn8-0.png: Expected 4 parts, got 6.
# Skipping q4hwc7-0.png: Expected 6 parts, got 0.
# Skipping p4jdm22-0.png: Expected 7 parts, got 8.
# Skipping dctp4-0.png: Expected 5 parts, got 4.
# Skipping 7ih0-0.png: Expected 4 parts, got 5.
# Skipping li2k6-0.png: Expected 5 parts, got 1.
# Skipping fx3l1-0.png: Expected 5 parts, got 1.
# Skipping mmxinw4x-0.png: Expected 8 parts, got 2.
# Skipping l8jvyooi-0.png: Expected 8 parts, got 3.
# Skipping 4rvj-0.png: Expected 4 parts, got 0.
# Skipping uwhgjd2-0.png: Expected 7 parts, got 1.
# Skipping n8n4ol-0.png: Expected 6 parts, got 0.
# Skipping 4c0booxn-0.png: Expected 8 parts, got 7.
# Skipping qekhqgo-0.png: Expected 7 parts, got 10.
# Skipping xk70-0.png: Expected 4 parts, got 2.
# Skipping pnlen54-0.png: Expected 7 parts, got 8.
# Skipping u7npos0c-0.png: Expected 8 parts, got 7.
# Skipping trf8z7r-0.png: Expected 7 parts, got 2.
# Skipping tidnbz6-0.png: Expected 7 parts, got 3.
# Skipping 3fswd8-0.png: Expected 6 parts, got 7.
# Skipping akdbdc-0.png: Expected 6 parts, got 5.
# Skipping ryq9-0.png: Expected 4 parts, got 3.
# Skipping wkiiqi4n-0.png: Expected 8 parts, got 1.
# Skipping 23e4h-0.png: Expected 5 parts, got 3.
# Skipping c37073s7-0.png: Expected 8 parts, got 0.
# Skipping m3us-0.png: Expected 4 parts, got 5.
# Skipping r9ec79xv-0.png: Expected 8 parts, got 0.
# Skipping zfk708q-0.png: Expected 7 parts, got 4.
# Skipping cxl8dhh6-0.png: Expected 8 parts, got 0.
# Skipping vti0kdl-0.png: Expected 7 parts, got 0.
# Skipping x4u4hebx-0.png: Expected 8 parts, got 6.
# Skipping ooyc6m9-0.png: Expected 7 parts, got 11.
# Skipping d7uv-0.png: Expected 4 parts, got 0.
# Skipping brr37j-0.png: Expected 6 parts, got 1.
# Skipping vk7tp-0.png: Expected 5 parts, got 0.
# Skipping 4q433u82-0.png: Expected 8 parts, got 0.
# Skipping uzkol-0.png: Expected 5 parts, got 3.
# Skipping wcyf-0.png: Expected 4 parts, got 0.
# Skipping 356ccu-0.png: Expected 6 parts, got 12.
# Skipping 4kocxrt-0.png: Expected 7 parts, got 6.
# Skipping 6fy3-0.png: Expected 4 parts, got 2.
# Skipping xsuiagc-0.png: Expected 7 parts, got 6.
# Skipping xpm5v4-0.png: Expected 6 parts, got 5.
# Skipping rlot4z-0.png: Expected 6 parts, got 4.
# Skipping 2fgthyo9-0.png: Expected 8 parts, got 6.
# Skipping 75qb0jc9-0.png: Expected 8 parts, got 0.
# Skipping 15c3-0.png: Expected 4 parts, got 2.
# Skipping 47a48re-0.png: Expected 7 parts, got 1.
# Skipping qgivf-0.png: Expected 5 parts, got 1.
# Skipping kd8zcf58-0.png: Expected 8 parts, got 11.
# Skipping tnna72-0.png: Expected 6 parts, got 5.
# Skipping zjt2e-0.png: Expected 5 parts, got 3.
# Skipping lm64h4j-0.png: Expected 7 parts, got 0.
# Skipping 9xgdgd5-0.png: Expected 7 parts, got 10.
# Skipping ua0c-0.png: Expected 4 parts, got 1.
# Skipping j6qdr8-0.png: Expected 6 parts, got 8.
# Skipping j2st8-0.png: Expected 5 parts, got 2.
# Skipping rzs500-0.png: Expected 6 parts, got 10.
# Skipping 1pksa7t-0.png: Expected 7 parts, got 0.
# Skipping 9ikjyy6-0.png: Expected 7 parts, got 0.
# Skipping 2bd9wa3-0.png: Expected 7 parts, got 0.
# Skipping vbgikb-0.png: Expected 6 parts, got 3.
# Skipping tf2tp-0.png: Expected 5 parts, got 4.
# Skipping nawfmhl5-0.png: Expected 8 parts, got 7.
# Skipping ka3q-0.png: Expected 4 parts, got 0.
# Skipping z39uplo7-0.png: Expected 8 parts, got 5.
# Skipping sovo-0.png: Expected 4 parts, got 2.
# Skipping zqzbvk-0.png: Expected 6 parts, got 10.
# Skipping ide1-0.png: Expected 4 parts, got 3.
# Skipping i3lamtg-0.png: Expected 7 parts, got 6.
# Skipping kjt9-0.png: Expected 4 parts, got 5.
# Skipping etizrd-0.png: Expected 6 parts, got 0.
# Skipping s2xz-0.png: Expected 4 parts, got 0.
# Skipping efc2o9ch-0.png: Expected 8 parts, got 9.
# Skipping 7d9k3-0.png: Expected 5 parts, got 4.
# Skipping y8bd-0.png: Expected 4 parts, got 0.
# Skipping wvim9f3-0.png: Expected 7 parts, got 1.
# Skipping efnkypn5-0.png: Expected 8 parts, got 7.
# Skipping ze4p5c14-0.png: Expected 8 parts, got 2.
# Skipping h28drs7-0.png: Expected 7 parts, got 4.
# Skipping kcz61vn-0.png: Expected 7 parts, got 9.
# Skipping xai1-0.png: Expected 4 parts, got 0.
# ...
# Skipping g0h66u-0.png: Expected 6 parts, got 9.
# Skipping 7tz8-0.png: Expected 4 parts, got 3.
# Skipping mqb4pzs-0.png: Expected 7 parts, got 4.
# Skipping mn2rh1-0.png: Expected 6 parts, got 2.
# Skipping hf4af5-0.png: Expected 6 parts, got 7.
# Skipping 52qoqji-0.png: Expected 7 parts, got 1.
# Skipping zryy5-0.png: Expected 5 parts, got 3.
# Skipping cvrp2iy-0.png: Expected 7 parts, got 8.
# Skipping 6wpo9y4-0.png: Expected 7 parts, got 3.
# Skipping j72fad6r-0.png: Expected 8 parts, got 7.
# Skipping dcxc-0.png: Expected 4 parts, got 7.
# Skipping zsq2xr-0.png: Expected 6 parts, got 0.
# Skipping sxkr-0.png: Expected 4 parts, got 2.
# Skipping 4p7cky-0.png: Expected 6 parts, got 3.
# Skipping x8vwpvab-0.png: Expected 8 parts, got 0.
# Skipping jvtfzm0m-0.png: Expected 8 parts, got 2.
# Skipping t0f40wn-0.png: Expected 7 parts, got 5.
# Skipping bm1wb-0.png: Expected 5 parts, got 6.
# Skipping oqiqe4t-0.png: Expected 7 parts, got 1.
# Skipping de9ehwc-0.png: Expected 7 parts, got 6.
# Skipping qfthxok7-0.png: Expected 8 parts, got 7.
# Skipping jbro8l9x-0.png: Expected 8 parts, got 0.
# Skipping qic72um-0.png: Expected 7 parts, got 6.
# Skipping l3famu21-0.png: Expected 8 parts, got 7.
# Skipping mc5kin-0.png: Expected 6 parts, got 7.
# Skipping 31kz-0.png: Expected 4 parts, got 3.
# Skipping 2x6ygp-0.png: Expected 6 parts, got 0.
# Skipping hcul03l-0.png: Expected 7 parts, got 6.
# Skipping l2q2i-0.png: Expected 5 parts, got 6.
# Skipping jzvf1-0.png: Expected 5 parts, got 2.
# Skipping o2r50v-0.png: Expected 6 parts, got 5.
# Skipping l3h3dwp-0.png: Expected 7 parts, got 4.
# Skipping 2fvmeb4-0.png: Expected 7 parts, got 9.
# Skipping x7fa-0.png: Expected 4 parts, got 2.
# Skipping 2gfo66dh-0.png: Expected 8 parts, got 6.
# Skipping 7yv3h-0.png: Expected 5 parts, got 3.
# Skipping 10sj-0.png: Expected 4 parts, got 3.
# Skipping ok1h-0.png: Expected 4 parts, got 3.
# Skipping nrw3o7m-0.png: Expected 7 parts, got 8.
# Skipping b5ry1z-0.png: Expected 6 parts, got 5.
# Skipping g49ra-0.png: Expected 5 parts, got 6.
# Skipping 0fm4a3rx-0.png: Expected 8 parts, got 0.
# Skipping dm5xa-0.png: Expected 5 parts, got 4.
# Skipping kb14b5-0.png: Expected 6 parts, got 4.
# Skipping 37fhsm2-0.png: Expected 7 parts, got 0.
# Skipping fv2oik-0.png: Expected 6 parts, got 0.
# Skipping hxx17tex-0.png: Expected 8 parts, got 4.
# Skipping wmoy7yzn-0.png: Expected 8 parts, got 6.
# Skipping f1xrpj4u-0.png: Expected 8 parts, got 9.
# Skipping khzj8bf-0.png: Expected 7 parts, got 6.
# Skipping zr7q7c6c-0.png: Expected 8 parts, got 1.
# Skipping pp8w1-0.png: Expected 5 parts, got 4.
# Skipping mh4fjm-0.png: Expected 6 parts, got 5.
# Skipping eue1-0.png: Expected 4 parts, got 1.
# Skipping mxr8db8w-0.png: Expected 8 parts, got 10.
# Skipping 5gomqbt-0.png: Expected 7 parts, got 10.
# Skipping jutq59s6-0.png: Expected 8 parts, got 0.
# Skipping 5ifb3-0.png: Expected 5 parts, got 0.
# Skipping 7pzrx0ct-0.png: Expected 8 parts, got 7.
# Skipping b961hw-0.png: Expected 6 parts, got 9.
# Skipping crpheoi-0.png: Expected 7 parts, got 5.
# Skipping 9e3j1oj-0.png: Expected 7 parts, got 0.
# Skipping uwlf66w8-0.png: Expected 8 parts, got 6.
# Skipping u8lwt7-0.png: Expected 6 parts, got 0.
# Skipping 9vpp-0.png: Expected 4 parts, got 0.
# Skipping hxer2q-0.png: Expected 6 parts, got 1.
# Skipping nya7f5-0.png: Expected 6 parts, got 8.
# Skipping v2qlb-0.png: Expected 5 parts, got 4.
# Skipping mf65g-0.png: Expected 5 parts, got 8.
# Skipping lhul7j-0.png: Expected 6 parts, got 8.
# Skipping qvtxb1-0.png: Expected 6 parts, got 0.
# Skipping 09u8b47-0.png: Expected 7 parts, got 8.
# Skipping m27yku-0.png: Expected 6 parts, got 9.
# Skipping uah0-0.png: Expected 4 parts, got 0.
# Skipping nxqhz-0.png: Expected 5 parts, got 0.
# Skipping geys-0.png: Expected 4 parts, got 3.
# Skipping jq9gjytn-0.png: Expected 8 parts, got 7.
# Skipping wspv3d-0.png: Expected 6 parts, got 4.
# Skipping 0xfmd4-0.png: Expected 6 parts, got 7.
# Skipping xhtn0gj-0.png: Expected 7 parts, got 0.
# Skipping zl259-0.png: Expected 5 parts, got 6.
# Skipping mtrj-0.png: Expected 4 parts, got 0.
# Skipping zdfvcb-0.png: Expected 6 parts, got 7.
# Skipping wsbd0-0.png: Expected 5 parts, got 10.
# Skipping wnef2p-0.png: Expected 6 parts, got 8.
# Skipping u7xqho-0.png: Expected 6 parts, got 2.
# Skipping wghe36r-0.png: Expected 7 parts, got 1.
# Skipping n5ca-0.png: Expected 4 parts, got 0.
# Skipping qwsr24b8-0.png: Expected 8 parts, got 10.
# Skipping r5yfvbt7-0.png: Expected 8 parts, got 9.
# Skipping ddn8qk4c-0.png: Expected 8 parts, got 7.
# Skipping nok5h-0.png: Expected 5 parts, got 7.
# Skipping wlv6xsd-0.png: Expected 7 parts, got 8.
# Skipping chw3-0.png: Expected 4 parts, got 3.
# Skipping 8jbtjs-0.png: Expected 6 parts, got 0.
# Skipping uv1w1ekj-0.png: Expected 8 parts, got 10.
# Skipping htyxx-0.png: Expected 5 parts, got 0.
# Skipping g7pft2-0.png: Expected 6 parts, got 4.
# Skipping o8gwm-0.png: Expected 5 parts, got 4.
# Skipping 8gr6z-0.png: Expected 5 parts, got 4.
# Skipping abligtsu-0.png: Expected 8 parts, got 3.
# Skipping 43u1voui-0.png: Expected 8 parts, got 0.
# Skipping pooqawbn-0.png: Expected 8 parts, got 7.
# Skipping plelck-0.png: Expected 6 parts, got 4.
# Skipping lmmx8pg-0.png: Expected 7 parts, got 4.
# Skipping gu1dd53v-0.png: Expected 8 parts, got 12.
# Skipping shfkvjtx-0.png: Expected 8 parts, got 7.
# Skipping ej0ss39-0.png: Expected 7 parts, got 10.
# Skipping hvgqwz-0.png: Expected 6 parts, got 8.
# Skipping hxzsm-0.png: Expected 5 parts, got 0.
# Skipping nidg-0.png: Expected 4 parts, got 0.
# Skipping 6gzxrr-0.png: Expected 6 parts, got 0.
# Skipping e11xcxtx-0.png: Expected 8 parts, got 5.
# Skipping 5idgdn-0.png: Expected 6 parts, got 1.
# Skipping fnl9-0.png: Expected 4 parts, got 3.
# Skipping 03ykb47u-0.png: Expected 8 parts, got 9.
# Skipping qibpw0-0.png: Expected 6 parts, got 2.
# Skipping e17bzs5-0.png: Expected 7 parts, got 6.
# Skipping ywrljt-0.png: Expected 6 parts, got 0.
# Skipping zlwvizw-0.png: Expected 7 parts, got 12.
# Skipping i5r6epj-0.png: Expected 7 parts, got 8.
# Skipping 2jano-0.png: Expected 5 parts, got 4.
# Skipping jiks1h4-0.png: Expected 7 parts, got 2.
# Skipping sfaqe0-0.png: Expected 6 parts, got 8.
# Skipping umy8cwn-0.png: Expected 7 parts, got 0.
# Skipping xjgk68-0.png: Expected 6 parts, got 0.
# Skipping 117l9-0.png: Expected 5 parts, got 2.
# Skipping 80a79g-0.png: Expected 6 parts, got 0.
# Skipping fojc-0.png: Expected 4 parts, got 5.
# Skipping f260-0.png: Expected 4 parts, got 6.
# Skipping 8zfaxm-0.png: Expected 6 parts, got 4.
# Skipping v5vwc-0.png: Expected 5 parts, got 4.
# Skipping afamhwjj-0.png: Expected 8 parts, got 11.
# Skipping txay7-0.png: Expected 5 parts, got 0.
# Skipping 0h7htrjq-0.png: Expected 8 parts, got 1.
# Skipping ekwuc8af-0.png: Expected 8 parts, got 2.
# Skipping r3w8w7m-0.png: Expected 7 parts, got 10.
# Skipping ylal-0.png: Expected 4 parts, got 6.
# Skipping qjhpi-0.png: Expected 5 parts, got 6.
# Skipping nqvhwngj-0.png: Expected 8 parts, got 4.
# Skipping b7suqtgf-0.png: Expected 8 parts, got 10.
# Skipping 5dtoxa-0.png: Expected 6 parts, got 4.
# Skipping amj2afk-0.png: Expected 7 parts, got 9.
# Skipping wd83-0(1).png: Expected 4 parts, got 2.
# Skipping b8ceaq6-0.png: Expected 7 parts, got 8.
# Skipping vuvpv5-0.png: Expected 6 parts, got 5.
# Skipping v2ku-0.png: Expected 4 parts, got 2.
# Skipping fqr2d-0.png: Expected 5 parts, got 4.
# Skipping d5eci-0.png: Expected 5 parts, got 6.
# Skipping 74r1c319-0.png: Expected 8 parts, got 9.
# Skipping rl3dpce-0.png: Expected 7 parts, got 6.
# Skipping p46iyr-0.png: Expected 6 parts, got 3.
# Skipping 1u5b3hlt-0.png: Expected 8 parts, got 11.
# Skipping lfbewadl-0.png: Expected 8 parts, got 7.
# Skipping p45so-0.png: Expected 5 parts, got 0.
# Skipping nmued43-0.png: Expected 7 parts, got 5.
# Skipping 7bcjn-0.png: Expected 5 parts, got 1.
# Skipping nqrqhs4p-0.png: Expected 8 parts, got 4.
# Skipping pe08sp-0.png: Expected 6 parts, got 7.
# Skipping 66i29n-0.png: Expected 6 parts, got 8.
# Skipping n2ujhk0b-0.png: Expected 8 parts, got 0.
# Skipping a6vg1s-0.png: Expected 6 parts, got 3.
# Skipping rmf5bv-0.png: Expected 6 parts, got 5.
# Skipping g7zqyv6-0.png: Expected 7 parts, got 0.
# Skipping 28rqld-0.png: Expected 6 parts, got 5.
# Skipping wjss-0.png: Expected 4 parts, got 3.
# Skipping 1u5bgi1-0.png: Expected 7 parts, got 1.
# Skipping xt1r9liy-0.png: Expected 8 parts, got 3.
# Skipping yyq1c1-0.png: Expected 6 parts, got 0.
# Skipping xfyr2-0.png: Expected 5 parts, got 7.
# Skipping gz8x-0.png: Expected 4 parts, got 3.
# Skipping mspwu1wb-0.png: Expected 8 parts, got 10.
# Skipping 32pt-0.png: Expected 4 parts, got 6.
# Skipping g7w62-0.png: Expected 5 parts, got 6.
# Skipping muynbh6-0.png: Expected 7 parts, got 12.
# Skipping hp48uegi-0.png: Expected 8 parts, got 7.
# Skipping zdwz-0.png: Expected 4 parts, got 1.
# Skipping yo4y5o28-0.png: Expected 8 parts, got 7.
# Skipping aiqnfxb0-0.png: Expected 8 parts, got 3.
# Skipping yglx0-0.png: Expected 5 parts, got 6.
# Skipping mcik3b1-0.png: Expected 7 parts, got 6.
# Skipping 1knx-0.png: Expected 4 parts, got 5.
# Skipping q5thi-0.png: Expected 5 parts, got 0.
# Skipping pj1svxla-0.png: Expected 8 parts, got 0.
# Skipping 5vgjp-0.png: Expected 5 parts, got 0.
# Skipping bavytrty-0.png: Expected 8 parts, got 9.
# Skipping 2ggtipg-0.png: Expected 7 parts, got 6.
# Skipping cx2ysb-0.png: Expected 6 parts, got 12.
# Skipping 1hue9-0.png: Expected 5 parts, got 3.
# Skipping ushd-0.png: Expected 4 parts, got 1.
# Skipping gsm9pcp-0.png: Expected 7 parts, got 5.
# Skipping q8l04ku-0.png: Expected 7 parts, got 0.
# Skipping o0endi-0.png: Expected 6 parts, got 0.
# Skipping r4m7-0.png: Expected 4 parts, got 1.
# Skipping bwmnr-0.png: Expected 5 parts, got 8.
# Skipping xcdf1g-0.png: Expected 6 parts, got 1.
# Skipping 67zs-0.png: Expected 4 parts, got 1.
# Skipping o2jf-0.png: Expected 4 parts, got 5.
# Skipping x8s4nyc-0.png: Expected 7 parts, got 8.
# Skipping rosmm4-0.png: Expected 6 parts, got 12.
# Skipping z374-0.png: Expected 4 parts, got 1.
# Skipping p66w-0.png: Expected 4 parts, got 2.
# Skipping 23bz8q8n-0.png: Expected 8 parts, got 5.
# Skipping zwol36kj-0.png: Expected 8 parts, got 0.
# Skipping yedxpokp-0.png: Expected 8 parts, got 5.
# Skipping 3d2e-0.png: Expected 4 parts, got 0.
# Skipping te58y6-0.png: Expected 6 parts, got 8.
# Skipping 53vmg7b-0.png: Expected 7 parts, got 8.
# Skipping jdp40cu-0.png: Expected 7 parts, got 0.
# Skipping pi6x-0.png: Expected 4 parts, got 0.
# Skipping 4e4qjny7-0.png: Expected 8 parts, got 4.
# Skipping 9wt7-0.png: Expected 4 parts, got 2.
# Skipping j7vyhu-0.png: Expected 6 parts, got 4.
# Skipping 1gqe-0.png: Expected 4 parts, got 2.
# Skipping j1as7r-0.png: Expected 6 parts, got 0.
# Skipping 010b-0.png: Expected 4 parts, got 0.
# Skipping bt11-0.png: Expected 4 parts, got 3.
# Skipping ol28rdv6-0.png: Expected 8 parts, got 0.
# Skipping grjdtf11-0.png: Expected 8 parts, got 12.
# Skipping t6xz-0.png: Expected 4 parts, got 1.
# Skipping 8q0x-0.png: Expected 4 parts, got 1.
# Skipping nulq4-0.png: Expected 5 parts, got 4.
# Skipping 8lp9-0.png: Expected 4 parts, got 2.
# Skipping q8l5d0-0.png: Expected 6 parts, got 2.
# Skipping co9nerl-0.png: Expected 7 parts, got 6.
# Skipping 19zzp-0.png: Expected 5 parts, got 10.
# Skipping ajyjc7-0.png: Expected 6 parts, got 2.
# Skipping jvsd2r5-0.png: Expected 7 parts, got 4.
# Skipping y2nq-0.png: Expected 4 parts, got 5.
# Skipping jpn7wq-0.png: Expected 6 parts, got 0.
# Skipping 9i3yk9-0.png: Expected 6 parts, got 7.
# Skipping b6fd80x-0.png: Expected 7 parts, got 5.
# Skipping iy3onn5-0.png: Expected 7 parts, got 3.
# Skipping ostkosqw-0.png: Expected 8 parts, got 15.
# Skipping f39ucxi-0.png: Expected 7 parts, got 6.
# Skipping pev16zo-0.png: Expected 7 parts, got 1.
# Skipping lf63g-0.png: Expected 5 parts, got 0.
# Skipping hntl-0.png: Expected 4 parts, got 3.
# Skipping 6a9p-0.png: Expected 4 parts, got 0.
# Skipping 9hhzkw-0.png: Expected 6 parts, got 0.
# Skipping h977idg-0.png: Expected 7 parts, got 0.
# Skipping n0e0jfaj-0.png: Expected 8 parts, got 7.
# Skipping saca4-0.png: Expected 5 parts, got 3.
# Skipping 363r-0.png: Expected 4 parts, got 2.
# Skipping f5ks8b44-0.png: Expected 8 parts, got 5.
# Skipping 7hyn7eq-0.png: Expected 7 parts, got 11.
# Skipping ngsc-0.png: Expected 4 parts, got 1.
# Skipping 1ehi-0.png: Expected 4 parts, got 0.
# Skipping ouspon-0.png: Expected 6 parts, got 10.
# Skipping zaig9-0.png: Expected 5 parts, got 4.
# Skipping tuw51b-0.png: Expected 6 parts, got 2.
# Skipping qkqv-0.png: Expected 4 parts, got 0.
# Skipping b21fu-0.png: Expected 5 parts, got 6.
# Skipping gzjtii-0.png: Expected 6 parts, got 4.
# Skipping cpuwhul-0.png: Expected 7 parts, got 12.
# Skipping h7j0-0.png: Expected 4 parts, got 3.
# Skipping v4xia2-0.png: Expected 6 parts, got 11.
# Skipping ow1uitv-0.png: Expected 7 parts, got 0.
# Skipping ltb2-0.png: Expected 4 parts, got 7.
# Skipping xdv0pp1q-0.png: Expected 8 parts, got 3.
# Skipping 4z79pirj-0.png: Expected 8 parts, got 1.
# Skipping 9xfcz7-0.png: Expected 6 parts, got 7.
# Skipping xyvz-0.png: Expected 4 parts, got 0.
# Skipping 1lib-0.png: Expected 4 parts, got 3.
# Skipping ao7k-0.png: Expected 4 parts, got 7.
# Skipping b0vupan-0.png: Expected 7 parts, got 0.
# Skipping aj8lu8-0.png: Expected 6 parts, got 4.
# Skipping 2gn63i-0.png: Expected 6 parts, got 4.
# Skipping 6zdkq7o-0.png: Expected 7 parts, got 0.
# Skipping j3w44drh-0.png: Expected 8 parts, got 0.
# Skipping 70do56y-0.png: Expected 7 parts, got 3.
# Skipping y1nk-0.png: Expected 4 parts, got 1.
# Skipping tuxl-0.png: Expected 4 parts, got 2.
# Skipping uh1vqeyc-0.png: Expected 8 parts, got 0.
# Skipping 76sp8v-0.png: Expected 6 parts, got 7.
# Skipping kfxz5-0.png: Expected 5 parts, got 0.
# Skipping tm31r5-0.png: Expected 6 parts, got 2.
# Skipping fpyrmh-0.png: Expected 6 parts, got 7.
# Skipping j5s5mgs-0.png: Expected 7 parts, got 6.
# Skipping 3parb27i-0.png: Expected 8 parts, got 7.
# Skipping vlg8j7-0.png: Expected 6 parts, got 5.
# Skipping z1c33-0.png: Expected 5 parts, got 4.
# Skipping 5lcr-0.png: Expected 4 parts, got 0.
# Skipping zxa8-0.png: Expected 4 parts, got 5.
# Skipping 0umrcy-0.png: Expected 6 parts, got 0.
# Skipping tg1wgq-0.png: Expected 6 parts, got 1.
# Skipping h9xpr6-0.png: Expected 6 parts, got 4.
# Skipping jztgkdr-0.png: Expected 7 parts, got 1.
# Skipping ojb96mm-0.png: Expected 7 parts, got 0.
# Skipping 92xyvp-0.png: Expected 6 parts, got 8.
# Skipping sbn76-0.png: Expected 5 parts, got 6.
# Skipping y74bsx-0.png: Expected 6 parts, got 5.
# Skipping cb7pekr-0.png: Expected 7 parts, got 11.
# Skipping z1arx-0.png: Expected 5 parts, got 2.
# Skipping s8xp0uq-0.png: Expected 7 parts, got 5.
# Skipping fk17p-0.png: Expected 5 parts, got 3.
# Skipping 5icltk07-0.png: Expected 8 parts, got 7.
# Skipping 7wrz-0.png: Expected 4 parts, got 5.
# Skipping ef6uszg-0.png: Expected 7 parts, got 0.
# Skipping ph54m3-0.png: Expected 6 parts, got 7.
# Skipping lbpm-0.png: Expected 4 parts, got 0.
# Skipping h3iydumz-0.png: Expected 8 parts, got 0.
# Skipping 9i3vx-0.png: Expected 5 parts, got 3.
# Skipping hvwhc7x-0.png: Expected 7 parts, got 1.
# Skipping 62b3oy-0.png: Expected 6 parts, got 5.
# Skipping 50vhxk-0.png: Expected 6 parts, got 8.
# Skipping m2fak3-0.png: Expected 6 parts, got 4.
# Skipping uslkh1l-0.png: Expected 7 parts, got 3.
# Skipping cu2g-0.png: Expected 4 parts, got 5.
# Skipping hfkiyki-0.png: Expected 7 parts, got 2.
# Skipping gkus8umz-0.png: Expected 8 parts, got 1.
# Skipping 3pkp-0.png: Expected 4 parts, got 3.
# Skipping 6q84ibe-0.png: Expected 7 parts, got 0.
# Skipping v2lrfu-0.png: Expected 6 parts, got 0.
# Skipping yve9-0.png: Expected 4 parts, got 6.
# Skipping 6t82hn7h-0.png: Expected 8 parts, got 6.
# Skipping 1yam8ih9-0.png: Expected 8 parts, got 11.
# Skipping ph4wx-0.png: Expected 5 parts, got 4.
# Skipping 057ea-0.png: Expected 5 parts, got 4.
# Skipping lyjy-0.png: Expected 4 parts, got 1.
# Skipping na62zw-0.png: Expected 6 parts, got 4.
# Skipping bbs7y-0.png: Expected 5 parts, got 7.
# Skipping 4u7fh0-0.png: Expected 6 parts, got 10.
# Skipping i9tep8-0.png: Expected 6 parts, got 3.
# Skipping 4nx86y-0.png: Expected 6 parts, got 0.
# Skipping vrzow-0.png: Expected 5 parts, got 6.
# Skipping a70ond9c-0.png: Expected 8 parts, got 0.
# Skipping o9uthdb-0.png: Expected 7 parts, got 9.
# Skipping dbz24514-0.png: Expected 8 parts, got 0.
# Processing complete! Segmented characters are saved in /Users/jjtiong/Desktop/captcha_dataset/segmented_train
# Total skipped: 2686

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def augment_and_save_images(input_dir, output_dir, augment_count=3):
    """Augment images from `input_dir` and save them with proper naming to `output_dir`."""
    os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists

    # Define a more controlled data augmentation pipeline
    datagen = ImageDataGenerator(
        rotation_range=10,          # Small rotation for better quality
        width_shift_range=0.05,     # Slight horizontal shift
        height_shift_range=0.05,    # Slight vertical shift
        shear_range=0.1,            # Mild shearing
        zoom_range=0.1,             # Mild zoom
        fill_mode='nearest'         # Avoid introducing artifacts
    )

    # Loop through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Load the original image
            image_path = os.path.join(input_dir, filename)
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Expand dimensions for augmentation
            img = np.expand_dims(img, axis=-1)  # Add channel dimension
            img = np.expand_dims(img, axis=0)   # Add batch dimension

            # Extract the base filename without extension (e.g., 'abc-o')
            base_name = filename.split('.')[0]

            # Generate and save augmented images
            for i, batch in enumerate(datagen.flow(img, batch_size=1)):
                # Save each augmented image with proper naming
                augmented_filename = f"{base_name}-{i + 1}.png"
                augmented_path = os.path.join(output_dir, augmented_filename)

                # Save the augmented image
                cv2.imwrite(augmented_path, batch[0].squeeze().astype(np.uint8))

                # Stop after generating `augment_count` images per original image
                if i + 1 >= augment_count:
                    break

    print(f"Augmentation complete! Augmented images saved in {output_dir}")


# Example usage
input_dir = SEGMENTED_TRAIN_DATASET_PATH
output_dir = AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH
augment_and_save_images(input_dir, output_dir)
# Out:
# Augmentation complete! Augmented images saved in /Users/jjtiong/Desktop/captcha_dataset/augmented_segmented_train

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# Define character set (e.g., 0-9, a-z)
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_TO_IDX = {char: idx for idx, char in enumerate(CHAR_SET)}

def load_dataset(data_dir):
    images = []
    labels = []

    for filename in os.listdir(data_dir):
        if filename.endswith('.png'):
            # Extract the character from the filename (e.g., 'o' from 'oq1j-o.png')
            char_label = filename.split('-')[1][0]

            if char_label in CHAR_TO_IDX:
                # Load the image in grayscale
                image_path = os.path.join(data_dir, filename)
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

                # Resize to 28x28 (if needed)
                img = cv2.resize(img, (28, 28))
                img = img / 255.0  # Normalize pixel values to [0, 1]

                # Store the image and label
                images.append(img)
                labels.append(CHAR_TO_IDX[char_label])

    # Convert to numpy arrays
    images = np.array(images).reshape(-1, 28, 28, 1)  # Add channel dimension
    labels = np.array(labels)

    return images, labels

# Load the dataset
images, labels = load_dataset(output_dir)
print(f"Loaded {len(images)} images with {len(set(labels))} unique labels.")
# Out:
# Loaded 88374 images with 36 unique labels.

# %%
# Split the data into training and validation sets (80% train, 20% validation)
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

print(f"Training set size: {X_train.shape[0]}, Validation set size: {X_val.shape[0]}")
# Out:
# Training set size: 70699, Validation set size: 17675

# %%
#MODEL 1 ~8%

# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# def build_model(num_classes):
#     model = Sequential([
#         Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
#         MaxPooling2D((2, 2)),
#         Dropout(0.2),

#         Conv2D(64, (3, 3), activation='relu'),
#         MaxPooling2D((2, 2)),
#         Dropout(0.2),

#         Flatten(),
#         Dense(128, activation='relu'),
#         Dropout(0.5),
#         Dense(num_classes, activation='softmax')
#     ])

#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#     return model

# # Build the model for 36 classes (0-9, a-z)
# num_classes = len(CHAR_SET)
# model = build_model(num_classes)
# model.summary()

# %%
#MODEL 2 ~24%

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Dropout, ReLU

# def build_custom_cnn(num_classes):
#     model = Sequential()

#     # First Conv Block
#     model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Second Conv Block
#     model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Third Conv Block
#     model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2, 2)))

#     # Fully Connected Layers
#     model.add(Flatten())
#     model.add(Dropout(0.5))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(36, activation='softmax'))  # 36 classes: 0-9 + a-z

#     # Compile the model
#     model.compile(optimizer='adam', 
#                   loss='sparse_categorical_crossentropy', 
#                   metrics=['accuracy'])

#     return model


# num_classes = len(CHAR_SET)
# model = build_model(num_classes)
# model.summary()

# %%
#MODEL 3 ~33% (AlexNet)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, ReLU

def build_alexnet():
    model = Sequential()

    # 1st Convolutional Layer
    model.add(Conv2D(64, (3, 3), strides=1, padding='same', input_shape=(28, 28, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # 2nd Convolutional Layer
    model.add(Conv2D(128, (3, 3), strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # 3rd Convolutional Layer
    model.add(Conv2D(256, (3, 3), strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten the output for Fully Connected Layers
    model.add(Flatten())

    # 1st Fully Connected Layer
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    # 2nd Fully Connected Layer
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    # Output Layer
    model.add(Dense(36, activation='softmax'))

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

model = build_alexnet()
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 28, 28, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 14, 14, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 14, 14, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 7, 7, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 7, 7, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 36)             │        18,468 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,832,740 (6.99 MB)
#  Trainable params: 1,831,844 (6.99 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# history = model.fit(
#     X_train, y_train,
#     validation_data=(X_val, y_val),
#     epochs=30,
#     batch_size=64
# )
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# Train the model with EarlyStopping
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 65s 58ms/step - accuracy: 0.1909 - loss: 2.9335 - val_accuracy: 0.6095 - val_loss: 1.4479
# Epoch 2/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 63s 57ms/step - accuracy: 0.5775 - loss: 1.3941 - val_accuracy: 0.5969 - val_loss: 1.4257
# Epoch 3/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 64s 58ms/step - accuracy: 0.6947 - loss: 1.0297 - val_accuracy: 0.7207 - val_loss: 0.9415
# Epoch 4/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 63s 57ms/step - accuracy: 0.7390 - loss: 0.8602 - val_accuracy: 0.7407 - val_loss: 0.8857
# Epoch 5/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 63s 57ms/step - accuracy: 0.7696 - loss: 0.7649 - val_accuracy: 0.7290 - val_loss: 0.9569
# Epoch 6/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 65s 58ms/step - accuracy: 0.7911 - loss: 0.6888 - val_accuracy: 0.8074 - val_loss: 0.6516
# Epoch 7/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 66s 60ms/step - accuracy: 0.8063 - loss: 0.6269 - val_accuracy: 0.7285 - val_loss: 0.9352
# Epoch 8/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 68s 62ms/step - accuracy: 0.8169 - loss: 0.5910 - val_accuracy: 0.8108 - val_loss: 0.6245
# Epoch 9/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 69s 62ms/step - accuracy: 0.8272 - loss: 0.5445 - val_accuracy: 0.8266 - val_loss: 0.5951
# Epoch 10/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 73s 66ms/step - accuracy: 0.8395 - loss: 0.5065 - val_accuracy: 0.7708 - val_loss: 0.7951
# Epoch 11/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 70s 64ms/step - accuracy: 0.8473 - loss: 0.4745 - val_accuracy: 0.5409 - val_loss: 1.7575
# Epoch 12/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 70s 63ms/step - accuracy: 0.8589 - loss: 0.4411 - val_accuracy: 0.7847 - val_loss: 0.7631

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8258 - loss: 0.5970
# Validation Loss: 0.5959, Validation Accuracy: 82.66%

# %%
# Save the trained model
def save_model(model, dir_path, model_name="character_recognition_model.h5"):
    # Ensure the directory exists
    os.makedirs(dir_path, exist_ok=True)
    
    # Create the full path to the model file
    model_path = os.path.join(dir_path, model_name)
    
    # Save the model
    model.save(model_path)
    print(f"Model saved successfully at: {model_path}")

# Example usage
save_dir = '/Users/jjtiong/Desktop/captcha_dataset/model2'
save_model(model, save_dir)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at: /Users/jjtiong/Desktop/captcha_dataset/model2/character_recognition_model.h5

# %%
def predict_character(image_path, model):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28, 28)) / 255.0  # Normalize
    img = np.expand_dims(img, axis=[0, -1])  # Add batch and channel dimensions

    prediction = model.predict(img)
    predicted_label = np.argmax(prediction)
    predicted_char = CHAR_SET[predicted_label]

    return predicted_char

# Example usage
model = tf.keras.models.load_model(MODEL_PATH)
predicted_char = predict_character('/Users/jjtiong/Desktop/captcha_dataset/segmented_train/0tqk-t.png', model)
print(f"Predicted Character: {predicted_char}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predicted Character: t

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model(MODEL_PATH)

# Define the character set used during training
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_MAP = {idx: char for idx, char in enumerate(CHAR_SET)}

def preprocess_image(image_path):
    """Preprocess the image using the same steps as in training."""
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = gaussian_thresholding(image)
    image = dilate(image)
    return image

def gaussian_thresholding(image):
    # Use gaussian blur to make characters thicker before thresholding 
    blur = cv2.GaussianBlur(image, (5, 5), 0)
    thresholded_image = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
        cv2.THRESH_BINARY, blockSize=11, C=2
    )
    return image

def dilate(image):
    #  Remove noise via dilation
    kernel = np.ones((3,3), np.uint8)
    dilation = cv2.dilate(image, kernel, iterations=1)
    
    # show_image("Dilated", dilation)
    return dilation

# def adaptive_thresholding(image):
#     """Apply adaptive thresholding."""
#     return cv2.adaptiveThreshold(
#         image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
#         cv2.THRESH_BINARY_INV, blockSize=11, C=2
#     )

# def remove_noise(image):
#     """Remove small noise using morphological operations."""
#     kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
#     cleaned_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel, iterations=1)
#     cleaned_image = cv2.morphologyEx(cleaned_image, cv2.MORPH_CLOSE, kernel, iterations=1)
#     return cleaned_image

# def remove_lines(image):
#     """Remove lines using Hough Line Transform."""
#     lines = cv2.HoughLinesP(image, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)
#     if lines is not None:
#         for line in lines:
#             x1, y1, x2, y2 = line[0]
#             cv2.line(image, (x1, y1), (x2, y2), 0, thickness=2)
#     return image

def segment_characters(image):
    """Segment the CAPTCHA image into individual characters."""
    inverted_image = cv2.bitwise_not(image)

    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    char_images = []

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if h > 10:  # Ignore small contours (noise)
            char_img = image[y:y+h, x:x+w]
            char_images.append((x, char_img))

    # Sort by x-coordinate to ensure correct order
    char_images = sorted(char_images, key=lambda c: c[0])
    return [char[1] for char in char_images]

def predict_character(image, model):
    """Predict a single character using the trained model."""
    img = cv2.resize(image, (28, 28)) / 255.0  # Resize and normalize
    img = np.expand_dims(img, axis=[0, -1])  # Add batch and channel dimensions

    prediction = model.predict(img)
    predicted_label = np.argmax(prediction)
    predicted_char = CHAR_MAP[predicted_label]
    return predicted_char

def predict_captcha_string(image_path, model):
    """Predict the entire CAPTCHA string from the input image."""
    # Preprocess the image
    processed_image = preprocess_image(image_path)

    # Segment the characters
    char_images = segment_characters(processed_image)

    # Predict each character and reconstruct the string
    predicted_string = ""
    for char_img in char_images:
        predicted_char = predict_character(char_img, model)
        predicted_string += predicted_char

    return predicted_string



# Example usage
captcha_image_path = "/Users/jjtiong/Desktop/captcha_dataset/test/2d76-0.png"
predicted_string = predict_captcha_string(captcha_image_path, model)
print(f"Predicted CAPTCHA string: {predicted_string}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Predicted CAPTCHA string: 2d76

# %%
import os

def evaluate_on_unseen_data(unseen_dir, model, num_images=20):
    """Evaluate the model on the first `num_images` from the unseen directory."""
    correct_predictions = 0
    total_images = 0

    # Get the first `num_images` files from the directory
    all_files = [f for f in os.listdir(unseen_dir) if f.endswith('.png')]
    all_files = sorted(all_files)[:num_images]  # Limit to first `num_images`

    for filename in all_files:
        # Extract the true label from the filename (e.g., '2d76' from '2d76-0.png')
        true_label = filename.split('-')[0]

        # Get the full path to the image
        image_path = os.path.join(unseen_dir, filename)

        # Predict the CAPTCHA string
        predicted_string = predict_captcha_string(image_path, model)
        print(f"True: {true_label}, Predicted: {predicted_string}")

        # Compare the predicted string with the true label
        if predicted_string == true_label:
            correct_predictions += 1

        total_images += 1

    # Calculate accuracy
    accuracy = correct_predictions / total_images * 100
    print(f"\nAccuracy on the first {num_images} images: {accuracy:.2f}%")

# Example usage
unseen_dir = "/Users/jjtiong/Desktop/captcha_dataset/test"
evaluate_on_unseen_data(unseen_dir, model, 1000)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 002e23, Predicted: 002e23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 03yl9s, Predicted: 03yi9s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 03yuav5, Predicted: 03yuav5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 03zl9o, Predicted: 03zl90
# True: 04zqohgi, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 05htm, Predicted: 05htm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 05pb, Predicted: 05pb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 07oj, Predicted: 070j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 07z0, Predicted: 07z0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 08ft2e2z, Predicted: o8ft2e2z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 08nxd77, Predicted: 08nxd77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 08otejfi, Predicted: 08otejfi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 08sba, Predicted: iuba
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 09popm, Predicted: 09popm
# True: 0a7sh2wp, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0al4pl, Predicted: ji
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0c3dp, Predicted: 0c3dp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0c7mgdmd, Predicted: 0o7mgdmd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0chnm34, Predicted: ww4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0col7w, Predicted: oco2w
# True: 0cr6, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# True: 0dx9, Predicted: r1q3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0fa6qtkn, Predicted: 0faljgikr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0favtnx, Predicted: ofavtnx
# True: 0fee, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0gil, Predicted: 0gi1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 0gzwaq8, Predicted: ogzwaqp111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 0h5ya8, Predicted: 0h5ya8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0i7uom, Predicted: 0a2kiom3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 0ilhsr2t, Predicted: dilhsr27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 0iqk95h, Predicted: 0iqk95h
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0k2lyyc, Predicted: fn18
# True: 0lfjfob, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0me2a, Predicted: 0me2a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0mgnhi, Predicted: 0mgmml
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0msi, Predicted: 0msi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0n5546, Predicted: 0n5546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0nq0e, Predicted: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0nucs59, Predicted: 0aucs59
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0pglswc, Predicted: 0pgi8wc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0pv2w1t, Predicted: 0pv2w1t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0qtjdlvt, Predicted: 0i1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0rlbarm, Predicted: 0rl8arm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0rq9qn, Predicted: 0rq9on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0rw4sjk, Predicted: jrw4sjt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0s2rn2o, Predicted: 052an20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 0scs, Predicted: 0sc5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# True: 0sia, Predicted: dsa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0sm8cb4c, Predicted: om8cb4c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0tbe, Predicted: he
# True: 0u0y5, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0u4aj, Predicted: 0u4aj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 0v4o0p, Predicted: 0t8op
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# True: 0vug13, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0w0pankd, Predicted: mifk2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0wcz1w, Predicted: owcz7w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0wla, Predicted: l1iy1j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 0wy4otel, Predicted: ol12i140tei
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 0yoxyw5, Predicted: 0y0xyw5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 11nm, Predicted: 11nm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1324mrg, Predicted: i324mrg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# True: 13be3kf, Predicted: 17jijf7jkf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 13bsgn2, Predicted: e
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 13v4msh, Predicted: 13v4msh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 13xy, Predicted: i3xy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 153tt0, Predicted: s3kko
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 17z8030, Predicted: zylj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 18gg, Predicted: 78gg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 19hz, Predicted: 19hz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1asdyrv, Predicted: 1asdyrv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1avc, Predicted: 1avc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1awqu, Predicted: 1aw9u
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 1bu55hc, Predicted: 1bu55hc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1c3bi3zm, Predicted: 1c5bimzm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1cfa40wy, Predicted: 1ahjuy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1ctc5l, Predicted: mk0w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1dhcacd, Predicted: 1dhcacd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1dy0p, Predicted: 1o40p
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1e1qxwyz, Predicted: jejqxwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1ed0i9xz, Predicted: 1edoi9xz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1ewgub4, Predicted: 1ew6ub4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1ewq, Predicted: 1ewo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: 1fh4thm, Predicted: ifh4thm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# True: 1gbu5qus, Predicted: 7g8u5qug
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1ghx0spj, Predicted: ighxospj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1hiqbpx3, Predicted: ihiqbpx3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1imwt, Predicted: iimi00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1irn, Predicted: 0i00n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1iwe, Predicted: iiwe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1j2xhu, Predicted: 112xhui
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1k94, Predicted: 1159y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1kfm, Predicted: ihfm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1ku9bzoy, Predicted: 1ku9bzoy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1mrffz, Predicted: 1rff2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1mwa, Predicted: 1mwa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1nyd, Predicted: 1nyd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1o5kcof, Predicted: i05kcof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1ozltu, Predicted: oltu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1qp4885m, Predicted: 1qp4886m
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1rhud8rx, Predicted: knudwx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1sil9, Predicted: il
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1tyn, Predicted: 1tyn
# True: 1u81r, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1ulul, Predicted: 7u1u1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1wu0cul, Predicted: 1ifjijgciji
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1x44n7nx, Predicted: aq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1x8ljpi, Predicted: tm8ljp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 1xut0w4, Predicted: 0xut0w4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 1zcg2o, Predicted: zcg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 20ka8wmo, Predicted: 20ka8wm0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 21iyxsn, Predicted: 21jyh5n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 21z1y, Predicted: 21z1y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 220ofgki, Predicted: irc2l
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 23osam, Predicted: 230sam
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 24idbq3f, Predicted: 24idbq3f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 24y0s85, Predicted: 24y0s85
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 265qfy, Predicted: 265qfy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 26pw3, Predicted: 26pw3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 273u, Predicted: 273u
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 27hibrae, Predicted: q7klbkqe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 29bgk, Predicted: 29bgk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 29or, Predicted: 2m0r
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2aidl, Predicted: 2didi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2bdh, Predicted: 2bdh
# True: 2bjj1pos, Predicted:
# True: 2c5ol, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2cteaog, Predicted: 2ctea0g
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2d0qj, Predicted: 20oqj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2d76, Predicted: 2d76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2ennujkj, Predicted: 2ennujkj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2flvu7n, Predicted: lf3j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2fxu0s, Predicted: 2fxu0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2fyohm, Predicted: 3tylhw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2gbiw7, Predicted: x7n1117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2gquin1i, Predicted: 2gquinii
# True: 2gslhci, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2iulzl, Predicted: 2iulzl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2k1xlp, Predicted: 2k1xlp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2m1qu1e4, Predicted: 2m1qu1e1g
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2mo9qj39, Predicted: 2mej9qj39
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2mvjsa, Predicted: 2mvjsa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2n2it3lx, Predicted: 2n2it3lx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2njlt4, Predicted: 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2o6f, Predicted: n56f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2oa73, Predicted: 20a73
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2oy2f9, Predicted: 2oy2fq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2p6wwybk, Predicted: 2p8wwybh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2q9zjsun, Predicted: az75um
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2qhqtv2, Predicted: k1rf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2rs4jvyr, Predicted: 2rsauvyr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2sp9gvbi, Predicted: 2sp9gvbi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2sxkz2vj, Predicted: 2sxkz2uj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2t02x, Predicted: 2t02x
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2txh8, Predicted: 2txh8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2tyw3, Predicted: 2trw5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2u6t6, Predicted: 2u6t6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2v2n13je, Predicted: 2v2n13je
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2vapwy, Predicted: 2vapwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2w02hmo, Predicted: 2w02mm0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2x7qps0, Predicted: xtqf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2y11w, Predicted: 2y11w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 2y43vf, Predicted: 2y43df
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2ybig03, Predicted: 77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2yjiz, Predicted: 2xjiz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2yjoie, Predicted: xj0ie
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2yqdk, Predicted: 2yqdk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 2zkfhs1n, Predicted: 2zkfhs1n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# True: 2zs3, Predicted: 2zs3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 30rju0c, Predicted: 30rju0c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 30znefk, Predicted: 30i26fk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 31qyiq, Predicted: 31qyiq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 327gm, Predicted: 327gm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 32evcjk8, Predicted: 32eycs58
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 32llr, Predicted: 321ir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 33yxl, Predicted: lf11xt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 345ar, Predicted: 345ar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 35av6, Predicted: 35av6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 36ev8oj, Predicted: 368u801
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 379cfumx, Predicted: 329cfumx
# True: 386h7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 38v2mv, Predicted: 38y2my
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 39fyn9, Predicted: 39fyn9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 39uww47, Predicted: m9uwwh7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3aa8, Predicted: o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3aut4, Predicted: 3aut4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3b84c7sq, Predicted: 9084c7j0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3easf, Predicted: s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3eo06, Predicted: 3wb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3eyys, Predicted: 3eyys
# True: 3flp3ljj, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3fv5o, Predicted: 3fvud0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3g34h, Predicted: 384h
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3g79jlr, Predicted: 3g79jir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3ho9, Predicted: 3a09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3ia0oel, Predicted: 3o8e1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3ido1q0, Predicted: 3ido1q0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3ii4, Predicted: 3ii4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3j61hli, Predicted: irqii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3lsrj, Predicted: 3trj
# True: 3ltl6jon, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3m22, Predicted: 3m22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3mlhaz, Predicted: 3mwh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3mtklt8z, Predicted: 3mtclt8z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3n6o, Predicted: 3n6o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3nnz7pka, Predicted: anz7w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3nw0pr, Predicted: 3nw0pr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3ov5w, Predicted: 30v5w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3psc, Predicted: 3psc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: 3q9kl33x, Predicted: 3q9k33x
# True: 3r677, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: 3s10de, Predicted: 310ac
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: h4f77tdw, Predicted: hfk71t4w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: h4titb0, Predicted: m14fjttjn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: h50769iw, Predicted: h50769iw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: h50uifd, Predicted: m
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: h6dtd, Predicted: h6dtd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: h6o7n, Predicted: h601n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: h7f9, Predicted: h7f9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: h8tg, Predicted: h8tc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hagreh, Predicted: hagreh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: ham46lpd, Predicted: ham46ipd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: haps2, Predicted: 2j7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hb5fz, Predicted: hb5fz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hbll9, Predicted: hb1i9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hc0ulqk, Predicted: k0gk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hc5rx39, Predicted: 11c5rx39
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hc8jk3, Predicted: hwjk3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hciv7, Predicted: hunjvi7i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hcwgu, Predicted: hcwgu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: he7grud, Predicted: he7grud
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hetibp, Predicted: h8tibp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hj5ms, Predicted: hj5ms
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hjbj, Predicted: hibi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hkmy29, Predicted: hkmy29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hl79, Predicted: hl79
# True: hljv6, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hm5osaq, Predicted: irsz7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hnns4, Predicted: hnn64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: ho6v2tsw, Predicted: hc6l2ksw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hptym6, Predicted: xaty36
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hqo6slvr, Predicted: hqo6sivr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hrdksy8, Predicted: hhdky8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hsb1tie, Predicted: hsb1tie
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hsnd7hq, Predicted: h4hd7h1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hvch2er7, Predicted: hjhe7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hvgp, Predicted: hvgp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hvj6wg, Predicted: 4iiii33k11f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hvk6, Predicted: hvk6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hw6ta6, Predicted: hkhok
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hwev766, Predicted: hwev766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hxtahp3, Predicted: i16t8j1e3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: hy850xk1, Predicted: hy85oxki
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: hy8d, Predicted: i1yrq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hyj870q, Predicted: hjia70q
# True: hynvxdz, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: hyp3tvwt, Predicted: yhb5k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i1yipm08, Predicted: nihmi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i23xg1a8, Predicted: 123xgb8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i2d24k, Predicted: j2d24k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i2j3gfg, Predicted: i2j3gfg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i2tc, Predicted: i2tc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i2ximgo, Predicted: 12x1mgo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i3hsnv, Predicted: i5hsnij
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i3ijtc, Predicted: i31jtc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i3jpjs, Predicted: i3jpjs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: i3reuje, Predicted: l3reu6e
# True: i3vv4b7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i4yahaly, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i5aa1, Predicted: i1d1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i5kd0omr, Predicted: ifkd0oif
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# True: i6i6e, Predicted: i6i6e
# True: i7hqc7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i9dhn60, Predicted: i9nh76o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: i9n9a, Predicted: j9n9a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: iackdv2, Predicted: iackov2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: iazoykf, Predicted: a9jk2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# True: ib7372l, Predicted: i61i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: ibkmxh, Predicted: ibkn7xh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# True: ibn9ph, Predicted: 18n9ph
#
# Accuracy on the first 1000 images: 32.10%
