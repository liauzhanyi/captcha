# %%
TRAIN_DATASET_PATH = '/Users/pearl/Downloads/cs4243/train'
TEST_DATASET_PATH = '/Users/pearl/Downloads/cs4243/test'
OUTPUT_PATH = '/Users/pearl/Downloads/cs4243/segmented_train'
SEGMENTED_TRAIN_DATASET_PATH = '/Users/pearl/Downloads/cs4243/segmented_train'
AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH = '/Users/pearl/Downloads/cs4243/augmented_segmented_train'

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt


def gaussian_thresholding(image):
    # Use gaussian blur to make characters thicker before thresholding 
    blur = cv2.GaussianBlur(image, (5, 5), 0)
    thresholded_image = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
        cv2.THRESH_BINARY, blockSize=11, C=2
    )
    return image

def dilate(image):
    #  Remove noise via dilation
    kernel = np.ones((3,3), np.uint8)
    dilation = cv2.dilate(image, kernel, iterations=1)
    
    return dilation

# def adaptive_thresholding(image):
#     thresholded_image = cv2.adaptiveThreshold(
#         image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
#         cv2.THRESH_BINARY, blockSize=11, C=2
#     )
#     return thresholded_image

# def remove_noise(image):
#     kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
#     cleaned_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel, iterations=1)
#     cleaned_image = cv2.morphologyEx(cleaned_image, cv2.MORPH_CLOSE, kernel, iterations=1)
#     return cleaned_image

# def remove_lines(image):
#     lines = cv2.HoughLinesP(image, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)
#     if lines is not None:
#         for line in lines:
#             x1, y1, x2, y2 = line[0]
#             cv2.line(image, (x1, y1), (x2, y2), 0, thickness=2)
#     return image

def segment_characters(image):
    inverted_image = cv2.bitwise_not(image)
    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    char_images = []
    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if h > 10:  # Filter small noise
            char_img = image[y:y+h, x:x+w]
            char_images.append((x, char_img))
    char_images = sorted(char_images, key=lambda c: c[0])  # Sort by x-coordinate

    return [char[1] for char in char_images]

def process_and_save_images(input_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Keep track of how many captchas were skipped
    skipped_count = 0

    # Process each image in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Extract the true label from the filename
            base_name = filename.split('-')[0]

            # Load and preprocess the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Apply preprocessing steps
            image = gaussian_thresholding(image)
            image = dilate(image)
            # image = remove_lines(image)

            # Segment characters
            char_images = segment_characters(image)

            # Validate the number of segmented parts
            if len(char_images) != len(base_name):
                print(f"Skipping {filename}: Expected {len(base_name)} parts, got {len(char_images)}.")
                skipped_count += 1
                continue  # Skip saving this image

            # Save each segmented character follow the naming convention <label_str>-<char>.png
            for idx, char_img in enumerate(char_images):
                char_label = base_name[idx]
                save_name = f"{base_name}-{char_label}.png"
                save_path = os.path.join(output_dir, save_name)

                # Save the segmented character
                cv2.imwrite(save_path, char_img)

    print(f"Processing complete! Segmented characters are saved in {output_dir}")
    print(f"Total skipped: {skipped_count}")


process_and_save_images(TRAIN_DATASET_PATH, SEGMENTED_TRAIN_DATASET_PATH)
# Out:
# Skipping 00fh-0.png: Expected 4 parts, got 0.
# Skipping 00o47-0.png: Expected 5 parts, got 7.
# Skipping 010b-0.png: Expected 4 parts, got 0.
# Skipping 010ud-0.png: Expected 5 parts, got 8.
# Skipping 01gokr0s-0.png: Expected 8 parts, got 9.
# Skipping 02cc-0.png: Expected 4 parts, got 2.
# Skipping 03518k9-0.png: Expected 7 parts, got 8.
# Skipping 03ykb47u-0.png: Expected 8 parts, got 9.
# Skipping 04ue-0.png: Expected 4 parts, got 1.
# Skipping 053e-0.png: Expected 4 parts, got 2.
# Skipping 057ea-0.png: Expected 5 parts, got 4.
# Skipping 06mhii9s-0.png: Expected 8 parts, got 1.
# Skipping 06w6m8y-0.png: Expected 7 parts, got 8.
# Skipping 06xg-0.png: Expected 4 parts, got 1.
# Skipping 06yx8nkv-0.png: Expected 8 parts, got 7.
# Skipping 07r8f9or-0.png: Expected 8 parts, got 5.
# Skipping 07smvpl-0.png: Expected 7 parts, got 6.
# Skipping 07zdo-0.png: Expected 5 parts, got 4.
# Skipping 08mse1o-0.png: Expected 7 parts, got 0.
# Skipping 08vlz-0.png: Expected 5 parts, got 0.
# Skipping 08xj75-0.png: Expected 6 parts, got 1.
# Skipping 09bki-0.png: Expected 5 parts, got 0.
# Skipping 09u8b47-0.png: Expected 7 parts, got 8.
# Skipping 0a1gfi-0.png: Expected 6 parts, got 8.
# Skipping 0axhfa-0.png: Expected 6 parts, got 5.
# Skipping 0bag6mnf-0.png: Expected 8 parts, got 9.
# Skipping 0bcjvo4p-0.png: Expected 8 parts, got 2.
# Skipping 0csa-0.png: Expected 4 parts, got 1.
# Skipping 0d6qvz4x-0.png: Expected 8 parts, got 2.
# Skipping 0duo1r-0.png: Expected 6 parts, got 5.
# Skipping 0dw9b7hd-0.png: Expected 8 parts, got 7.
# Skipping 0dyiae-0.png: Expected 6 parts, got 5.
# Skipping 0e1e-0.png: Expected 4 parts, got 1.
# Skipping 0f91bz-0.png: Expected 6 parts, got 8.
# Skipping 0fm4a3rx-0.png: Expected 8 parts, got 0.
# Skipping 0gfm9dbw-0.png: Expected 8 parts, got 0.
# Skipping 0gi1-0.png: Expected 4 parts, got 3.
# Skipping 0grcaqy-0.png: Expected 7 parts, got 6.
# Skipping 0gwk-0.png: Expected 4 parts, got 5.
# Skipping 0h7htrjq-0.png: Expected 8 parts, got 1.
# Skipping 0hhit-0.png: Expected 5 parts, got 7.
# Skipping 0hox6-0.png: Expected 5 parts, got 4.
# Skipping 0i7o-0.png: Expected 4 parts, got 0.
# Skipping 0ihk7bk-0.png: Expected 7 parts, got 3.
# Skipping 0imxqb2-0.png: Expected 7 parts, got 0.
# Skipping 0jl4-0.png: Expected 4 parts, got 0.
# Skipping 0kl57-0.png: Expected 5 parts, got 4.
# Skipping 0kxu0w-0.png: Expected 6 parts, got 0.
# Skipping 0lov-0.png: Expected 4 parts, got 3.
# Skipping 0m5gzz-0.png: Expected 6 parts, got 5.
# Skipping 0mjig-0.png: Expected 5 parts, got 2.
# Skipping 0my5m1b-0.png: Expected 7 parts, got 0.
# Skipping 0mygmeg-0.png: Expected 7 parts, got 0.
# Skipping 0n8v9-0.png: Expected 5 parts, got 4.
# Skipping 0nhe37q-0.png: Expected 7 parts, got 10.
# Skipping 0nhq9jca-0.png: Expected 8 parts, got 0.
# Skipping 0no6-0.png: Expected 4 parts, got 8.
# Skipping 0ovv-0.png: Expected 4 parts, got 5.
# Skipping 0pl92-0.png: Expected 5 parts, got 6.
# Skipping 0qf323yb-0.png: Expected 8 parts, got 9.
# Skipping 0rf40s-0.png: Expected 6 parts, got 7.
# Skipping 0rnyn-0.png: Expected 5 parts, got 3.
# Skipping 0rvn5xke-0.png: Expected 8 parts, got 5.
# Skipping 0s4iyt8-0.png: Expected 7 parts, got 6.
# Skipping 0si2gw-0.png: Expected 6 parts, got 3.
# Skipping 0sle-0.png: Expected 4 parts, got 2.
# Skipping 0stf-0.png: Expected 4 parts, got 1.
# Skipping 0sw1nb-0.png: Expected 6 parts, got 9.
# Skipping 0sz63i1-0.png: Expected 7 parts, got 6.
# Skipping 0tmvvyfp-0.png: Expected 8 parts, got 9.
# Skipping 0tzo25-0.png: Expected 6 parts, got 1.
# Skipping 0ujb-0.png: Expected 4 parts, got 0.
# Skipping 0umrcy-0.png: Expected 6 parts, got 0.
# Skipping 0v4n-0.png: Expected 4 parts, got 0.
# Skipping 0vngi-0.png: Expected 5 parts, got 8.
# Skipping 0vopim-0.png: Expected 6 parts, got 8.
# Skipping 0wczk9o8-0.png: Expected 8 parts, got 2.
# Skipping 0wwhwf-0.png: Expected 6 parts, got 5.
# Skipping 0x2b-0.png: Expected 4 parts, got 1.
# Skipping 0xfmd4-0.png: Expected 6 parts, got 7.
# Skipping 0xnsjn-0.png: Expected 6 parts, got 1.
# Skipping 0xxukpj-0.png: Expected 7 parts, got 5.
# Skipping 0y2taomx-0.png: Expected 8 parts, got 5.
# Skipping 0ykbzgvb-0.png: Expected 8 parts, got 0.
# Skipping 0yunriz5-0.png: Expected 8 parts, got 10.
# Skipping 1078c-0.png: Expected 5 parts, got 0.
# Skipping 1099dths-0.png: Expected 8 parts, got 6.
# Skipping 10sj-0.png: Expected 4 parts, got 3.
# Skipping 115cip-0.png: Expected 6 parts, got 4.
# Skipping 117l9-0.png: Expected 5 parts, got 2.
# Skipping 12arnksa-0.png: Expected 8 parts, got 9.
# Skipping 12iei2-0.png: Expected 6 parts, got 4.
# Skipping 12ozbizk-0.png: Expected 8 parts, got 3.
# Skipping 12r24cb-0.png: Expected 7 parts, got 6.
# Skipping 12y6y1y-0.png: Expected 7 parts, got 6.
# Skipping 15c3-0.png: Expected 4 parts, got 2.
# Skipping 15t4an-0.png: Expected 6 parts, got 8.
# Skipping 15z2n8-0.png: Expected 6 parts, got 9.
# Skipping 16uzri3v-0.png: Expected 8 parts, got 3.
# Skipping 174u-0.png: Expected 4 parts, got 3.
# Skipping 18o46t-0.png: Expected 6 parts, got 9.
# Skipping 19d7p9-0.png: Expected 6 parts, got 2.
# Skipping 19hoe-0.png: Expected 5 parts, got 4.
# Skipping 19zzp-0.png: Expected 5 parts, got 10.
# Skipping 1b4z-0.png: Expected 4 parts, got 3.
# Skipping 1b88c2-0.png: Expected 6 parts, got 0.
# Skipping 1becisn-0.png: Expected 7 parts, got 9.
# Skipping 1bu7-0.png: Expected 4 parts, got 0.
# Skipping 1cfu8x-0.png: Expected 6 parts, got 5.
# Skipping 1d9gd-0.png: Expected 5 parts, got 3.
# Skipping 1dpd7v-0.png: Expected 6 parts, got 0.
# Skipping 1dswg3sc-0.png: Expected 8 parts, got 0.
# Skipping 1dzo-0.png: Expected 4 parts, got 0.
# Skipping 1ehi-0.png: Expected 4 parts, got 0.
# Skipping 1f8m0nu-0.png: Expected 7 parts, got 0.
# Skipping 1fai6638-0.png: Expected 8 parts, got 12.
# Skipping 1fuhmmn-0.png: Expected 7 parts, got 1.
# Skipping 1g02nte-0.png: Expected 7 parts, got 5.
# Skipping 1gqe-0.png: Expected 4 parts, got 2.
# Skipping 1hk01t-0.png: Expected 6 parts, got 1.
# Skipping 1hlt42-0.png: Expected 6 parts, got 7.
# Skipping 1ht64kj-0.png: Expected 7 parts, got 9.
# Skipping 1hue9-0.png: Expected 5 parts, got 3.
# Skipping 1hznv-0.png: Expected 5 parts, got 4.
# Skipping 1i0oea74-0.png: Expected 8 parts, got 9.
# Skipping 1j3fjd-0.png: Expected 6 parts, got 5.
# Skipping 1jgt-0.png: Expected 4 parts, got 3.
# Skipping 1jnus8-0.png: Expected 6 parts, got 7.
# Skipping 1k0e1-0.png: Expected 5 parts, got 6.
# Skipping 1k2r-0.png: Expected 4 parts, got 3.
# Skipping 1knx-0.png: Expected 4 parts, got 5.
# Skipping 1lib-0.png: Expected 4 parts, got 3.
# Skipping 1m4h-0.png: Expected 4 parts, got 1.
# Skipping 1m7m772e-0.png: Expected 8 parts, got 10.
# Skipping 1mijuxy-0.png: Expected 7 parts, got 5.
# Skipping 1msc-0.png: Expected 4 parts, got 1.
# Skipping 1nk93g-0.png: Expected 6 parts, got 5.
# Skipping 1nov0r3o-0.png: Expected 8 parts, got 10.
# Skipping 1olu4y04-0.png: Expected 8 parts, got 1.
# Skipping 1pbhtt6u-0.png: Expected 8 parts, got 9.
# Skipping 1pksa7t-0.png: Expected 7 parts, got 0.
# Skipping 1s8ii3-0.png: Expected 6 parts, got 2.
# Skipping 1shy04-0.png: Expected 6 parts, got 7.
# Skipping 1su4ar-0.png: Expected 6 parts, got 5.
# Skipping 1t0y82oj-0.png: Expected 8 parts, got 7.
# Skipping 1t7ykc-0.png: Expected 6 parts, got 0.
# Skipping 1u5b3hlt-0.png: Expected 8 parts, got 11.
# Skipping 1u5bgi1-0.png: Expected 7 parts, got 1.
# Skipping 1udt-0.png: Expected 4 parts, got 2.
# Skipping 1vbc15z-0.png: Expected 7 parts, got 1.
# Skipping 1vgz-0.png: Expected 4 parts, got 0.
# Skipping 1vob8r-0.png: Expected 6 parts, got 9.
# Skipping 1vw0zvpw-0.png: Expected 8 parts, got 1.
# Skipping 1w572r-0.png: Expected 6 parts, got 1.
# Skipping 1wmebgw-0.png: Expected 7 parts, got 0.
# Skipping 1wpcmtoh-0.png: Expected 8 parts, got 0.
# Skipping 1wpkup-0.png: Expected 6 parts, got 0.
# Skipping 1x0dmb6-0.png: Expected 7 parts, got 12.
# Skipping 1xk809q-0.png: Expected 7 parts, got 10.
# Skipping 1y50dcgt-0.png: Expected 8 parts, got 1.
# Skipping 1yam8ih9-0.png: Expected 8 parts, got 11.
# Skipping 1ydjf-0.png: Expected 5 parts, got 1.
# Skipping 1yvb-0.png: Expected 4 parts, got 5.
# Skipping 1yyo-0.png: Expected 4 parts, got 5.
# Skipping 1zafz7-0.png: Expected 6 parts, got 5.
# Skipping 1zsaac-0.png: Expected 6 parts, got 0.
# Skipping 20rym-0.png: Expected 5 parts, got 4.
# Skipping 20tzku6e-0.png: Expected 8 parts, got 3.
# Skipping 21n98a3-0.png: Expected 7 parts, got 10.
# Skipping 21y76j6-0.png: Expected 7 parts, got 0.
# Skipping 21zvg6u-0.png: Expected 7 parts, got 6.
# Skipping 227hgav-0.png: Expected 7 parts, got 15.
# Skipping 23bz8q8n-0.png: Expected 8 parts, got 5.
# Skipping 23e4h-0.png: Expected 5 parts, got 3.
# Skipping 23ny7sr-0.png: Expected 7 parts, got 8.
# Skipping 24dx-0.png: Expected 4 parts, got 5.
# Skipping 24hx-0.png: Expected 4 parts, got 5.
# Skipping 24uyja-0.png: Expected 6 parts, got 0.
# Skipping 24zh-0.png: Expected 4 parts, got 0.
# Skipping 251csk-0.png: Expected 6 parts, got 4.
# Skipping 25927mqe-0.png: Expected 8 parts, got 12.
# Skipping 25b4edqd-0.png: Expected 8 parts, got 6.
# Skipping 25t561q-0.png: Expected 7 parts, got 3.
# Skipping 26x1pa-0.png: Expected 6 parts, got 13.
# Skipping 28kqis-0.png: Expected 6 parts, got 0.
# Skipping 28rqld-0.png: Expected 6 parts, got 5.
# Skipping 29k2a-0.png: Expected 5 parts, got 0.
# Skipping 29w3yq-0.png: Expected 6 parts, got 8.
# Skipping 2anr-0.png: Expected 4 parts, got 2.
# Skipping 2aofi-0.png: Expected 5 parts, got 2.
# Skipping 2at5l1k9-0.png: Expected 8 parts, got 0.
# Skipping 2b4d-0.png: Expected 4 parts, got 1.
# Skipping 2bd9wa3-0.png: Expected 7 parts, got 0.
# Skipping 2bh4x6x-0.png: Expected 7 parts, got 3.
# Skipping 2cg2og8e-0.png: Expected 8 parts, got 4.
# Skipping 2dkp9x-0.png: Expected 6 parts, got 4.
# Skipping 2e6i-0.png: Expected 4 parts, got 0.
# Skipping 2f48g-0.png: Expected 5 parts, got 3.
# Skipping 2fgthyo9-0.png: Expected 8 parts, got 6.
# Skipping 2fvmeb4-0.png: Expected 7 parts, got 9.
# Skipping 2fvrrfg-0.png: Expected 7 parts, got 8.
# Skipping 2g0fg-0.png: Expected 5 parts, got 4.
# Skipping 2gfo66dh-0.png: Expected 8 parts, got 6.
# Skipping 2ggtipg-0.png: Expected 7 parts, got 6.
# Skipping 2gn63i-0.png: Expected 6 parts, got 4.
# Skipping 2hmi-0.png: Expected 4 parts, got 5.
# Skipping 2hr9d9-0.png: Expected 6 parts, got 10.
# Skipping 2jano-0.png: Expected 5 parts, got 4.
# Skipping 2kiz79h-0.png: Expected 7 parts, got 4.
# Skipping 2l2a3-0.png: Expected 5 parts, got 0.
# Skipping 2lt1-0.png: Expected 4 parts, got 3.
# Skipping 2lylbmw-0.png: Expected 7 parts, got 6.
# Skipping 2m4e97yo-0.png: Expected 8 parts, got 9.
# Skipping 2ogcaj-0.png: Expected 6 parts, got 4.
# Skipping 2pxbrb-0.png: Expected 6 parts, got 1.
# Skipping 2qj98he-0.png: Expected 7 parts, got 0.
# Skipping 2qugryl-0.png: Expected 7 parts, got 6.
# Skipping 2qzvpp-0.png: Expected 6 parts, got 4.
# Skipping 2roqqy4c-0.png: Expected 8 parts, got 3.
# Skipping 2sdnije-0.png: Expected 7 parts, got 0.
# Skipping 2uba9hkt-0.png: Expected 8 parts, got 5.
# Skipping 2ufo9hqq-0.png: Expected 8 parts, got 9.
# Skipping 2uknf1-0.png: Expected 6 parts, got 0.
# Skipping 2urroi-0.png: Expected 6 parts, got 8.
# Skipping 2wf8ae3g-0.png: Expected 8 parts, got 6.
# Skipping 2x65-0.png: Expected 4 parts, got 2.
# Skipping 2x6xzl9-0.png: Expected 7 parts, got 2.
# Skipping 2x6ygp-0.png: Expected 6 parts, got 0.
# Skipping 2xyvo-0.png: Expected 5 parts, got 2.
# Skipping 2y72vr-0.png: Expected 6 parts, got 8.
# Skipping 2zff-0.png: Expected 4 parts, got 2.
# Skipping 2zimhl0-0.png: Expected 7 parts, got 0.
# Skipping 30u6-0.png: Expected 4 parts, got 5.
# Skipping 311fkbdg-0.png: Expected 8 parts, got 7.
# Skipping 31kz-0.png: Expected 4 parts, got 3.
# Skipping 32917thd-0.png: Expected 8 parts, got 0.
# Skipping 329cx08-0.png: Expected 7 parts, got 0.
# Skipping 32o7-0.png: Expected 4 parts, got 1.
# Skipping 32pt-0.png: Expected 4 parts, got 6.
# Skipping 3319u-0.png: Expected 5 parts, got 1.
# Skipping 33200cco-0.png: Expected 8 parts, got 5.
# Skipping 33naz-0.png: Expected 5 parts, got 2.
# Skipping 347s-0.png: Expected 4 parts, got 3.
# Skipping 348iv-0.png: Expected 5 parts, got 7.
# Skipping 34og7pyo-0.png: Expected 8 parts, got 0.
# Skipping 34vjemc-0.png: Expected 7 parts, got 5.
# Skipping 356ccu-0.png: Expected 6 parts, got 12.
# Skipping 357azsc-0.png: Expected 7 parts, got 2.
# Skipping 35mziw-0.png: Expected 6 parts, got 9.
# Skipping 363r-0.png: Expected 4 parts, got 2.
# Skipping 369b4-0.png: Expected 5 parts, got 6.
# Skipping 36rf-0.png: Expected 4 parts, got 3.
# Skipping 37fhsm2-0.png: Expected 7 parts, got 0.
# Skipping 37ly-0.png: Expected 4 parts, got 3.
# Skipping 38ap-0.png: Expected 4 parts, got 8.
# Skipping 38ccou-0.png: Expected 6 parts, got 4.
# Skipping 38obikh-0.png: Expected 7 parts, got 2.
# Skipping 38sh-0.png: Expected 4 parts, got 0.
# Skipping 394r1ld-0.png: Expected 7 parts, got 8.
# Skipping 39em-0.png: Expected 4 parts, got 3.
# Skipping 3amh-0.png: Expected 4 parts, got 2.
# Skipping 3b3a0-0.png: Expected 5 parts, got 6.
# Skipping 3be3z-0.png: Expected 5 parts, got 0.
# Skipping 3bxdtr9-0.png: Expected 7 parts, got 8.
# Skipping 3cnr4p9-0.png: Expected 7 parts, got 1.
# Skipping 3d2e-0.png: Expected 4 parts, got 0.
# Skipping 3e4p-0.png: Expected 4 parts, got 0.
# Skipping 3es0-0.png: Expected 4 parts, got 0.
# Skipping 3fqd23r-0.png: Expected 7 parts, got 9.
# Skipping 3fswd8-0.png: Expected 6 parts, got 7.
# Skipping 3g65-0.png: Expected 4 parts, got 3.
# Skipping 3geu5-0.png: Expected 5 parts, got 6.
# Skipping 3gnzz-0.png: Expected 5 parts, got 6.
# Skipping 3iyid-0.png: Expected 5 parts, got 7.
# Skipping 3j9gcdp-0.png: Expected 7 parts, got 1.
# Skipping 3k0n3pad-0.png: Expected 8 parts, got 0.
# Skipping 3kyutzk-0.png: Expected 7 parts, got 6.
# Skipping 3l7brc-0.png: Expected 6 parts, got 2.
# Skipping 3lkh9-0.png: Expected 5 parts, got 6.
# Skipping 3lvvlu4-0.png: Expected 7 parts, got 8.
# Skipping 3lxkt-0.png: Expected 5 parts, got 0.
# Skipping 3m8al-0.png: Expected 5 parts, got 4.
# Skipping 3ns6o1dj-0.png: Expected 8 parts, got 10.
# Skipping 3o6u-0.png: Expected 4 parts, got 5.
# Skipping 3otukim-0.png: Expected 7 parts, got 6.
# Skipping 3parb27i-0.png: Expected 8 parts, got 7.
# Skipping 3pkp-0.png: Expected 4 parts, got 3.
# Skipping 3pp1pc-0.png: Expected 6 parts, got 5.
# Skipping 3qdkyexn-0.png: Expected 8 parts, got 0.
# Skipping 3qi961-0.png: Expected 6 parts, got 0.
# Skipping 3qi9bll-0.png: Expected 7 parts, got 0.
# Skipping 3qm2p1m-0.png: Expected 7 parts, got 0.
# Skipping 3qv27-0.png: Expected 5 parts, got 4.
# Skipping 3rsu0pwz-0.png: Expected 8 parts, got 5.
# Skipping 3s2k5-0.png: Expected 5 parts, got 3.
# Skipping 3sksn-0.png: Expected 5 parts, got 2.
# Skipping 3spzvbk-0.png: Expected 7 parts, got 3.
# Skipping 3ts5-0.png: Expected 4 parts, got 3.
# Skipping 3tvbwkj-0.png: Expected 7 parts, got 0.
# Skipping 3u35r3-0.png: Expected 6 parts, got 10.
# Skipping 3um65ck5-0.png: Expected 8 parts, got 0.
# Skipping 3uqd-0.png: Expected 4 parts, got 2.
# Skipping 3v17ro93-0.png: Expected 8 parts, got 7.
# Skipping 3v5rt7-0.png: Expected 6 parts, got 7.
# Skipping 3vsldhma-0.png: Expected 8 parts, got 9.
# Skipping 3wcsp3-0.png: Expected 6 parts, got 10.
# Skipping 3wrs2p-0.png: Expected 6 parts, got 1.
# Skipping 3xf2-0.png: Expected 4 parts, got 0.
# Skipping 3xfvi-0.png: Expected 5 parts, got 6.
# Skipping 3xh6-0.png: Expected 4 parts, got 0.
# Skipping 3yc6be-0.png: Expected 6 parts, got 7.
# Skipping 3yfc6jy-0.png: Expected 7 parts, got 1.
# Skipping 3zb67dd6-0.png: Expected 8 parts, got 7.
# Skipping 4194-0.png: Expected 4 parts, got 7.
# Skipping 41a67-0.png: Expected 5 parts, got 3.
# Skipping 41w6qvtq-0.png: Expected 8 parts, got 10.
# Skipping 422g0b-0.png: Expected 6 parts, got 10.
# Skipping 42o75-0.png: Expected 5 parts, got 10.
# Skipping 42x8-0.png: Expected 4 parts, got 1.
# Skipping 42ywd-0.png: Expected 5 parts, got 0.
# Skipping 43b16p-0.png: Expected 6 parts, got 7.
# Skipping 43i4-0.png: Expected 4 parts, got 3.
# Skipping 43u1voui-0.png: Expected 8 parts, got 0.
# Skipping 440cq-0.png: Expected 5 parts, got 9.
# Skipping 441bz-0.png: Expected 5 parts, got 7.
# Skipping 444kmpf-0.png: Expected 7 parts, got 8.
# Skipping 444z9exx-0.png: Expected 8 parts, got 7.
# Skipping 447hq49-0.png: Expected 7 parts, got 4.
# Skipping 449ftp-0.png: Expected 6 parts, got 0.
# Skipping 44fe-0.png: Expected 4 parts, got 0.
# Skipping 44y4ih3-0.png: Expected 7 parts, got 5.
# Skipping 45fu-0.png: Expected 4 parts, got 5.
# Skipping 463o-0.png: Expected 4 parts, got 0.
# Skipping 473dzh5-0.png: Expected 7 parts, got 5.
# Skipping 47a48re-0.png: Expected 7 parts, got 1.
# Skipping 480c-0.png: Expected 4 parts, got 3.
# Skipping 48h7-0.png: Expected 4 parts, got 5.
# Skipping 48p951o5-0.png: Expected 8 parts, got 13.
# Skipping 48ri-0.png: Expected 4 parts, got 1.
# Skipping 48zgrln-0.png: Expected 7 parts, got 5.
# Skipping 498brbe-0.png: Expected 7 parts, got 0.
# Skipping 4bbd15-0.png: Expected 6 parts, got 0.
# Skipping 4bek73-0.png: Expected 6 parts, got 3.
# Skipping 4bkgh-0.png: Expected 5 parts, got 0.
# Skipping 4c0booxn-0.png: Expected 8 parts, got 7.
# Skipping 4d3wu-0.png: Expected 5 parts, got 1.
# Skipping 4dmk7-0.png: Expected 5 parts, got 10.
# Skipping 4dmm-0.png: Expected 4 parts, got 0.
# Skipping 4e4qjny7-0.png: Expected 8 parts, got 4.
# Skipping 4eg6-0.png: Expected 4 parts, got 6.
# Skipping 4fc1e-0.png: Expected 5 parts, got 1.
# Skipping 4ff7pwx-0.png: Expected 7 parts, got 1.
# Skipping 4ft9k7qn-0.png: Expected 8 parts, got 0.
# Skipping 4fw61vc-0.png: Expected 7 parts, got 6.
# Skipping 4fyq-0.png: Expected 4 parts, got 1.
# Skipping 4i29-0.png: Expected 4 parts, got 0.
# Skipping 4i58-0.png: Expected 4 parts, got 1.
# Skipping 4i669we-0.png: Expected 7 parts, got 1.
# Skipping 4i9z-0.png: Expected 4 parts, got 5.
# Skipping 4ih1w4-0.png: Expected 6 parts, got 7.
# Skipping 4iu4cjd-0.png: Expected 7 parts, got 5.
# Skipping 4jjv-0.png: Expected 4 parts, got 0.
# Skipping 4jl9-0.png: Expected 4 parts, got 3.
# Skipping 4kht8-0.png: Expected 5 parts, got 0.
# Skipping 4knef0-0.png: Expected 6 parts, got 7.
# Skipping 4kocxrt-0.png: Expected 7 parts, got 6.
# Skipping 4mb632-0.png: Expected 6 parts, got 0.
# Skipping 4mck-0.png: Expected 4 parts, got 3.
# Skipping 4mlcnn0-0.png: Expected 7 parts, got 13.
# Skipping 4myn-0.png: Expected 4 parts, got 1.
# Skipping 4nx86y-0.png: Expected 6 parts, got 0.
# Skipping 4o1cgem-0.png: Expected 7 parts, got 8.
# Skipping 4o8zt-0.png: Expected 5 parts, got 2.
# Skipping 4p7cky-0.png: Expected 6 parts, got 3.
# Skipping 4pa6-0.png: Expected 4 parts, got 1.
# Skipping 4pafxd-0.png: Expected 6 parts, got 5.
# Skipping 4q433u82-0.png: Expected 8 parts, got 0.
# Skipping 4rcb-0.png: Expected 4 parts, got 0.
# Skipping 4rso377-0.png: Expected 7 parts, got 8.
# Skipping 4rvj-0.png: Expected 4 parts, got 0.
# Skipping 4tlgz8-0.png: Expected 6 parts, got 3.
# Skipping 4tu9fi2-0.png: Expected 7 parts, got 0.
# Skipping 4u7fh0-0.png: Expected 6 parts, got 10.
# Skipping 4uv2-0.png: Expected 4 parts, got 5.
# Skipping 4va4qss-0.png: Expected 7 parts, got 8.
# Skipping 4vatp9k7-0.png: Expected 8 parts, got 7.
# Skipping 4vsfs-0.png: Expected 5 parts, got 4.
# Skipping 4vzc-0.png: Expected 4 parts, got 1.
# Skipping 4wtr-0.png: Expected 4 parts, got 0.
# Skipping 4wy55-0.png: Expected 5 parts, got 4.
# Skipping 4x4d2-0.png: Expected 5 parts, got 0.
# Skipping 4xqp4g-0.png: Expected 6 parts, got 5.
# Skipping 4yh2-0.png: Expected 4 parts, got 0.
# Skipping 4z292-0.png: Expected 5 parts, got 4.
# Skipping 4z79pirj-0.png: Expected 8 parts, got 1.
# Skipping 4zwzcs8-0.png: Expected 7 parts, got 0.
# Skipping 50rknq-0.png: Expected 6 parts, got 4.
# Skipping 50vhxk-0.png: Expected 6 parts, got 8.
# Skipping 50vy-0.png: Expected 4 parts, got 0.
# Skipping 50yc8-0.png: Expected 5 parts, got 2.
# Skipping 51oap8f-0.png: Expected 7 parts, got 6.
# Skipping 52qoqji-0.png: Expected 7 parts, got 1.
# Skipping 52tqpn0e-0.png: Expected 8 parts, got 1.
# Skipping 53o8o2-0.png: Expected 6 parts, got 5.
# Skipping 53vmg7b-0.png: Expected 7 parts, got 8.
# Skipping 54krh-0.png: Expected 5 parts, got 4.
# Skipping 55vrsa8p-0.png: Expected 8 parts, got 7.
# Skipping 55ychzt-0.png: Expected 7 parts, got 1.
# Skipping 569lml-0.png: Expected 6 parts, got 0.
# Skipping 56eca-0.png: Expected 5 parts, got 1.
# Skipping 57s14-0.png: Expected 5 parts, got 3.
# Skipping 582v0k-0.png: Expected 6 parts, got 7.
# Skipping 58bp1pgm-0.png: Expected 8 parts, got 7.
# Skipping 59nl1yr5-0.png: Expected 8 parts, got 0.
# Skipping 59xhq-0.png: Expected 5 parts, got 4.
# Skipping 5age6-0.png: Expected 5 parts, got 4.
# Skipping 5ai8ko-0.png: Expected 6 parts, got 7.
# Skipping 5ait-0.png: Expected 4 parts, got 0.
# Skipping 5b2bh05-0.png: Expected 7 parts, got 6.
# Skipping 5ccaiavz-0.png: Expected 8 parts, got 6.
# Skipping 5djybypt-0.png: Expected 8 parts, got 7.
# Skipping 5dtoxa-0.png: Expected 6 parts, got 4.
# Skipping 5e2thl-0.png: Expected 6 parts, got 0.
# Skipping 5e3iz5d5-0.png: Expected 8 parts, got 7.
# Skipping 5edl-0.png: Expected 4 parts, got 0.
# Skipping 5eno1np-0.png: Expected 7 parts, got 8.
# Skipping 5f928u-0.png: Expected 6 parts, got 9.
# Skipping 5fk4me-0.png: Expected 6 parts, got 0.
# Skipping 5fntvt-0.png: Expected 6 parts, got 1.
# Skipping 5fywtys-0.png: Expected 7 parts, got 1.
# Skipping 5g243-0.png: Expected 5 parts, got 4.
# Skipping 5ggh8o-0.png: Expected 6 parts, got 0.
# Skipping 5gomqbt-0.png: Expected 7 parts, got 10.
# Skipping 5h6uvse8-0.png: Expected 8 parts, got 3.
# Skipping 5icltk07-0.png: Expected 8 parts, got 7.
# Skipping 5idgdn-0.png: Expected 6 parts, got 1.
# Skipping 5ie69wtf-0.png: Expected 8 parts, got 9.
# Skipping 5ifb3-0.png: Expected 5 parts, got 0.
# Skipping 5jae-0.png: Expected 4 parts, got 2.
# Skipping 5jcv-0.png: Expected 4 parts, got 8.
# Skipping 5kwapv-0.png: Expected 6 parts, got 7.
# Skipping 5l0eu5c-0.png: Expected 7 parts, got 8.
# Skipping 5l93heb-0.png: Expected 7 parts, got 6.
# Skipping 5lcr-0.png: Expected 4 parts, got 0.
# Skipping 5n95t-0.png: Expected 5 parts, got 4.
# Skipping 5p9h-0.png: Expected 4 parts, got 5.
# Skipping 5ph33-0.png: Expected 5 parts, got 6.
# Skipping 5poop-0.png: Expected 5 parts, got 4.
# Skipping 5qm9rwrq-0.png: Expected 8 parts, got 7.
# Skipping 5qxdu-0.png: Expected 5 parts, got 4.
# Skipping 5rbfpwt-0.png: Expected 7 parts, got 14.
# Skipping 5sza3-0.png: Expected 5 parts, got 4.
# Skipping 5t6g-0.png: Expected 4 parts, got 2.
# Skipping 5treqnua-0.png: Expected 8 parts, got 0.
# Skipping 5u3y3t-0.png: Expected 6 parts, got 5.
# Skipping 5uafo-0.png: Expected 5 parts, got 4.
# Skipping 5uiux-0.png: Expected 5 parts, got 8.
# Skipping 5vd4-0.png: Expected 4 parts, got 0.
# Skipping 5vd9-0.png: Expected 4 parts, got 2.
# Skipping 5vgjp-0.png: Expected 5 parts, got 0.
# Skipping 5vzq-0.png: Expected 4 parts, got 0.
# Skipping 5w0cc-0.png: Expected 5 parts, got 6.
# Skipping 5w2p2-0.png: Expected 5 parts, got 9.
# Skipping 5w5vfsz-0.png: Expected 7 parts, got 5.
# Skipping 5yfc-0.png: Expected 4 parts, got 0.
# Skipping 5yiwz-0.png: Expected 5 parts, got 6.
# Skipping 5zge-0.png: Expected 4 parts, got 3.
# Skipping 5zkkh8-0.png: Expected 6 parts, got 5.
# Skipping 604ont5-0.png: Expected 7 parts, got 5.
# Skipping 60j6f-0.png: Expected 5 parts, got 2.
# Skipping 60rd08ji-0.png: Expected 8 parts, got 10.
# Skipping 6mhm-0.png: Expected 4 parts, got 5.
# Skipping 6n4qn7-0.png: Expected 6 parts, got 9.
# Skipping 6ocl0d1-0.png: Expected 7 parts, got 6.
# Skipping 6od31q-0.png: Expected 6 parts, got 3.
# Skipping 6op8-0.png: Expected 4 parts, got 0.
# Skipping 6pnn74-0.png: Expected 6 parts, got 2.
# Skipping 6q84ibe-0.png: Expected 7 parts, got 0.
# Skipping 6rw7x-0.png: Expected 5 parts, got 0.
# Skipping 6sdnex1-0.png: Expected 7 parts, got 0.
# Skipping 6soqfbku-0.png: Expected 8 parts, got 6.
# Skipping 6sre2n-0.png: Expected 6 parts, got 2.
# Skipping 6t6v-0.png: Expected 4 parts, got 5.
# Skipping 6t82hn7h-0.png: Expected 8 parts, got 6.
# Skipping 6tch63a-0.png: Expected 7 parts, got 8.
# Skipping 6ti6e1d-0.png: Expected 7 parts, got 0.
# Skipping 6toeeyqt-0.png: Expected 8 parts, got 7.
# Skipping 6uno-0.png: Expected 4 parts, got 6.
# Skipping 6v36-0.png: Expected 4 parts, got 1.
# Skipping 6vnazff-0.png: Expected 7 parts, got 5.
# Skipping 6vov-0.png: Expected 4 parts, got 0.
# Skipping 6vq8d3p-0.png: Expected 7 parts, got 6.
# Skipping 6vwq2ve-0.png: Expected 7 parts, got 6.
# Skipping 6vwvgo6-0.png: Expected 7 parts, got 0.
# Skipping 6wdcs-0.png: Expected 5 parts, got 0.
# Skipping 6wpo9y4-0.png: Expected 7 parts, got 3.
# Skipping 6xl3aw-0.png: Expected 6 parts, got 7.
# Skipping 6xrf-0.png: Expected 4 parts, got 3.
# Skipping 6yxdy-0.png: Expected 5 parts, got 6.
# Skipping 6z007hv0-0.png: Expected 8 parts, got 1.
# Skipping 6zdkq7o-0.png: Expected 7 parts, got 0.
# Skipping 701n0f-0.png: Expected 6 parts, got 8.
# Skipping 7094tgmo-0.png: Expected 8 parts, got 4.
# Skipping 70do56y-0.png: Expected 7 parts, got 3.
# Skipping 70n12tn-0.png: Expected 7 parts, got 9.
# Skipping 71ag-0.png: Expected 4 parts, got 5.
# Skipping 71pk-0.png: Expected 4 parts, got 5.
# Skipping 73mc7-0.png: Expected 5 parts, got 4.
# Skipping 74h0lpb-0.png: Expected 7 parts, got 0.
# Skipping 74r1c319-0.png: Expected 8 parts, got 9.
# Skipping 74svltny-0.png: Expected 8 parts, got 9.
# Skipping 75hetxz-0.png: Expected 7 parts, got 5.
# Skipping 75qb0jc9-0.png: Expected 8 parts, got 0.
# Skipping 765iii9-0.png: Expected 7 parts, got 4.
# Skipping 7681vc-0.png: Expected 6 parts, got 4.
# Skipping 76jot9a3-0.png: Expected 8 parts, got 7.
# Skipping 76sp8v-0.png: Expected 6 parts, got 7.
# Skipping 76xt-0.png: Expected 4 parts, got 0.
# Skipping 772jfic4-0.png: Expected 8 parts, got 7.
# Skipping 777h0nq-0.png: Expected 7 parts, got 5.
# Skipping 77a0h0i-0.png: Expected 7 parts, got 8.
# Skipping 77sbo-0.png: Expected 5 parts, got 4.
# Skipping 781kqo9-0.png: Expected 7 parts, got 0.
# Skipping 78hab06-0.png: Expected 7 parts, got 11.
# Skipping 78hw61-0.png: Expected 6 parts, got 7.
# Skipping 79jsr0pe-0.png: Expected 8 parts, got 9.
# Skipping 79qx0fis-0.png: Expected 8 parts, got 1.
# Skipping 7b2wneu-0.png: Expected 7 parts, got 1.
# Skipping 7b97z-0.png: Expected 5 parts, got 1.
# Skipping 7bcjn-0.png: Expected 5 parts, got 1.
# Skipping 7brd8h00-0.png: Expected 8 parts, got 4.
# Skipping 7bti0u-0.png: Expected 6 parts, got 8.
# Skipping 7c9819-0.png: Expected 6 parts, got 11.
# Skipping 7cyn-0.png: Expected 4 parts, got 7.
# Skipping 7d9k3-0.png: Expected 5 parts, got 4.
# Skipping 7dqtxy-0.png: Expected 6 parts, got 2.
# Skipping 7etjsrio-0.png: Expected 8 parts, got 6.
# Skipping 7etzoob-0.png: Expected 7 parts, got 6.
# Skipping 7fnlfb4t-0.png: Expected 8 parts, got 6.
# Skipping 7fptq5ti-0.png: Expected 8 parts, got 5.
# Skipping 7genwgh-0.png: Expected 7 parts, got 8.
# Skipping 7gk0bha-0.png: Expected 7 parts, got 0.
# Skipping 7heenhd-0.png: Expected 7 parts, got 0.
# Skipping 7hqqs7-0.png: Expected 6 parts, got 12.
# Skipping 7hyn7eq-0.png: Expected 7 parts, got 11.
# Skipping 7icfzcyg-0.png: Expected 8 parts, got 5.
# Skipping 7ih0-0.png: Expected 4 parts, got 5.
# Skipping 7iv4-0.png: Expected 4 parts, got 3.
# Skipping 7izgh-0.png: Expected 5 parts, got 1.
# Skipping 7m4dsw-0.png: Expected 6 parts, got 4.
# Skipping 7nn8-0.png: Expected 4 parts, got 6.
# Skipping 7nxwy-0.png: Expected 5 parts, got 3.
# Skipping 7o68a-0.png: Expected 5 parts, got 4.
# Skipping 7o8sa-0.png: Expected 5 parts, got 0.
# Skipping 7onsn-0.png: Expected 5 parts, got 6.
# Skipping 7p6te6h-0.png: Expected 7 parts, got 0.
# Skipping 7py6rx41-0.png: Expected 8 parts, got 0.
# Skipping 7pzrx0ct-0.png: Expected 8 parts, got 7.
# Skipping 7q8888-0.png: Expected 6 parts, got 8.
# Skipping 7qr4opg-0.png: Expected 7 parts, got 5.
# Skipping 7qy4-0.png: Expected 4 parts, got 3.
# Skipping 7rl3w0-0.png: Expected 6 parts, got 0.
# Skipping 7s0txxh-0.png: Expected 7 parts, got 3.
# Skipping 7s265-0.png: Expected 5 parts, got 4.
# Skipping 7twrv-0.png: Expected 5 parts, got 4.
# Skipping 7tz8-0.png: Expected 4 parts, got 3.
# Skipping 7uhliq98-0.png: Expected 8 parts, got 7.
# Skipping 7uoz9keb-0.png: Expected 8 parts, got 7.
# Skipping 7urzpkn-0.png: Expected 7 parts, got 0.
# Skipping 7v2460-0.png: Expected 6 parts, got 8.
# Skipping 7wd4e-0.png: Expected 5 parts, got 2.
# Skipping 7wqt-0.png: Expected 4 parts, got 3.
# Skipping 7wrz-0.png: Expected 4 parts, got 5.
# Skipping 7wvww6-0.png: Expected 6 parts, got 3.
# Skipping 7xyrf2c-0.png: Expected 7 parts, got 3.
# Skipping 7y0cynw-0.png: Expected 7 parts, got 9.
# Skipping 7ypolv8-0.png: Expected 7 parts, got 8.
# Skipping 7yv3h-0.png: Expected 5 parts, got 3.
# Skipping 80a79g-0.png: Expected 6 parts, got 0.
# Skipping 80cmz27f-0.png: Expected 8 parts, got 9.
# Skipping 80qxfez1-0.png: Expected 8 parts, got 1.
# Skipping 81x9da4a-0.png: Expected 8 parts, got 0.
# Skipping 82nr-0.png: Expected 4 parts, got 5.
# Skipping 82te98w3-0.png: Expected 8 parts, got 0.
# Skipping 82vxl6vy-0.png: Expected 8 parts, got 1.
# Skipping 839cg-0.png: Expected 5 parts, got 6.
# Skipping 854d4-0.png: Expected 5 parts, got 0.
# Skipping 85i10jy-0.png: Expected 7 parts, got 0.
# Skipping 8663ssg-0.png: Expected 7 parts, got 0.
# Skipping 87vrx-0.png: Expected 5 parts, got 3.
# Skipping 882u06ey-0.png: Expected 8 parts, got 1.
# Skipping 88iaqi-0.png: Expected 6 parts, got 4.
# Skipping 88py-0.png: Expected 4 parts, got 10.
# Skipping 8ce92-0.png: Expected 5 parts, got 2.
# Skipping 8cxf97n1-0.png: Expected 8 parts, got 5.
# Skipping 8cyjlhnp-0.png: Expected 8 parts, got 7.
# Skipping 8d2y98-0.png: Expected 6 parts, got 5.
# Skipping 8f0agm0r-0.png: Expected 8 parts, got 9.
# Skipping 8fdn01f-0.png: Expected 7 parts, got 6.
# Skipping 8ff3g25-0.png: Expected 7 parts, got 0.
# Skipping 8fjn-0.png: Expected 4 parts, got 0.
# Skipping 8fqrws-0.png: Expected 6 parts, got 7.
# Skipping 8g04-0.png: Expected 4 parts, got 0.
# Skipping 8ggxk-0.png: Expected 5 parts, got 2.
# Skipping 8gr6z-0.png: Expected 5 parts, got 4.
# Skipping 8gxnsua3-0.png: Expected 8 parts, got 9.
# Skipping 8h218ub-0.png: Expected 7 parts, got 1.
# Skipping 8hbd5c-0.png: Expected 6 parts, got 7.
# Skipping 8hxj-0.png: Expected 4 parts, got 0.
# Skipping 8ijm4l-0.png: Expected 6 parts, got 1.
# Skipping 8iyt-0.png: Expected 4 parts, got 5.
# Skipping 8izy-0.png: Expected 4 parts, got 2.
# Skipping 8jbtjs-0.png: Expected 6 parts, got 0.
# Skipping 8l8hmh-0.png: Expected 6 parts, got 2.
# Skipping 8lp9-0.png: Expected 4 parts, got 2.
# Skipping 8mcwv-0.png: Expected 5 parts, got 0.
# Skipping 8mfai4-0.png: Expected 6 parts, got 4.
# Skipping 8nitobic-0.png: Expected 8 parts, got 6.
# Skipping 8nogbc-0.png: Expected 6 parts, got 3.
# Skipping 8npspa-0.png: Expected 6 parts, got 3.
# Skipping 8o8379d-0.png: Expected 7 parts, got 3.
# Skipping 8ouita-0.png: Expected 6 parts, got 7.
# Skipping 8pfi4-0.png: Expected 5 parts, got 2.
# Skipping 8psdsaa-0.png: Expected 7 parts, got 5.
# Skipping 8ptz473-0.png: Expected 7 parts, got 5.
# Skipping 8pvuo2gt-0.png: Expected 8 parts, got 5.
# Skipping 8q0x-0.png: Expected 4 parts, got 1.
# Skipping 8q58-0.png: Expected 4 parts, got 5.
# Skipping 8q9r-0.png: Expected 4 parts, got 1.
# Skipping 8qdh-0.png: Expected 4 parts, got 5.
# Skipping 8qepaf3-0.png: Expected 7 parts, got 10.
# Skipping 8qup-0.png: Expected 4 parts, got 1.
# Skipping 8qvn-0.png: Expected 4 parts, got 6.
# Skipping 8qzox7x-0.png: Expected 7 parts, got 0.
# Skipping 8s0r6-0.png: Expected 5 parts, got 10.
# Skipping 8shgmq-0.png: Expected 6 parts, got 5.
# Skipping 8sq2w6z-0.png: Expected 7 parts, got 0.
# Skipping 8u2yxjmu-0.png: Expected 8 parts, got 11.
# Skipping 8v14kl-0.png: Expected 6 parts, got 4.
# Skipping 8vep-0.png: Expected 4 parts, got 3.
# Skipping 8x0pjn-0.png: Expected 6 parts, got 11.
# Skipping 8x7l-0.png: Expected 4 parts, got 0.
# Skipping 8x8k3-0.png: Expected 5 parts, got 0.
# Skipping 8yrtxj-0.png: Expected 6 parts, got 0.
# Skipping 8yv00c-0.png: Expected 6 parts, got 0.
# Skipping 8zdzgsf3-0.png: Expected 8 parts, got 0.
# Skipping 8zfaxm-0.png: Expected 6 parts, got 4.
# Skipping 8zq47-0.png: Expected 5 parts, got 7.
# Skipping 9173l-0.png: Expected 5 parts, got 4.
# Skipping 91nok-0.png: Expected 5 parts, got 6.
# Skipping 91qs4qf-0.png: Expected 7 parts, got 10.
# Skipping 92q7-0.png: Expected 4 parts, got 1.
# Skipping 92xyvp-0.png: Expected 6 parts, got 8.
# Skipping 937rz9-0.png: Expected 6 parts, got 2.
# Skipping 93hssl-0.png: Expected 6 parts, got 7.
# Skipping 93s68fxh-0.png: Expected 8 parts, got 12.
# Skipping 955udj8o-0.png: Expected 8 parts, got 12.
# Skipping 95cld-0.png: Expected 5 parts, got 7.
# Skipping 96b7kz4p-0.png: Expected 8 parts, got 12.
# Skipping 96gvsow-0.png: Expected 7 parts, got 0.
# Skipping 99fbon-0.png: Expected 6 parts, got 11.
# Skipping 99l4g0l-0.png: Expected 7 parts, got 8.
# Skipping 99mqhb-0.png: Expected 6 parts, got 4.
# Skipping 99xgc9m2-0.png: Expected 8 parts, got 7.
# Skipping 9a2xdo-0.png: Expected 6 parts, got 0.
# Skipping 9abwl0a-0.png: Expected 7 parts, got 5.
# Skipping 9aeol3h-0.png: Expected 7 parts, got 12.
# Skipping 9bj5m0m-0.png: Expected 7 parts, got 0.
# Skipping 9bqm45xe-0.png: Expected 8 parts, got 10.
# Skipping 9c42y-0.png: Expected 5 parts, got 0.
# Skipping 9d5xyo-0.png: Expected 6 parts, got 4.
# Skipping 9dfu3gfs-0.png: Expected 8 parts, got 9.
# Skipping 9do065v-0.png: Expected 7 parts, got 2.
# Skipping 9e3j1oj-0.png: Expected 7 parts, got 0.
# Skipping 9e83qa-0.png: Expected 6 parts, got 10.
# Skipping 9edktm-0.png: Expected 6 parts, got 1.
# Skipping 9edys4-0.png: Expected 6 parts, got 0.
# Skipping d6f5y7-0.png: Expected 6 parts, got 10.
# Skipping d6vw-0.png: Expected 4 parts, got 0.
# ...
# Skipping veu44p-0.png: Expected 6 parts, got 2.
# Skipping vf1n2ewf-0.png: Expected 8 parts, got 7.
# Skipping vf3zdvo-0.png: Expected 7 parts, got 2.
# Skipping vggdclx-0.png: Expected 7 parts, got 14.
# Skipping vhb3-0.png: Expected 4 parts, got 5.
# Skipping vipst6u8-0.png: Expected 8 parts, got 7.
# Skipping viqn2wc-0.png: Expected 7 parts, got 6.
# Skipping vjen4a-0.png: Expected 6 parts, got 5.
# Skipping vk7tp-0.png: Expected 5 parts, got 0.
# Skipping vkqilkuo-0.png: Expected 8 parts, got 20.
# Skipping vkte-0.png: Expected 4 parts, got 3.
# Skipping vlg8j7-0.png: Expected 6 parts, got 5.
# Skipping vlgruxyf-0.png: Expected 8 parts, got 9.
# Skipping vlw3lq-0.png: Expected 6 parts, got 1.
# Skipping vlwit1ft-0.png: Expected 8 parts, got 0.
# Skipping vmii-0.png: Expected 4 parts, got 5.
# Skipping vmquc-0.png: Expected 5 parts, got 3.
# Skipping vmszgrh5-0.png: Expected 8 parts, got 4.
# Skipping vo47-0.png: Expected 4 parts, got 0.
# Skipping vo4wkb-0.png: Expected 6 parts, got 1.
# Skipping vonxg-0.png: Expected 5 parts, got 1.
# Skipping vpdug7-0.png: Expected 6 parts, got 0.
# Skipping vq9s-0.png: Expected 4 parts, got 2.
# Skipping vrd63n-0.png: Expected 6 parts, got 7.
# Skipping vrfdjz-0.png: Expected 6 parts, got 5.
# Skipping vrnjiy-0.png: Expected 6 parts, got 7.
# Skipping vru3d-0.png: Expected 5 parts, got 2.
# Skipping vrzow-0.png: Expected 5 parts, got 6.
# Skipping vseps0-0.png: Expected 6 parts, got 0.
# Skipping vti0kdl-0.png: Expected 7 parts, got 0.
# Skipping vu93lj3-0.png: Expected 7 parts, got 1.
# Skipping vu9gosqe-0.png: Expected 8 parts, got 7.
# Skipping vueex1o4-0.png: Expected 8 parts, got 10.
# Skipping vund0i-0.png: Expected 6 parts, got 2.
# Skipping vuvpv5-0.png: Expected 6 parts, got 5.
# Skipping vverai6p-0.png: Expected 8 parts, got 7.
# Skipping vvvc2lx-0.png: Expected 7 parts, got 0.
# Skipping vw683i-0.png: Expected 6 parts, got 1.
# Skipping vxhtnoi-0.png: Expected 7 parts, got 0.
# Skipping vyg2wz-0.png: Expected 6 parts, got 0.
# Skipping vznffj3f-0.png: Expected 8 parts, got 5.
# Skipping w0j0y-0.png: Expected 5 parts, got 4.
# Skipping w2n3fop-0.png: Expected 7 parts, got 6.
# Skipping w3wo2-0.png: Expected 5 parts, got 9.
# Skipping w46pe3ai-0.png: Expected 8 parts, got 1.
# Skipping w4hj-0.png: Expected 4 parts, got 3.
# Skipping w4tk19h-0.png: Expected 7 parts, got 8.
# Skipping w4yplxy7-0.png: Expected 8 parts, got 13.
# Skipping w51m8lf-0.png: Expected 7 parts, got 5.
# Skipping w53w-0.png: Expected 4 parts, got 2.
# Skipping xhtn0gj-0.png: Expected 7 parts, got 0.
# Skipping xhzfw8-0.png: Expected 6 parts, got 5.
# Skipping xjgk68-0.png: Expected 6 parts, got 0.
# Skipping xjnijun1-0.png: Expected 8 parts, got 7.
# Skipping xk70-0.png: Expected 4 parts, got 2.
# Skipping xl2h-0.png: Expected 4 parts, got 3.
# Skipping xlwwmr-0.png: Expected 6 parts, got 2.
# Skipping xm23a-0.png: Expected 5 parts, got 0.
# Skipping xmw8-0.png: Expected 4 parts, got 5.
# Skipping xnrr-0.png: Expected 4 parts, got 2.
# Skipping xomtqn2-0.png: Expected 7 parts, got 5.
# Skipping xp1jmtc-0.png: Expected 7 parts, got 4.
# Skipping xpav6p-0.png: Expected 6 parts, got 0.
# Skipping xpm5v4-0.png: Expected 6 parts, got 5.
# Skipping xr8b2-0.png: Expected 5 parts, got 0.
# Skipping xrb5-0.png: Expected 4 parts, got 2.
# Skipping xrdc-0.png: Expected 4 parts, got 0.
# Skipping xs4hgq-0.png: Expected 6 parts, got 0.
# Skipping xsuiagc-0.png: Expected 7 parts, got 6.
# Skipping xsxtu9-0.png: Expected 6 parts, got 3.
# Skipping xt1r9liy-0.png: Expected 8 parts, got 3.
# Skipping xv0ozy3-0.png: Expected 7 parts, got 0.
# Skipping xv8p-0.png: Expected 4 parts, got 0.
# Skipping xwgvm-0.png: Expected 5 parts, got 4.
# Skipping xwh3nqxx-0.png: Expected 8 parts, got 3.
# Skipping xxblrq9s-0.png: Expected 8 parts, got 10.
# Skipping xxdlt4x1-0.png: Expected 8 parts, got 0.
# Skipping xyvz-0.png: Expected 4 parts, got 0.
# Skipping xzov4-0.png: Expected 5 parts, got 0.
# Skipping y07ce-0.png: Expected 5 parts, got 0.
# Skipping y0ab6-0.png: Expected 5 parts, got 2.
# Skipping y0cq-0.png: Expected 4 parts, got 2.
# Skipping y0qo-0.png: Expected 4 parts, got 0.
# Skipping y1nk-0.png: Expected 4 parts, got 1.
# Skipping y2bbp-0.png: Expected 5 parts, got 0.
# Skipping y2nq-0.png: Expected 4 parts, got 5.
# Skipping y31w-0.png: Expected 4 parts, got 0.
# Skipping y33e0ck-0.png: Expected 7 parts, got 0.
# Skipping y3df0f79-0.png: Expected 8 parts, got 7.
# Skipping y3t7tr-0.png: Expected 6 parts, got 5.
# Skipping y47br5d3-0.png: Expected 8 parts, got 0.
# Skipping y48gtvr-0.png: Expected 7 parts, got 9.
# Skipping y4h0wzbo-0.png: Expected 8 parts, got 0.
# Skipping y50vlby-0.png: Expected 7 parts, got 1.
# Skipping y56ibo-0.png: Expected 6 parts, got 1.
# Skipping y5h7lmio-0.png: Expected 8 parts, got 3.
# Skipping y5qymn65-0.png: Expected 8 parts, got 0.
# Skipping y5s7pz-0.png: Expected 6 parts, got 13.
# Skipping y6qxq2p-0.png: Expected 7 parts, got 0.
# Skipping y6rjq-0.png: Expected 5 parts, got 7.
# Skipping y74bsx-0.png: Expected 6 parts, got 5.
# Skipping y8bd-0.png: Expected 4 parts, got 0.
# Skipping y8cc-0.png: Expected 4 parts, got 3.
# Skipping y90mbh-0.png: Expected 6 parts, got 0.
# Skipping y94v-0.png: Expected 4 parts, got 3.
# Skipping y9ii18yh-0.png: Expected 8 parts, got 0.
# Skipping y9om70-0.png: Expected 6 parts, got 5.
# Skipping yaqnusi5-0.png: Expected 8 parts, got 3.
# Skipping yaxwtssg-0.png: Expected 8 parts, got 0.
# Skipping yedxpokp-0.png: Expected 8 parts, got 5.
# Skipping yf1skt-0.png: Expected 6 parts, got 0.
# Skipping yfkx4v1-0.png: Expected 7 parts, got 3.
# Skipping ygaju-0.png: Expected 5 parts, got 4.
# Skipping ygir7b-0.png: Expected 6 parts, got 5.
# Skipping yglx0-0.png: Expected 5 parts, got 6.
# Skipping ygwf3-0.png: Expected 5 parts, got 4.
# Skipping yizefh-0.png: Expected 6 parts, got 4.
# Skipping yj8alup-0.png: Expected 7 parts, got 3.
# Skipping yjbykv-0.png: Expected 6 parts, got 0.
# Skipping yjod-0.png: Expected 4 parts, got 0.
# Skipping yjshxc-0.png: Expected 6 parts, got 0.
# Skipping ykdw-0.png: Expected 4 parts, got 2.
# Skipping yl55oswh-0.png: Expected 8 parts, got 9.
# Skipping ylal-0.png: Expected 4 parts, got 6.
# Skipping ylby0t0a-0.png: Expected 8 parts, got 7.
# Skipping yml9m-0.png: Expected 5 parts, got 2.
# Skipping ymva5s55-0.png: Expected 8 parts, got 9.
# Skipping ynrjet-0.png: Expected 6 parts, got 0.
# Skipping yo4y5o28-0.png: Expected 8 parts, got 7.
# Skipping yof332no-0.png: Expected 8 parts, got 10.
# Skipping yoj2-0.png: Expected 4 parts, got 5.
# Skipping ypczzmkn-0.png: Expected 8 parts, got 7.
# Skipping yps8t-0.png: Expected 5 parts, got 3.
# Skipping yput-0.png: Expected 4 parts, got 0.
# Skipping yq85o-0.png: Expected 5 parts, got 0.
# Skipping yqeg-0.png: Expected 4 parts, got 8.
# Skipping yrer3q6-0.png: Expected 7 parts, got 1.
# Skipping yruoe-0.png: Expected 5 parts, got 6.
# Skipping ysd1x7xl-0.png: Expected 8 parts, got 6.
# Skipping ysqhhiqa-0.png: Expected 8 parts, got 0.
# Skipping ysv1jv2-0.png: Expected 7 parts, got 3.
# Skipping yva82-0.png: Expected 5 parts, got 6.
# Skipping yve9-0.png: Expected 4 parts, got 6.
# Skipping yvhei-0.png: Expected 5 parts, got 4.
# Skipping ywmln43-0.png: Expected 7 parts, got 9.
# Skipping ywrljt-0.png: Expected 6 parts, got 0.
# Skipping ywurlaja-0.png: Expected 8 parts, got 7.
# Skipping ywwwm-0.png: Expected 5 parts, got 7.
# Skipping yyq1c1-0.png: Expected 6 parts, got 0.
# Skipping yyvv0kit-0.png: Expected 8 parts, got 1.
# Skipping yzcyf-0.png: Expected 5 parts, got 0.
# Skipping yzikl-0.png: Expected 5 parts, got 0.
# Skipping yzt3tz-0.png: Expected 6 parts, got 5.
# Skipping z0r2jhoe-0.png: Expected 8 parts, got 3.
# Skipping z0srsos-0.png: Expected 7 parts, got 3.
# Skipping z10e-0.png: Expected 4 parts, got 1.
# Skipping z1arx-0.png: Expected 5 parts, got 2.
# Skipping zsq2xr-0.png: Expected 6 parts, got 0.
# Skipping ztlig-0.png: Expected 5 parts, got 4.
# Skipping ztodeq-0.png: Expected 6 parts, got 7.
# Skipping ztotnw-0.png: Expected 6 parts, got 5.
# Skipping zu313a-0.png: Expected 6 parts, got 5.
# Skipping zvdl5-0.png: Expected 5 parts, got 4.
# Skipping zw3i6-0.png: Expected 5 parts, got 1.
# Skipping zwo8y-0.png: Expected 5 parts, got 2.
# Skipping zwol36kj-0.png: Expected 8 parts, got 0.
# Skipping zwvt087-0.png: Expected 7 parts, got 9.
# Skipping zxa8-0.png: Expected 4 parts, got 5.
# Skipping zykh5-0.png: Expected 5 parts, got 6.
# Skipping zzs1jtb-0.png: Expected 7 parts, got 2.
# Processing complete! Segmented characters are saved in /Users/pearl/Downloads/cs4243/segmented_train
# Total skipped: 2686

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def augment_and_save_images(input_dir, output_dir, augment_count=3):
    """Augment images from `input_dir` and save them with proper naming to `output_dir`."""
    os.makedirs(output_dir, exist_ok=True)  # Ensure the output directory exists

    # Define a more controlled data augmentation pipeline
    datagen = ImageDataGenerator(
        rotation_range=10,          # Small rotation for better quality
        width_shift_range=0.05,     # Slight horizontal shift
        height_shift_range=0.05,    # Slight vertical shift
        shear_range=0.1,            # Mild shearing
        zoom_range=0.1,             # Mild zoom
        fill_mode='nearest'         # Avoid introducing artifacts
    )

    # Loop through all images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith('.png'):
            # Load the original image
            image_path = os.path.join(input_dir, filename)
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # Expand dimensions for augmentation
            img = np.expand_dims(img, axis=-1)  # Add channel dimension
            img = np.expand_dims(img, axis=0)   # Add batch dimension

            # Extract the base filename without extension (e.g., 'abc-o')
            base_name = filename.split('.')[0]

            # Generate and save augmented images
            for i, batch in enumerate(datagen.flow(img, batch_size=1)):
                # Save each augmented image with proper naming
                augmented_filename = f"{base_name}-{i + 1}.png"
                augmented_path = os.path.join(output_dir, augmented_filename)

                # Save the augmented image
                cv2.imwrite(augmented_path, batch[0].squeeze().astype(np.uint8))

                # Stop after generating `augment_count` images per original image
                if i + 1 >= augment_count:
                    break

    print(f"Augmentation complete! Augmented images saved in {output_dir}")


# Example usage
input_dir = SEGMENTED_TRAIN_DATASET_PATH
output_dir = AUGMENTED_SEGMENTED_TRAIN_DATASET_PATH
augment_and_save_images(input_dir, output_dir)
# Out:
# Augmentation complete! Augmented images saved in /Users/pearl/Downloads/cs4243/augmented_segmented_train

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# Define character set (e.g., 0-9, a-z)
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_TO_IDX = {char: idx for idx, char in enumerate(CHAR_SET)}

def load_dataset(data_dir):
    images = []
    labels = []

    for filename in os.listdir(data_dir):
        if filename.endswith('.png'):
            # Extract the character from the filename (e.g., 'o' from 'oq1j-o.png')
            char_label = filename.split('-')[1][0]

            if char_label in CHAR_TO_IDX:
                # Load the image in grayscale
                image_path = os.path.join(data_dir, filename)
                img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

                # Resize to 28x28 (if needed)
                img = cv2.resize(img, (28, 28))
                img = img / 255.0  # Normalize pixel values to [0, 1]

                # Store the image and label
                images.append(img)
                labels.append(CHAR_TO_IDX[char_label])

    # Convert to numpy arrays
    images = np.array(images).reshape(-1, 28, 28, 1)  # Add channel dimension
    labels = np.array(labels)

    return images, labels

# Load the dataset
images, labels = load_dataset(output_dir)
print(f"Loaded {len(images)} images with {len(set(labels))} unique labels.")
# Out:
# Loaded 88374 images with 36 unique labels.

# %%
# Split the data into training and validation sets (80% train, 20% validation)
X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

print(f"Training set size: {X_train.shape[0]}, Validation set size: {X_val.shape[0]}")
# Out:
# Training set size: 70699, Validation set size: 17675

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def build_model(num_classes):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D((2, 2)),
        Dropout(0.2),

        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Dropout(0.2),

        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Build the model for 36 classes (0-9, a-z)
num_classes = len(CHAR_SET)
model = build_model(num_classes)
model.summary()
# Out:
# c:\Users\pearl\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 36)             │         4,644 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 228,388 (892.14 KB)
#  Trainable params: 228,388 (892.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64
)
# Out:
# Epoch 1/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.1867 - loss: 2.9844 - val_accuracy: 0.5864 - val_loss: 1.5236
# Epoch 2/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.4951 - loss: 1.7685 - val_accuracy: 0.6448 - val_loss: 1.2703
# Epoch 3/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.5542 - loss: 1.5396 - val_accuracy: 0.6674 - val_loss: 1.1598
# Epoch 4/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.5805 - loss: 1.4282 - val_accuracy: 0.6963 - val_loss: 1.0669
# Epoch 5/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6060 - loss: 1.3602 - val_accuracy: 0.7057 - val_loss: 1.0289
# Epoch 6/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6172 - loss: 1.3081 - val_accuracy: 0.7159 - val_loss: 0.9737
# Epoch 7/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6289 - loss: 1.2689 - val_accuracy: 0.7218 - val_loss: 0.9576
# Epoch 8/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6397 - loss: 1.2295 - val_accuracy: 0.7274 - val_loss: 0.9415
# Epoch 9/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6453 - loss: 1.2002 - val_accuracy: 0.7350 - val_loss: 0.9206
# Epoch 10/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.6529 - loss: 1.1791 - val_accuracy: 0.7334 - val_loss: 0.9337
# Epoch 11/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6602 - loss: 1.1511 - val_accuracy: 0.7413 - val_loss: 0.8899
# Epoch 12/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6612 - loss: 1.1380 - val_accuracy: 0.7391 - val_loss: 0.8977
# Epoch 13/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6647 - loss: 1.1229 - val_accuracy: 0.7512 - val_loss: 0.8466
# Epoch 14/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6668 - loss: 1.1228 - val_accuracy: 0.7513 - val_loss: 0.8476
# Epoch 15/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6698 - loss: 1.1029 - val_accuracy: 0.7549 - val_loss: 0.8403
# Epoch 16/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6734 - loss: 1.0881 - val_accuracy: 0.7565 - val_loss: 0.8331
# Epoch 17/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6808 - loss: 1.0771 - val_accuracy: 0.7585 - val_loss: 0.8184
# Epoch 18/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6819 - loss: 1.0652 - val_accuracy: 0.7614 - val_loss: 0.8129
# Epoch 19/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6899 - loss: 1.0388 - val_accuracy: 0.7629 - val_loss: 0.8078
# Epoch 20/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6874 - loss: 1.0422 - val_accuracy: 0.7644 - val_loss: 0.7937
# Epoch 21/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.6891 - loss: 1.0315 - val_accuracy: 0.7632 - val_loss: 0.7961
# Epoch 22/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6918 - loss: 1.0202 - val_accuracy: 0.7653 - val_loss: 0.8014
# Epoch 23/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6891 - loss: 1.0266 - val_accuracy: 0.7710 - val_loss: 0.7820
# Epoch 24/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7022 - loss: 0.9951 - val_accuracy: 0.7684 - val_loss: 0.7837
# Epoch 25/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6983 - loss: 0.9979 - val_accuracy: 0.7661 - val_loss: 0.7915
# Epoch 26/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6965 - loss: 1.0078 - val_accuracy: 0.7721 - val_loss: 0.7650
# Epoch 27/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6998 - loss: 0.9895 - val_accuracy: 0.7730 - val_loss: 0.7804
# Epoch 28/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7007 - loss: 0.9874 - val_accuracy: 0.7724 - val_loss: 0.7630
# Epoch 29/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7009 - loss: 0.9866 - val_accuracy: 0.7677 - val_loss: 0.7838
# Epoch 30/30
# 1105/1105 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7045 - loss: 0.9719 - val_accuracy: 0.7753 - val_loss: 0.7541

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7756 - loss: 0.7500
# Validation Loss: 0.7541, Validation Accuracy: 77.53%

# %%
# Save the trained model
def save_model(model, dir_path, model_name="character_recognition_model.h5"):
    # Ensure the directory exists
    os.makedirs(dir_path, exist_ok=True)
    
    # Create the full path to the model file
    model_path = os.path.join(dir_path, model_name)
    
    # Save the model
    model.save(model_path)
    print(f"Model saved successfully at: {model_path}")

# Example usage
save_dir = "/Users/pearl/Downloads/cs4243/model"
save_model(model, save_dir)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully at: /Users/pearl/Downloads/cs4243/model\character_recognition_model.h5

# %%
def predict_character(image_path, model):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (28, 28)) / 255.0  # Normalize
    img = np.expand_dims(img, axis=[0, -1])  # Add batch and channel dimensions

    prediction = model.predict(img)
    predicted_label = np.argmax(prediction)
    predicted_char = CHAR_SET[predicted_label]

    return predicted_char

# Example usage
model = tf.keras.models.load_model('/Users/pearl/Downloads/cs4243/model/character_recognition_model.h5')
predicted_char = predict_character('/Users/pearl/Downloads/cs4243/segmented_train/0tqk-t.png', model)
print(f"Predicted Character: {predicted_char}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted Character: t

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load the trained model
model_path = '/Users/pearl/Downloads/cs4243/model/character_recognition_model.h5'
model = load_model(model_path)

# Define the character set used during training
CHAR_SET = "0123456789abcdefghijklmnopqrstuvwxyz"
CHAR_MAP = {idx: char for idx, char in enumerate(CHAR_SET)}

def preprocess_image(image_path):
    """Preprocess the image using the same steps as in training."""
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = gaussian_thresholding(image)
    image = dilate(image)
    return image

def gaussian_thresholding(image):
    # Use gaussian blur to make characters thicker before thresholding 
    blur = cv2.GaussianBlur(image, (5, 5), 0)
    thresholded_image = cv2.adaptiveThreshold(
        blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
        cv2.THRESH_BINARY, blockSize=11, C=2
    )
    return image

def dilate(image):
    #  Remove noise via dilation
    kernel = np.ones((3,3), np.uint8)
    dilation = cv2.dilate(image, kernel, iterations=1)
    
    # show_image("Dilated", dilation)
    return dilation

# def adaptive_thresholding(image):
#     """Apply adaptive thresholding."""
#     return cv2.adaptiveThreshold(
#         image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
#         cv2.THRESH_BINARY_INV, blockSize=11, C=2
#     )

# def remove_noise(image):
#     """Remove small noise using morphological operations."""
#     kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
#     cleaned_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel, iterations=1)
#     cleaned_image = cv2.morphologyEx(cleaned_image, cv2.MORPH_CLOSE, kernel, iterations=1)
#     return cleaned_image

# def remove_lines(image):
#     """Remove lines using Hough Line Transform."""
#     lines = cv2.HoughLinesP(image, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)
#     if lines is not None:
#         for line in lines:
#             x1, y1, x2, y2 = line[0]
#             cv2.line(image, (x1, y1), (x2, y2), 0, thickness=2)
#     return image

def segment_characters(image):
    """Segment the CAPTCHA image into individual characters."""
    inverted_image = cv2.bitwise_not(image)

    contours, _ = cv2.findContours(inverted_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    char_images = []

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        if h > 10:  # Ignore small contours (noise)
            char_img = image[y:y+h, x:x+w]
            char_images.append((x, char_img))

    # Sort by x-coordinate to ensure correct order
    char_images = sorted(char_images, key=lambda c: c[0])
    return [char[1] for char in char_images]

def predict_character(image, model):
    """Predict a single character using the trained model."""
    img = cv2.resize(image, (28, 28)) / 255.0  # Resize and normalize
    img = np.expand_dims(img, axis=[0, -1])  # Add batch and channel dimensions

    prediction = model.predict(img)
    predicted_label = np.argmax(prediction)
    predicted_char = CHAR_MAP[predicted_label]
    return predicted_char

def predict_captcha_string(image_path, model):
    """Predict the entire CAPTCHA string from the input image."""
    # Preprocess the image
    processed_image = preprocess_image(image_path)

    # Segment the characters
    char_images = segment_characters(processed_image)

    # Predict each character and reconstruct the string
    predicted_string = ""
    for char_img in char_images:
        predicted_char = predict_character(char_img, model)
        predicted_string += predicted_char

    return predicted_string



# Example usage
captcha_image_path = "/Users/pearl/Downloads/cs4243/test/2d76-0.png"
predicted_string = predict_captcha_string(captcha_image_path, model)
print(f"Predicted CAPTCHA string: {predicted_string}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted CAPTCHA string: 2d76

# %%
import os

def evaluate_on_unseen_data(unseen_dir, model, num_images=20):
    """Evaluate the model on the first `num_images` from the unseen directory."""
    correct_predictions = 0
    total_images = 0

    # Get the first `num_images` files from the directory
    all_files = [f for f in os.listdir(unseen_dir) if f.endswith('.png')]
    all_files = sorted(all_files)[:num_images]  # Limit to first `num_images`

    for filename in all_files:
        # Extract the true label from the filename (e.g., '2d76' from '2d76-0.png')
        true_label = filename.split('-')[0]

        # Get the full path to the image
        image_path = os.path.join(unseen_dir, filename)

        # Predict the CAPTCHA string
        predicted_string = predict_captcha_string(image_path, model)
        print(f"True: {true_label}, Predicted: {predicted_string}")

        # Compare the predicted string with the true label
        if predicted_string == true_label:
            correct_predictions += 1

        total_images += 1

    # Calculate accuracy
    accuracy = correct_predictions / total_images * 100
    print(f"\nAccuracy on the first {num_images} images: {accuracy:.2f}%")

# Example usage
unseen_dir = "/Users/pearl/Downloads/cs4243/test"
evaluate_on_unseen_data(unseen_dir, model, 1000)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 002e23, Predicted: o0ze23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 03yl9s, Predicted: o3yi9s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 03yuav5, Predicted: d3yuov5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 03zl9o, Predicted: 03zl90
# True: 04zqohgi, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 05htm, Predicted: 05htm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 05pb, Predicted: 05pb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 07oj, Predicted: 070j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# True: 07z0, Predicted: 07zo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 08ft2e2z, Predicted: o8ft2e2z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 08nxd77, Predicted: 08nxd77
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 08otejfi, Predicted: 080tejfz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 08sba, Predicted: inh3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 09popm, Predicted: 09popm
# True: 0a7sh2wp, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0al4pl, Predicted: ji
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0c3dp, Predicted: 0c3dp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0c7mgdmd, Predicted: oo7mgdmo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0chnm34, Predicted: ww4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0col7w, Predicted: oco2w
# True: 0cr6, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0dx9, Predicted: rj42
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0fa6qtkn, Predicted: nfai3ghe0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0favtnx, Predicted: cfavtnx
# True: 0fee, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0gil, Predicted: ogi1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0gzwaq8, Predicted: ogzwaqp111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0h5ya8, Predicted: oh5ya8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0i7uom, Predicted: 0i1fj0ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0ilhsr2t, Predicted: iilhsr27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0iqk95h, Predicted: nink95h
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0k2lyyc, Predicted: ii1i
# True: 0lfjfob, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0me2a, Predicted: 0me2a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0mgnhi, Predicted: 0mgnhl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0msi, Predicted: 0msi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0n5546, Predicted: on5546
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0nq0e, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 0nucs59, Predicted: 0nucs59
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0pglswc, Predicted: 0pgi8wc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# True: 0pv2w1t, Predicted: 0pv2wit
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0qtjdlvt, Predicted: ii1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0rlbarm, Predicted: obl8a8m
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0rq9qn, Predicted: dsq9on
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0rw4sjk, Predicted: jrw4s3t
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0s2rn2o, Predicted: d52rn20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0scs, Predicted: n505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0sia, Predicted: o5a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0sm8cb4c, Predicted: jm8cbfc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0tbe, Predicted: ie
# True: 0u0y5, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 0u4aj, Predicted: ou4aj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0v4o0p, Predicted: nt30p
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0vug13, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0w0pankd, Predicted: iifkj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0wcz1w, Predicted: owcz7w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 0wla, Predicted: ntlji3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0wy4otel, Predicted: olz3kl40fei
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 0yoxyw5, Predicted: 0y0xyw5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 11nm, Predicted: 11nm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1324mrg, Predicted: 13z4mrg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 13be3kf, Predicted: i2jcig2jc7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 13bsgn2, Predicted: f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 13v4msh, Predicted: 13v4msh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 13xy, Predicted: i3xy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 153tt0, Predicted: 63ffj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 17z8030, Predicted: zyii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 18gg, Predicted: 78gg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 19hz, Predicted: 19hz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1asdyrv, Predicted: 1asdyrv
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1avc, Predicted: 1avc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1awqu, Predicted: 1dwqu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1bu55hc, Predicted: 19u55h0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1c3bi3zm, Predicted: 1c56ihzm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1cfa40wy, Predicted: lntjyy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1ctc5l, Predicted: ckcw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1dhcacd, Predicted: 1dhcacd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1dy0p, Predicted: 7dy0d
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1e1qxwyz, Predicted: hehqxwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1ed0i9xz, Predicted: 1edoi9xz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 1ewgub4, Predicted: 1fw6ub4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1ewq, Predicted: 1ewo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1fh4thm, Predicted: ifh4thm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1gbu5qus, Predicted: 7qbu5qug
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1ghx0spj, Predicted: ighxospj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1hiqbpx3, Predicted: ih1qbpx3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1imwt, Predicted: iimtii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# True: 1irn, Predicted: iiiih
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1iwe, Predicted: iiwe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1j2xhu, Predicted: 7j2xhui
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1k94, Predicted: ii594
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# True: 1kfm, Predicted: 1kfm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1ku9bzoy, Predicted: 1ku9bzoy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1mrffz, Predicted: irff2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1mwa, Predicted: 1mwa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1nyd, Predicted: inyd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1o5kcof, Predicted: io5kcof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1ozltu, Predicted: 0lpu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1qp4885m, Predicted: 1gp4886m
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1rhud8rx, Predicted: mhudhx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1sil9, Predicted: ll
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1tyn, Predicted: 1tyn
# True: 1u81r, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1ulul, Predicted: 7uiui
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1wu0cul, Predicted: 1iljijoci1i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 1x44n7nx, Predicted: 4s
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# True: 1x8ljpi, Predicted: 1x8ljp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 1xut0w4, Predicted: ixut0w4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 1zcg2o, Predicted: zcg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: 20ka8wmo, Predicted: 20ka8wmn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 21iyxsn, Predicted: 2iiyhsn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 21z1y, Predicted: 2iziy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 220ofgki, Predicted: 9rcli
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 23osam, Predicted: 23osam
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 24idbq3f, Predicted: 24idb03f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 24y0s85, Predicted: 24yo5e5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 265qfy, Predicted: 265qfy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 26pw3, Predicted: 26pw3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 273u, Predicted: 273u
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 27hibrae, Predicted: q7fl6kqe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 29bgk, Predicted: 29bgk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 29or, Predicted: 2mor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2aidl, Predicted: 2didi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2bdh, Predicted: 2bdh
# True: 2bjj1pos, Predicted:
# True: 2c5ol, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2cteaog, Predicted: 2ctea0g
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2d0qj, Predicted: 2dooj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 2d76, Predicted: 2d76
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2ennujkj, Predicted: 2ennujkj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2flvu7n, Predicted: lf3j
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2fxu0s, Predicted: 2fxuo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2fyohm, Predicted: qtylwm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2gbiw7, Predicted: x2rf1i7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2gquin1i, Predicted: 2gquinii
# True: 2gslhci, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2iulzl, Predicted: 2iulzl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2k1xlp, Predicted: 2k1xlp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2m1qu1e4, Predicted: 2m1quie1d
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2mo9qj39, Predicted: 2mr79q139
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2mvjsa, Predicted: 2mvjs4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: 2n2it3lx, Predicted: 2n2it3lx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2njlt4, Predicted: 2i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2o6f, Predicted: 006f
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 2oa73, Predicted: 2oo73
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2oy2f9, Predicted: 20y2fq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2p6wwybk, Predicted: 2gfww4hk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2q9zjsun, Predicted: wz15un
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: 2qhqtv2, Predicted: ilif
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2rs4jvyr, Predicted: 2rs4uuyr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2sp9gvbi, Predicted: 2sp9gvbi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2sxkz2vj, Predicted: 2sxkz2uj
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# True: 2t02x, Predicted: 2t02x
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 2txh8, Predicted: 2txh8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2tyw3, Predicted: 2tfw3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 2u6t6, Predicted: 2u6t6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2v2n13je, Predicted: 2v2n13je
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2vapwy, Predicted: 2vapwy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 2w02hmo, Predicted: 2wn2hmn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 2x7qps0, Predicted: 3t9p
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 2y11w, Predicted: 2y11w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2y43vf, Predicted: qy421l
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 2ybig03, Predicted: 43
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 2yjiz, Predicted: 2yjjz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 2yjoie, Predicted: yj0if
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 2yqdk, Predicted: 2yqdk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 2zkfhs1n, Predicted: 2zhfhs10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 2zs3, Predicted: 2zs3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 30rju0c, Predicted: 30rju0c
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 30znefk, Predicted: gol2ofk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: 31qyiq, Predicted: 37qyiq
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 327gm, Predicted: 327gm
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 32evcjk8, Predicted: 32oys5xb
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 32llr, Predicted: 32iir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 33yxl, Predicted: if11xn
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 345ar, Predicted: 345ar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 35av6, Predicted: 35av6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 36ev8oj, Predicted: 36bh80i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 379cfumx, Predicted: 329cfunx
# True: 386h7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 38v2mv, Predicted: 3by2my
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: 39fyn9, Predicted: 39fyn9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 39uww47, Predicted: m9uwwh7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3aa8, Predicted: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3aut4, Predicted: 3aut4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 3b84c7sq, Predicted: 9b84e7jo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 3easf, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3eo06, Predicted: 3m6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3eyys, Predicted: 3eyys
# True: 3flp3ljj, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3fv5o, Predicted: 3tvuno
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 3g34h, Predicted: 3q4h
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# True: 3g79jlr, Predicted: 3g79jir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3ho9, Predicted: 3ad9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# True: 3ia0oel, Predicted: 3ogei
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: 3ido1q0, Predicted: 3ido1qo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3ii4, Predicted: 3ii4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3j61hli, Predicted: irjli
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3lsrj, Predicted: 3trj
# True: 3ltl6jon, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: 3m22, Predicted: 3m22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3mlhaz, Predicted: 3mwk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: 3mtklt8z, Predicted: 3mtl1t8z
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 3n6o, Predicted: 3n6o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: 3nnz7pka, Predicted: mnz7w
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: h4titb0, Predicted: h14fifid0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: h50769iw, Predicted: h50769iw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: h50uifd, Predicted: i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: h6dtd, Predicted: n6dtd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: h6o7n, Predicted: h607n
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: h7f9, Predicted: h7f9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: h8tg, Predicted: hntc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hagreh, Predicted: ho9reh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: ham46lpd, Predicted: ham46ipd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: haps2, Predicted: 3iz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hb5fz, Predicted: 4b5fz
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: hbll9, Predicted: hbii9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# True: hc0ulqk, Predicted: hoyk
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hc5rx39, Predicted: iic5nx3q
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hc8jk3, Predicted: hwjk3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hciv7, Predicted: huriui7i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hcwgu, Predicted: hcwgu
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# True: he7grud, Predicted: he7grup
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hetibp, Predicted: h8tihp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hj5ms, Predicted: hj5ms
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hjbj, Predicted: hihi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hkmy29, Predicted: hkmy29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hl79, Predicted: hl79
# True: hljv6, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hm5osaq, Predicted: ijsj7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hnns4, Predicted: hnns4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: ho6v2tsw, Predicted: hc6l2tsw
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: hptym6, Predicted: x3ty3b
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hqo6slvr, Predicted: hg06sivr
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hrdksy8, Predicted: hrdky8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hsb1tie, Predicted: hsh1tip
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: hsnd7hq, Predicted: ksg47h1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# True: hvch2er7, Predicted: hjbe7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hvgp, Predicted: hvgp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hvj6wg, Predicted: iil9i3jl16i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hvk6, Predicted: hvk6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hw6ta6, Predicted: hltcl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hwev766, Predicted: hwev766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hxtahp3, Predicted: ffit3ffp3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# True: hy850xk1, Predicted: hy85oxki
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# True: hy8d, Predicted: ilyr2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: hyj870q, Predicted: hyiq70q
# True: hynvxdz, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: hyp3tvwt, Predicted: fxvvx
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i1yipm08, Predicted: iifmi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i23xg1a8, Predicted: 123xqb8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# True: i2d24k, Predicted: i2d24k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# True: i2j3gfg, Predicted: i2j3gfg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i2tc, Predicted: i2tc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i2ximgo, Predicted: i2ximgo
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i3hsnv, Predicted: i34snii
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i3ijtc, Predicted: i3ijtc
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i3jpjs, Predicted: i3jpjs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i3reuje, Predicted: l3rewbe
# True: i3vv4b7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# True: i4yahaly, Predicted: l
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i5aa1, Predicted: i1t1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i5kd0omr, Predicted: icyd0nir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i6i6e, Predicted: i6i6e
# True: i7hqc7, Predicted:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: i9dhn60, Predicted: i9nhm6o
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: i9n9a, Predicted: 19n9a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# True: iackdv2, Predicted: iacxov2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: iazoykf, Predicted: 3wji1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True: ib7372l, Predicted: ih1i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# True: ibkmxh, Predicted: ihkn7xh
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# True: ibn9ph, Predicted: ibn9ph
#
# Accuracy on the first 1000 images: 25.30%
